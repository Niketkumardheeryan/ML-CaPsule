# %%
#Importing Libraries
import pandas as pd
import os
import tensorflow as tf
from keras import backend as K
from tensorflow.keras.preprocessing import image_dataset_from_directory
from keras.models import  Model
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Conv2D, GlobalAveragePooling2D,DepthwiseConv2D

# %%
#Extracting data
data_path = '../input/image-data'
work_path = '../work'

# %%
#Train and Test Data
train_path = os.path.join(work_path, 'train')
test_path = os.path.join(work_path, 'test1')

# %%
#Dataframe for images
train_df = pd.DataFrame({'image_name':os.listdir(train_path)})
train_df['label'] =train_df['image_name'].apply(lambda x: x.split('.')[0])

# %%
# Defining Variance Scaling Initializer
initializer = tf.keras.initializers.VarianceScaling(
scale=0.1, mode='fan_in', distribution='uniform')

# %%
#Defining Identity Block
def identity_block(X, f, filters, stage, block):
   
    conv_name_base = 'conv' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1,F3 = filters

    X_shortcut = X
   
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2a', kernel_initializer=initializer)(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = DepthwiseConv2D(kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=initializer)(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=initializer)(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X = Add()([X, X_shortcut])# SKIP Connection
    X = Activation('relu')(X)

    return X

# %%
#Defining Main Block
def main_block(X, f, filters, stage, block):
   
    conv_name_base = 'conv' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F3 = filters
   
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2a', kernel_initializer=initializer)(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = ZeroPadding2D((3, 3))(X)
    X = DepthwiseConv2D(kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=initializer)(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=initializer)(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    return X

# %%
# Defining the Google Teachable Machine that makes use of identity and main block
def GoogleTeachableMachine(input_shape=(224, 224, 3)):

    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    X = Conv2D(16, (3, 3), strides=(2, 2), name='conv1', kernel_initializer=initializer)(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = DepthwiseConv2D(16, (3, 3), name='conv2', kernel_initializer=initializer)(X)
    X = BatchNormalization(axis=3, name='bn_conv2')(X)
    X = Activation('relu')(X)
    X = Conv2D(16, (3, 3), strides=(2, 2), name='conv3', kernel_initializer=initializer)(X)
    X = BatchNormalization(axis=3, name='bn_conv3')(X)
    
    X = main_block(X, 3, [48,8], stage=2, block='b')
    X = identity_block(X, 3, [48,8], stage=2, block='c')
    
    X = main_block(X, 3, [48,16], stage=3, block='b')
    X = identity_block(X, 3, [96,16], stage=3, block='c')
    
    X = identity_block(X, 3, [96,16], stage=4, block='b')
    
    X = main_block(X, 3, [96,24], stage=5, block='b')
    X = identity_block(X, 3, [144,24], stage=5, block='c')
    
    X = identity_block(X, 3, [144,24], stage=6, block='b')
    
    X = identity_block(X, 3, [144,24], stage=7, block='b')
    
    X = main_block(X, 3, [144,32], stage=8, block='b')
    X = identity_block(X, 3, [192,32], stage=8, block='c')
    
    X = identity_block(X, 3, [192,32], stage=9, block='b')
    
    X = main_block(X, 3, [192,56], stage=10, block='b')
    X = identity_block(X, 3, [336,56], stage=10, block='c')
    
    X = identity_block(X, 3, [336,56], stage=11, block='b')
    
    X = main_block(X, 3, [336,112], stage=12, block='b')
    
    X = Conv2D(1280, (3, 3), strides=(2, 2), name='conv13', kernel_initializer=initializer)(X)
    X = BatchNormalization(axis=3, name='bn_conv13')(X)
    X = Activation('relu')(X)

    X = GlobalAveragePooling2D()(X)
    
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
#Defining the main model
base_model = GoogleTeachableMachine(input_shape=(224, 224, 3))
# Out:
# 2022-04-04 03:13:09.466276: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-04 03:13:09.583370: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-04 03:13:09.584537: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-04 03:13:09.586668: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-04 03:13:09.587952: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-04 03:13:09.589046: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-04 03:13:09.590065: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-04 03:13:11.822825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-04 03:13:11.823822: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-04 03:13:11.824696: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-04 03:13:11.825539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
#Adding the Dense and Output layers
headModel = base_model.output
headModel=Dense(100, activation='relu', name='dense1',kernel_initializer=initializer)(headModel)
headModel=Dense(1,activation='softmax', name='dense2',kernel_initializer=initializer)(headModel)

# %%
model = Model(inputs=base_model.input, outputs=headModel)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 114, 114, 16) 448         zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 114, 114, 16) 64          conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 114, 114, 16) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# conv2 (DepthwiseConv2D)         (None, 33, 33, 16)   4112        activation[0][0]
# __________________________________________________________________________________________________
# bn_conv2 (BatchNormalization)   (None, 33, 33, 16)   64          conv2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 33, 33, 16)   0           bn_conv2[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv2D)                  (None, 16, 16, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# bn_conv3 (BatchNormalization)   (None, 16, 16, 16)   64          conv3[0][0]
# __________________________________________________________________________________________________
# conv2b_branch2a (Conv2D)        (None, 16, 16, 48)   816         bn_conv3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 16, 16, 48)   192         conv2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 48)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 22, 22, 48)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2b_branch2b (DepthwiseConv2 (None, 22, 22, 48)   480         zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 22, 22, 48)   192         conv2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 22, 22, 48)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# conv2b_branch2c (Conv2D)        (None, 22, 22, 8)    392         activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 22, 22, 8)    32          conv2b_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2c_branch2a (Conv2D)        (None, 22, 22, 48)   432         bn2b_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 22, 22, 48)   192         conv2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 22, 22, 48)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# conv2c_branch2b (DepthwiseConv2 (None, 22, 22, 48)   480         activation_4[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 22, 22, 48)   192         conv2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 22, 22, 48)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# conv2c_branch2c (Conv2D)        (None, 22, 22, 8)    392         activation_5[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 22, 22, 8)    32          conv2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 22, 22, 8)    0           bn2c_branch2c[0][0]
#                                                                  bn2b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 22, 22, 8)    0           add[0][0]
# __________________________________________________________________________________________________
# conv3b_branch2a (Conv2D)        (None, 22, 22, 48)   432         activation_6[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 22, 22, 48)   192         conv3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 22, 22, 48)   0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 28, 28, 48)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv3b_branch2b (DepthwiseConv2 (None, 28, 28, 48)   480         zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 28, 28, 48)   192         conv3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 48)   0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# conv3b_branch2c (Conv2D)        (None, 28, 28, 16)   784         activation_8[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 28, 28, 16)   64          conv3b_branch2c[0][0]
# __________________________________________________________________________________________________
# conv3c_branch2a (Conv2D)        (None, 28, 28, 96)   1632        bn3b_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 28, 28, 96)   384         conv3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 28, 28, 96)   0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# conv3c_branch2b (DepthwiseConv2 (None, 28, 28, 96)   960         activation_9[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 28, 28, 96)   384         conv3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 28, 28, 96)   0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# conv3c_branch2c (Conv2D)        (None, 28, 28, 16)   1552        activation_10[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 28, 28, 16)   64          conv3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 16)   0           bn3c_branch2c[0][0]
#                                                                  bn3b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv4b_branch2a (Conv2D)        (None, 28, 28, 96)   1632        activation_11[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 28, 28, 96)   384         conv4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 96)   0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# conv4b_branch2b (DepthwiseConv2 (None, 28, 28, 96)   960         activation_12[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 28, 28, 96)   384         conv4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 96)   0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# conv4b_branch2c (Conv2D)        (None, 28, 28, 16)   1552        activation_13[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 28, 28, 16)   64          conv4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 16)   0           bn4b_branch2c[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv5b_branch2a (Conv2D)        (None, 28, 28, 96)   1632        activation_14[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 28, 28, 96)   384         conv5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 96)   0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 34, 34, 96)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv5b_branch2b (DepthwiseConv2 (None, 34, 34, 96)   960         zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 34, 34, 96)   384         conv5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 34, 34, 96)   0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# conv5b_branch2c (Conv2D)        (None, 34, 34, 24)   2328        activation_16[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 34, 34, 24)   96          conv5b_branch2c[0][0]
# __________________________________________________________________________________________________
# conv5c_branch2a (Conv2D)        (None, 34, 34, 144)  3600        bn5b_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 34, 34, 144)  576         conv5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 34, 34, 144)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# conv5c_branch2b (DepthwiseConv2 (None, 34, 34, 144)  1440        activation_17[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 34, 34, 144)  576         conv5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 34, 34, 144)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# conv5c_branch2c (Conv2D)        (None, 34, 34, 24)   3480        activation_18[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 34, 34, 24)   96          conv5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 34, 34, 24)   0           bn5c_branch2c[0][0]
#                                                                  bn5b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 34, 34, 24)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv6b_branch2a (Conv2D)        (None, 34, 34, 144)  3600        activation_19[0][0]
# __________________________________________________________________________________________________
# bn6b_branch2a (BatchNormalizati (None, 34, 34, 144)  576         conv6b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 34, 34, 144)  0           bn6b_branch2a[0][0]
# __________________________________________________________________________________________________
# conv6b_branch2b (DepthwiseConv2 (None, 34, 34, 144)  1440        activation_20[0][0]
# __________________________________________________________________________________________________
# bn6b_branch2b (BatchNormalizati (None, 34, 34, 144)  576         conv6b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 34, 34, 144)  0           bn6b_branch2b[0][0]
# __________________________________________________________________________________________________
# conv6b_branch2c (Conv2D)        (None, 34, 34, 24)   3480        activation_21[0][0]
# __________________________________________________________________________________________________
# bn6b_branch2c (BatchNormalizati (None, 34, 34, 24)   96          conv6b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 34, 34, 24)   0           bn6b_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 34, 34, 24)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv7b_branch2a (Conv2D)        (None, 34, 34, 144)  3600        activation_22[0][0]
# __________________________________________________________________________________________________
# bn7b_branch2a (BatchNormalizati (None, 34, 34, 144)  576         conv7b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 34, 34, 144)  0           bn7b_branch2a[0][0]
# __________________________________________________________________________________________________
# conv7b_branch2b (DepthwiseConv2 (None, 34, 34, 144)  1440        activation_23[0][0]
# __________________________________________________________________________________________________
# bn7b_branch2b (BatchNormalizati (None, 34, 34, 144)  576         conv7b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 34, 34, 144)  0           bn7b_branch2b[0][0]
# __________________________________________________________________________________________________
# conv7b_branch2c (Conv2D)        (None, 34, 34, 24)   3480        activation_24[0][0]
# __________________________________________________________________________________________________
# bn7b_branch2c (BatchNormalizati (None, 34, 34, 24)   96          conv7b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 34, 34, 24)   0           bn7b_branch2c[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 34, 34, 24)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv8b_branch2a (Conv2D)        (None, 34, 34, 144)  3600        activation_25[0][0]
# __________________________________________________________________________________________________
# bn8b_branch2a (BatchNormalizati (None, 34, 34, 144)  576         conv8b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 34, 34, 144)  0           bn8b_branch2a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 40, 40, 144)  0           activation_26[0][0]
# __________________________________________________________________________________________________
# conv8b_branch2b (DepthwiseConv2 (None, 40, 40, 144)  1440        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# bn8b_branch2b (BatchNormalizati (None, 40, 40, 144)  576         conv8b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 40, 40, 144)  0           bn8b_branch2b[0][0]
# __________________________________________________________________________________________________
# conv8b_branch2c (Conv2D)        (None, 40, 40, 32)   4640        activation_27[0][0]
# __________________________________________________________________________________________________
# bn8b_branch2c (BatchNormalizati (None, 40, 40, 32)   128         conv8b_branch2c[0][0]
# __________________________________________________________________________________________________
# conv8c_branch2a (Conv2D)        (None, 40, 40, 192)  6336        bn8b_branch2c[0][0]
# __________________________________________________________________________________________________
# bn8c_branch2a (BatchNormalizati (None, 40, 40, 192)  768         conv8c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 40, 40, 192)  0           bn8c_branch2a[0][0]
# __________________________________________________________________________________________________
# conv8c_branch2b (DepthwiseConv2 (None, 40, 40, 192)  1920        activation_28[0][0]
# __________________________________________________________________________________________________
# bn8c_branch2b (BatchNormalizati (None, 40, 40, 192)  768         conv8c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 40, 40, 192)  0           bn8c_branch2b[0][0]
# __________________________________________________________________________________________________
# conv8c_branch2c (Conv2D)        (None, 40, 40, 32)   6176        activation_29[0][0]
# __________________________________________________________________________________________________
# bn8c_branch2c (BatchNormalizati (None, 40, 40, 32)   128         conv8c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 40, 40, 32)   0           bn8c_branch2c[0][0]
#                                                                  bn8b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 40, 40, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv9b_branch2a (Conv2D)        (None, 40, 40, 192)  6336        activation_30[0][0]
# __________________________________________________________________________________________________
# bn9b_branch2a (BatchNormalizati (None, 40, 40, 192)  768         conv9b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 40, 40, 192)  0           bn9b_branch2a[0][0]
# __________________________________________________________________________________________________
# conv9b_branch2b (DepthwiseConv2 (None, 40, 40, 192)  1920        activation_31[0][0]
# __________________________________________________________________________________________________
# bn9b_branch2b (BatchNormalizati (None, 40, 40, 192)  768         conv9b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 40, 40, 192)  0           bn9b_branch2b[0][0]
# __________________________________________________________________________________________________
# conv9b_branch2c (Conv2D)        (None, 40, 40, 32)   6176        activation_32[0][0]
# __________________________________________________________________________________________________
# bn9b_branch2c (BatchNormalizati (None, 40, 40, 32)   128         conv9b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 40, 40, 32)   0           bn9b_branch2c[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 40, 40, 32)   0           add_7[0][0]
# __________________________________________________________________________________________________
# conv10b_branch2a (Conv2D)       (None, 40, 40, 192)  6336        activation_33[0][0]
# __________________________________________________________________________________________________
# bn10b_branch2a (BatchNormalizat (None, 40, 40, 192)  768         conv10b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 40, 40, 192)  0           bn10b_branch2a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 46, 46, 192)  0           activation_34[0][0]
# __________________________________________________________________________________________________
# conv10b_branch2b (DepthwiseConv (None, 46, 46, 192)  1920        zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# bn10b_branch2b (BatchNormalizat (None, 46, 46, 192)  768         conv10b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 46, 46, 192)  0           bn10b_branch2b[0][0]
# __________________________________________________________________________________________________
# conv10b_branch2c (Conv2D)       (None, 46, 46, 56)   10808       activation_35[0][0]
# __________________________________________________________________________________________________
# bn10b_branch2c (BatchNormalizat (None, 46, 46, 56)   224         conv10b_branch2c[0][0]
# __________________________________________________________________________________________________
# conv10c_branch2a (Conv2D)       (None, 46, 46, 336)  19152       bn10b_branch2c[0][0]
# __________________________________________________________________________________________________
# bn10c_branch2a (BatchNormalizat (None, 46, 46, 336)  1344        conv10c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 46, 46, 336)  0           bn10c_branch2a[0][0]
# __________________________________________________________________________________________________
# conv10c_branch2b (DepthwiseConv (None, 46, 46, 336)  3360        activation_36[0][0]
# __________________________________________________________________________________________________
# bn10c_branch2b (BatchNormalizat (None, 46, 46, 336)  1344        conv10c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 46, 46, 336)  0           bn10c_branch2b[0][0]
# __________________________________________________________________________________________________
# conv10c_branch2c (Conv2D)       (None, 46, 46, 56)   18872       activation_37[0][0]
# __________________________________________________________________________________________________
# bn10c_branch2c (BatchNormalizat (None, 46, 46, 56)   224         conv10c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 46, 46, 56)   0           bn10c_branch2c[0][0]
#                                                                  bn10b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 46, 46, 56)   0           add_8[0][0]
# __________________________________________________________________________________________________
# conv11b_branch2a (Conv2D)       (None, 46, 46, 336)  19152       activation_38[0][0]
# __________________________________________________________________________________________________
# bn11b_branch2a (BatchNormalizat (None, 46, 46, 336)  1344        conv11b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 46, 46, 336)  0           bn11b_branch2a[0][0]
# __________________________________________________________________________________________________
# conv11b_branch2b (DepthwiseConv (None, 46, 46, 336)  3360        activation_39[0][0]
# __________________________________________________________________________________________________
# bn11b_branch2b (BatchNormalizat (None, 46, 46, 336)  1344        conv11b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 46, 46, 336)  0           bn11b_branch2b[0][0]
# __________________________________________________________________________________________________
# conv11b_branch2c (Conv2D)       (None, 46, 46, 56)   18872       activation_40[0][0]
# __________________________________________________________________________________________________
# bn11b_branch2c (BatchNormalizat (None, 46, 46, 56)   224         conv11b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 46, 46, 56)   0           bn11b_branch2c[0][0]
#                                                                  activation_38[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 46, 46, 56)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv12b_branch2a (Conv2D)       (None, 46, 46, 336)  19152       activation_41[0][0]
# __________________________________________________________________________________________________
# bn12b_branch2a (BatchNormalizat (None, 46, 46, 336)  1344        conv12b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 46, 46, 336)  0           bn12b_branch2a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 52, 52, 336)  0           activation_42[0][0]
# __________________________________________________________________________________________________
# conv12b_branch2b (DepthwiseConv (None, 52, 52, 336)  3360        zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# bn12b_branch2b (BatchNormalizat (None, 52, 52, 336)  1344        conv12b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 52, 52, 336)  0           bn12b_branch2b[0][0]
# __________________________________________________________________________________________________
# conv12b_branch2c (Conv2D)       (None, 52, 52, 112)  37744       activation_43[0][0]
# __________________________________________________________________________________________________
# bn12b_branch2c (BatchNormalizat (None, 52, 52, 112)  448         conv12b_branch2c[0][0]
# __________________________________________________________________________________________________
# conv13 (Conv2D)                 (None, 25, 25, 1280) 1291520     bn12b_branch2c[0][0]
# __________________________________________________________________________________________________
# bn_conv13 (BatchNormalization)  (None, 25, 25, 1280) 5120        conv13[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 25, 25, 1280) 0           bn_conv13[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           activation_44[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 100)          128100      global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 1)            101         dense1[0][0]
# ==================================================================================================
# Total params: 1,698,881
# Trainable params: 1,684,785
# Non-trainable params: 14,096
# __________________________________________________________________________________________________

# %%
# Displaying all the layers in the model
for layer in model.layers:
    print(layer, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f0cd1712e90> True
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f0cd173bc50> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd030c390> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0c66610> True
# <keras.layers.core.Activation object at 0x7f0cd0cf45d0> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0c66950> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0cfc990> True
# <keras.layers.core.Activation object at 0x7f0cd0e6ad90> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd1bdc4d0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0e80810> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0e76f90> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0e0c4d0> True
# <keras.layers.core.Activation object at 0x7f0cd0e19190> True
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f0cd0e19bd0> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0e14cd0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0e24750> True
# <keras.layers.core.Activation object at 0x7f0cd0e29fd0> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0e20e10> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0e339d0> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0e3d690> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0e29750> True
# <keras.layers.core.Activation object at 0x7f0cd0e47090> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0dcccd0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0e368d0> True
# <keras.layers.core.Activation object at 0x7f0cd0dda350> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0de0ad0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0de27d0> True
# <keras.layers.merge.Add object at 0x7f0cd0e41f10> True
# <keras.layers.core.Activation object at 0x7f0cd1ba4f50> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0df2b10> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0defd90> True
# <keras.layers.core.Activation object at 0x7f0cd1baf390> True
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f0cd0dfba10> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0d49fd0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0e06690> True
# <keras.layers.core.Activation object at 0x7f0cd0e036d0> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0d564d0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0deff10> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0df2650> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0e33310> True
# <keras.layers.core.Activation object at 0x7f0cd0dcc190> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0e298d0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0e7a310> True
# <keras.layers.core.Activation object at 0x7f0cd0e0cad0> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0e704d0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0c668d0> True
# <keras.layers.merge.Add object at 0x7f0cd0c501d0> True
# <keras.layers.core.Activation object at 0x7f0cd0cfca90> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0d652d0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0d69890> True
# <keras.layers.core.Activation object at 0x7f0cd0d65550> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0d73410> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0d7ce10> True
# <keras.layers.core.Activation object at 0x7f0cd0d73990> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0d66f50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0d0f210> True
# <keras.layers.merge.Add object at 0x7f0cd0d0fb90> True
# <keras.layers.core.Activation object at 0x7f0cd0d0a950> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0d1aa10> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0d20bd0> True
# <keras.layers.core.Activation object at 0x7f0cd1bd2d50> True
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f0cd1bdc250> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0d30ad0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0d37f50> True
# <keras.layers.core.Activation object at 0x7f0cd0d13fd0> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0d3dd50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0d45fd0> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0c8cf10> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0c907d0> True
# <keras.layers.core.Activation object at 0x7f0cd0c9e150> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0c99cd0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0ca1750> True
# <keras.layers.core.Activation object at 0x7f0cd0cad3d0> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0caab10> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0caaf50> True
# <keras.layers.merge.Add object at 0x7f0cd0cc20d0> True
# <keras.layers.core.Activation object at 0x7f0cd0cb7390> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0c90310> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0cbdb90> True
# <keras.layers.core.Activation object at 0x7f0cd0d37d50> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0c9ee10> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0d20550> True
# <keras.layers.core.Activation object at 0x7f0cd0d7ce90> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0d83c10> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0e2ec90> True
# <keras.layers.merge.Add object at 0x7f0cd0e88790> True
# <keras.layers.core.Activation object at 0x7f0cd0e7acd0> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0cc6490> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0c0ca90> True
# <keras.layers.core.Activation object at 0x7f0cd0c10490> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0c10bd0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0c12f50> True
# <keras.layers.core.Activation object at 0x7f0cd0c18050> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0c1b350> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0c25b10> True
# <keras.layers.merge.Add object at 0x7f0cd0c352d0> True
# <keras.layers.core.Activation object at 0x7f0cd0c35890> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0c37050> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0c40a50> True
# <keras.layers.core.Activation object at 0x7f0cd0c47450> True
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f0cd0c40150> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0bcda90> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0bd2f90> True
# <keras.layers.core.Activation object at 0x7f0cd0bd9490> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0bd2e50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0be5250> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0bebfd0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0be57d0> True
# <keras.layers.core.Activation object at 0x7f0cd0bf80d0> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0bfd710> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0bf1650> True
# <keras.layers.core.Activation object at 0x7f0cd0c08390> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0070290> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0075150> True
# <keras.layers.merge.Add object at 0x7f0cd0bfe5d0> True
# <keras.layers.core.Activation object at 0x7f0cd0c08a50> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0088350> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd007e8d0> True
# <keras.layers.core.Activation object at 0x7f0cd007d6d0> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd0beec50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0c444d0> True
# <keras.layers.core.Activation object at 0x7f0cd0070ad0> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0c2ca10> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0c1bc90> True
# <keras.layers.merge.Add object at 0x7f0cd0c2cc50> True
# <keras.layers.core.Activation object at 0x7f0cd0c18850> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0088e90> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0d69cd0> True
# <keras.layers.core.Activation object at 0x7f0cd0e6aa10> True
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f0cd0c37e50> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd008dcd0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0d373d0> True
# <keras.layers.core.Activation object at 0x7f0cd0c90b50> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0094510> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0096410> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0e88650> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd00a2990> True
# <keras.layers.core.Activation object at 0x7f0cd002e5d0> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cd002cd50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0034c50> True
# <keras.layers.core.Activation object at 0x7f0cd00415d0> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0034d90> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0049810> True
# <keras.layers.merge.Add object at 0x7f0cd0056190> True
# <keras.layers.core.Activation object at 0x7f0cd0050810> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0095e50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0064710> True
# <keras.layers.core.Activation object at 0x7f0cc849a090> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cc849ab50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cc84a0b90> True
# <keras.layers.core.Activation object at 0x7f0cc84af610> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cc84afed0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cc84a2710> True
# <keras.layers.merge.Add object at 0x7f0cc84b7a10> True
# <keras.layers.core.Activation object at 0x7f0cc84bdd10> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd00412d0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cc84cc610> True
# <keras.layers.core.Activation object at 0x7f0cc8457050> True
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f0cc8457ad0> True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f0cc84bffd0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cc84a20d0> True
# <keras.layers.core.Activation object at 0x7f0cd0e76690> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0c4a490> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0df2350> True
# <keras.layers.convolutional.Conv2D object at 0x7f0cd0de2f50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0cd0d0fad0> True
# <keras.layers.core.Activation object at 0x7f0cd0bfe4d0> True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f0cd0c0e7d0> True
# <keras.layers.core.Dense object at 0x7f0cd005b390> True
# <keras.layers.core.Dense object at 0x7f0cd005b710> True

# %%
epochs=3

# %%
image_size = (224, 224)
batch_size = 32
rand_seed = 42
val_split = 0.2

# %%
#class_names=['cat', 'dog'] -- Can be diiferent depending on given dataset
class_names=['cat','dog']

# %%
# Training dataset
train_ds = image_dataset_from_directory(
    directory=train_path, 
    class_names=class_names,
    batch_size=batch_size,
    image_size=image_size,
    seed=rand_seed, 
    validation_split=val_split,
    subset='training'
)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.

# %%
# Compiling the model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
# Validation dataset
val_ds = image_dataset_from_directory(
    directory=train_path,
    class_names=class_names,
    batch_size=batch_size,
    image_size=image_size,
    seed=rand_seed,
    validation_split=val_split,
    subset='validation'
)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.

# %%
# Fitting the model
hist=model.fit(train_ds,epochs=epochs,validation_data=val_ds)
# Out:
# Epoch 1/3
# 2022-04-04 03:13:25.113187: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-04-04 03:13:27.593325: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
#
# 625/625 [==============================] - 195s 287ms/step - loss: 0.5503 - accuracy: 0.5981 - val_loss: 0.9054 - val_accuracy: 0.6076
# Epoch 2/3
# 625/625 [==============================] - 177s 283ms/step - loss: 0.4533 - accuracy: 0.7981 - val_loss: 0.6145 - val_accuracy: 0.8045
# Epoch 3/3
# 625/625 [==============================] - 179s 285ms/step - loss: 0.2321 - accuracy: 0.9281 - val_loss: 0.4242 - val_accuracy: 0.9314
