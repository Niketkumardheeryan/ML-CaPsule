# %% [markdown]
# # Copy The Image Dataset of Tomato Leaf

# %%
# !git clone "https://github.com/srajan-kiyotaka/CrowdAI-Plant-Disease-Prediction.git"
# Out:
# Cloning into 'CrowdAI-Plant-Disease-Prediction'...
# remote: Enumerating objects: 18002, done.
# remote: Counting objects: 100% (18002/18002), done.
# remote: Compressing objects: 100% (17987/17987), done.
# remote: Total 18002 (delta 10), reused 17998 (delta 10), pack-reused 0
# Receiving objects: 100% (18002/18002), 66.27 MiB | 27.32 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# Checking out files: 100% (17972/17972), done.

# %% [markdown]
# # Store The Images and The Corresponding Lables in The List

# %% [markdown]
# ## ***Tomato Leaf Image having Bacterial spot***

# %%
# import opencv
import cv2

# store list
images = []
lables = []

## Tomato Leaf Image having Bacterial spot with PreProcessing of the Image ##
for i in range(1, 2115):
    img = cv2.imread(f"/content/CrowdAI-Plant-Disease-Prediction/Tomato/Dataset/Tomato___Bacterial_spot/Bacterial_spot ({i}).JPG")
    # gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    gray = img/255
    gray = cv2.resize(gray,(50, 50))
    images.append(gray)
    lables.append(0)  # Bacterial spot

# %%
# Sample Images

import matplotlib.pyplot as plt

plt.figure(figsize = (14,14))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(images[100 + i**2])
plt.show()

# %% [markdown]
# ## **Tomato Leaf Image having Early blight**

# %%
## Tomato Leaf Image having Early blight with PreProcessing of the Image ##
for i in range(1, 989):
    img = cv2.imread(f"/content/CrowdAI-Plant-Disease-Prediction/Tomato/Dataset/Tomato___Early_blight/Early_blight ({i}).JPG")
    # gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    gray = img/255
    gray = cv2.resize(gray,(50, 50))
    images.append(gray)
    lables.append(1)  # Early blight

# %%
# Sample Images
plt.figure(figsize = (14,14))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(images[2500 + i*3])
plt.show()

# %% [markdown]
# ## **Tomato Leaf Image having Late blight**

# %%
## Tomato Leaf Image having Late blight with PreProcessing of the Image ##

for i in range(1, 1887):
    try :                
        img = cv2.imread(f"/content/CrowdAI-Plant-Disease-Prediction/Tomato/Dataset/Tomato___Late_blight/Late_blight ({i}).JPG")
        # gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        gray = img/255
    except :
        img = cv2.imread(f"/content/CrowdAI-Plant-Disease-Prediction/Tomato/Dataset/Tomato___Late_blight/Late_blight ({i}).jpg")
        # gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        gray = img/255 
    
    gray = cv2.resize(gray,(50, 50))
    images.append(gray)
    lables.append(2)    # Late blight

# %%
# Sample Images

plt.figure(figsize = (15,15))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(images[3600 + i*3])
plt.show()

# %% [markdown]
# ## ***Tomato Leaf Image having Leaf Mold***

# %%
## Tomato Leaf Image having Leaf Mold with PreProcessing of the Image ##

for i in range(1, 933):
    img = cv2.imread(f"/content/CrowdAI-Plant-Disease-Prediction/Tomato/Dataset/Tomato___Leaf_Mold/Leaf_Mold ({i}).JPG")
    # gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    gray = img/255
    gray = cv2.resize(gray,(50, 50))
    images.append(gray)
    lables.append(3)   # Leaf Mold

# %%
# Sample Images

plt.figure(figsize = (15,15))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(images[5000 + i*3])
plt.show()

# %% [markdown]
# ## ***Tomato Leaf Image having Septoria leaf spot***

# %%
## Tomato Leaf Image having Septoria leaf spot with PreProcessing of the Image ##
for i in range(1, 1752):
    img = cv2.imread(f"/content/CrowdAI-Plant-Disease-Prediction/Tomato/Dataset/Tomato___Septoria_leaf_spot/Septoria_leaf_spot ({i}).JPG")
    # gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    gray = img/255
    gray = cv2.resize(gray,(50, 50))
    images.append(gray)
    lables.append(4)  # Septoria leaf spot

# %%
# Sample Images
plt.figure(figsize = (14,14))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(images[6000 + i*3])
plt.show()

# %% [markdown]
# ## ***Tomato Leaf Image having Spider mites Two spotted spider mite***

# %%
## Tomato Leaf Image having Spider mites Two spotted spider mite with PreProcessing of the Image ##
for i in range(1, 1657):
    img = cv2.imread(f"/content/CrowdAI-Plant-Disease-Prediction/Tomato/Dataset/Tomato___Spider_mites Two-spotted_spider_mite/Spider_mites Two-spotted_spider_mite ({i}).JPG")
    # gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    gray = img/255
    gray = cv2.resize(gray,(50, 50))
    images.append(gray)
    lables.append(5)  # Spider mites Two spotted spider mite

# %%
# Sample Images
plt.figure(figsize = (14,14))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(images[8000 + i*3])
plt.show()

# %% [markdown]
# ## **Tomato Leaf Image having Target Spot**

# %%
## Tomato Leaf Image having Target Spot with PreProcessing of the Image ##
for i in range(1, 1385):
    img = cv2.imread(f"/content/CrowdAI-Plant-Disease-Prediction/Tomato/Dataset/Tomato___Target_Spot/Target_Spot ({i}).JPG")
    # gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    gray = img/255
    gray = cv2.resize(gray,(50, 50))
    images.append(gray)
    lables.append(6)  # Target Spot

# %%
# Sample Images
plt.figure(figsize = (14,14))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(images[1000 + i*3])
plt.show()

# %% [markdown]
# ## **Tomato Leaf Image having Tomato Yellow Leaf Curl Virus**

# %%
## Tomato Leaf Image having Tomato Yellow Leaf Curl Virus with PreProcessing of the Image ##
for i in range(1, 5338):
    img = cv2.imread(f"/content/CrowdAI-Plant-Disease-Prediction/Tomato/Dataset/Tomato___Tomato_Yellow_Leaf_Curl_Virus/Tomato_Yellow_Leaf_Curl_Virus ({i}).JPG")
    # gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    gray = img/255
    gray = cv2.resize(gray,(50, 50))
    images.append(gray)
    lables.append(7)  # Tomato Yellow Leaf Curl Virus

# %%
# Sample Images
plt.figure(figsize = (14,14))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(images[1200 + i*3])
plt.show()

# %% [markdown]
# ## ***Healthy Tomato Leaf***

# %%
## Healthy Tomato Leaf Image with PreProcessing of the Image ##

for i in range(1, 1571):
    try:
        img = cv2.imread(f"/content/CrowdAI-Plant-Disease-Prediction/Tomato/Dataset/Tomato___healthy/healthy ({i}).JPG")
        # gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        gray = img/255
    except:
        img = cv2.imread(f"/content/CrowdAI-Plant-Disease-Prediction/Tomato/Dataset/Tomato___healthy/healthy ({i}).jpg")
        # gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        gray = img/255
    
    gray = cv2.resize(gray,(50, 50))
    images.append(gray)
    lables.append(8)  # healthy

# %%
# Sample Images
plt.figure(figsize = (14,14))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(images[16100 + i*3])
plt.show()

# %%
# Shape of the Images

print(f"Shape of each image is = {images[0].shape}")
# Out:
# Shape of each image is = (50, 50, 3)

# %%
# Convert The List into Array Format  #

import numpy as np

train_feature = np.array(images)
lables = np.array(lables)

# %%
## Display Array Shape ##

print(f"image dataset shape = {train_feature.shape}")

print(f"lable dataset shape = {lables.shape}")
# Out:
# image dataset shape = (17618, 50, 50, 3)
# lable dataset shape = (17618,)

# %% [markdown]
# ## Split The Dataset into Test and Train

# %%
from sklearn.model_selection import train_test_split

train_features, test_features, train_target, test_target = train_test_split(train_feature,lables,test_size=0.1)

print(f"train_features shape = {train_features.shape}")

print(f"test_features shape = {test_features.shape}")

print(f"train_target shape = {train_target.shape}")

print(f"test_target shape = {test_target.shape}")
# Out:
# train_features shape = (15856, 50, 50, 3)
# test_features shape = (1762, 50, 50, 3)
# train_target shape = (15856,)
# test_target shape = (1762,)

# %%
import tensorflow
from tensorflow.keras.utils import to_categorical

# ONE NOT ENCODING

train_target = to_categorical(train_target)
test_target = to_categorical(test_target)

# %% [markdown]
# ## Deep Learning CNN Model

# %%
# MODEL ARCHITECTURE

import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout

# import BatchNormalization
from tensorflow.keras.layers import BatchNormalization

# MODEL LAYERS

model=Sequential()
# Convolutional Layers
model.add(Conv2D(200, kernel_size = (2,2), strides = (1,1), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(pool_size = (2,2)))
# model.add(BatchNormalization())

model.add(Conv2D(150, kernel_size = (2,2), strides = (1,1), padding = 'same', activation = 'relu'))
# model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(100, kernel_size = (2,2), strides = (1,1), padding = 'same', activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
# # model.add(BatchNormalization())

model.add(Conv2D(50, kernel_size = (2,2), strides = (1,1), padding = 'same', activation = 'relu'))
# model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Flatten())
# model.add(Dense(750,activation='relu'))
# model.add(BatchNormalization())
model.add(Dense(400,activation='relu'))
# model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(300,activation='relu'))
model.add(BatchNormalization())
model.add(Dense(200,activation='relu'))
model.add(BatchNormalization())
# model.add(Dropout(0.25))
model.add(Dense(100,activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.25))
model.add(Dense(9,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 50, 50, 200)       2600
#
#  max_pooling2d (MaxPooling2D  (None, 25, 25, 200)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 150)       120150
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 100)       60100
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 100)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 50)        20050
#
#  flatten (Flatten)           (None, 7200)              0
#
#  dense (Dense)               (None, 400)               2880400
#
#  dropout (Dropout)           (None, 400)               0
#
#  dense_1 (Dense)             (None, 300)               120300
#
#  batch_normalization (BatchN  (None, 300)              1200
#  ormalization)
#
#  dense_2 (Dense)             (None, 200)               60200
#
# ...

# %%
# # MODEL COPILE

# from tensorflow.keras.optimizers import Adam

# model.compile(Adam(learning_rate = 0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.optimizers import SGD

opt = SGD(lr=0.003)

model.compile(loss = "categorical_crossentropy", optimizer = opt, metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
# MODEL FITTING

model.fit(train_features, train_target, validation_data = (test_features, test_target), epochs = 300)
# Out:
# Epoch 1/300
# 496/496 [==============================] - 33s 46ms/step - loss: 1.5260 - accuracy: 0.4783 - val_loss: 1.3467 - val_accuracy: 0.6044
# Epoch 2/300
# 496/496 [==============================] - 22s 45ms/step - loss: 0.8992 - accuracy: 0.7007 - val_loss: 0.7198 - val_accuracy: 0.7622
# Epoch 3/300
# 496/496 [==============================] - 22s 45ms/step - loss: 0.6840 - accuracy: 0.7721 - val_loss: 2.4249 - val_accuracy: 0.4784
# Epoch 4/300
# 496/496 [==============================] - 22s 44ms/step - loss: 0.5668 - accuracy: 0.8072 - val_loss: 0.8040 - val_accuracy: 0.7196
# Epoch 5/300
# 496/496 [==============================] - 22s 44ms/step - loss: 0.4809 - accuracy: 0.8375 - val_loss: 3.9434 - val_accuracy: 0.2781
# Epoch 6/300
# 496/496 [==============================] - 22s 45ms/step - loss: 0.4226 - accuracy: 0.8557 - val_loss: 1.6651 - val_accuracy: 0.6073
# Epoch 7/300
# ...
