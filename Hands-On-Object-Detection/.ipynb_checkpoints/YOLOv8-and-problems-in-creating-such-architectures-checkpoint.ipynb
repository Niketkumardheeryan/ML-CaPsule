# %% [markdown]
# #### **What can we do to improvise the previous architecture?**

# %% [markdown]
# The previous architecture we designed can track only upto one object in an image what if we had more than one object?
#
# The primary limitation of a standard global regression architecture is its inability to detect multiple objects simultaneously, as it is mathematically constrained to output a single set of coordinates per image.
#
# To resolve this, we can discretize the input image into a localized grid of smaller, uniform sub-regions (or 'cells'). By shifting the network's objective from a single global prediction to multiple localized predictions, each individual cell becomes responsible for detecting at most one object whose center falls within its boundaries. If a sub-region contains no object, it is simply classified as background. This grid-based approach effectively transforms a complex, multi-object detection task into parallel, single-object regression problems.

# %% [markdown]
# <img src = "https://hvp.44e.myftpupload.com/wp-content/uploads/2026/01/image-34-1024x687.jpeg">

# %% [markdown]
# #### **How do we create Grid Division?**

# %% [markdown]
# ### How Convolutional Layers Enable Multi-Object Detection
#
# Using a Convolutional Neural Network (CNN) for object detection allows us to predict a specific number of variables per grid cell. The total number of predicted variables equals:
#
# $$\text{Total Variables} = 1 \text{ (Object Confidence)} + 4 \text{ (Bounding Box Coordinates)} + N \text{ (Number of Classes)}$$
#
# According to your configuration file, the dataset has exactly $N = 6$ classes (`nc: 6`). Substituting this into the formula gives:
#
# $$\text{Total Variables} = 1 + 4 + 6 = 11$$
#
# Instead of predicting one global set of coordinates for the entire image, the convolutional backbone processes the image while maintaining spatial conservation, effectively treating the output as a grid of smaller localized regions. This allows us to construct an output tensor of shape:
#
# $$\mathbf{(S, S, 11)}$$
#
# In this architecture, the channels inside each individual $(x, y)$ grid cell represent the object's presence, its local bounding coordinates, its dimensions, and its specific classification probabilities.
#
# ---
#
# ### Channel Mapping Example
#
# For your model trained to detect these 6 specific classes, the channel breakdown for every single cell in the $S \times S$ grid maps out exactly like this:
#
# * **Channel 0 $\to$ Object Confidence:** The probability that an object's center falls inside this specific grid cell (bounded between 0.0 and 1.0).
# * **Channel 1 $\to$ Box Center X ($x_c$):** The horizontal center of the bounding box, calculated relative to the boundaries of the current cell.
# * **Channel 2 $\to$ Box Center Y ($y_c$):** The vertical center of the bounding box, calculated relative to the boundaries of the current cell.
# * **Channel 3 $\to$ Box Width ($w$):** The total width of the bounding box, scaled relative to the dimensions of the entire image.
# * **Channel 4 $\to$ Box Height ($h$):** The total height of the bounding box, scaled relative to the dimensions of the entire image.
# * **Channel 5 $\to$ Probability:** pistol
# * **Channel 6 $\to$ Probability:** smartphone
# * **Channel 7 $\to$ Probability:** knife
# * **Channel 8 $\to$ Probability:** monedero (purse/wallet)
# * **Channel 9 $\to$ Probability:** billete (banknote/bill)
# * **Channel 10 $\to$ Probability:** tarjeta (card)
#
# ---
#
# ### Spatial Overlap Resolution
#
# By organizing the channels this way, the final $1 \times 1$ convolutional layer acts as an array of parallel detectors. If a person is holding a **smartphone** in their hand (activating a grid cell in the center) while a **tarjeta** is sitting on a table in the bottom-right corner, the corresponding spatial cells will activate and output their respective coordinates and probabilities simultaneously without interfering with one another.

# %% [markdown]
# #### **NOTE : Convolutional layer preserve spactial data**
#
# So the above method is similar to creating grids

# %% [markdown]
# #### **You must have noted that we predict box center why do we do that?**

# %% [markdown]
# We have different objects in our image but image a grid cell that has 50% of class 0 and 50% of class 1 what will the grid cell be forced to predict? Also note that we predict Box width and Box Height relative to the size of image so forcing a grid cell to predict center is more practical then forcing indivisual cells to predict indivisually

# %% [markdown]
# Um! We are close to learn how we use YOLO models now

# %% [markdown]
# The box width and height are predicted using sigmoid .. listening to the word sigmoid you must have noted that this can cause vansishing gradients problem because the $$ \text{derivative of sigmoid(x)} = \text{sigmoid(x)(1 - sigmoid(x))}$$ The maximum of this function can be 0.25. So this causes the vanishing gradient problem in the architecture.

# %% [markdown]
# #### **ANCHOR BOXES**

# %% [markdown]
# **Anchor Boxes (Handling Scale Diversity)**
#
# If a single cell is responsible for a giant object, how does it know how to calculate those massive shapes cleanly without its gradients exploding or vanishing? It uses Anchor Boxes (or prior boxes).
#
# Instead of making the network guess box dimensions completely from scratch, engineers look at the training dataset beforehand and calculate the most common object shapes (e.g., small square boxes for finger fractures, tall skinny boxes for forearm fractures, and giant wide boxes for shoulders).
#
# Every grid cell is given a set of these pre-defined shapes as templates:
# - **Anchor 1:** Small Square (Fingers)
# - **Anchor 2:** Medium Vertical Rectangle (Forearm)
# - **Anchor 3:** Large Horizontal Rectangle (Shoulder/Humerus)
#
# Instead of predicting raw sizes, the cell simply predicts a scaling factor to tweak the closest-matching anchor template:
#
# $$ \text{Final Width} = \text{Anchor Width} \times e^{\text{predicted scale}} $$
#
# If a massive object is present, the cell naturally selects its largest anchor template and scales it up slightly, allowing it to easily capture objects much larger than the cell itself.

# %% [markdown]
# ### Non-Maximum Suppression (NMS)
#
# Because large objects cover so much territory, a side effect occurs: multiple adjacent grid cells might get confused and all attempt to predict a bounding box for the same giant object. To clean up this mess, **Non-Maximum Suppression (NMS)** filters the final outputs at the very end of the pipeline.
#
#
#
# NMS operates through the following algorithmic steps:
#
# 1. **Identify the Highest Confidence Box:** It reviews all predicted boxes across the entire grid and selects the one with the absolute highest **Object Confidence** score.
# 2. **Measure the Overlap (IoU):** It calculates how much the other neighboring boxes overlap with this top-performing box using a metric called **Intersection over Union (IoU)**:
#
# $$\text{IoU} = \frac{\text{Area of Intersection}}{\text{Area of Union}}$$
#
# 3. **Suppress the Duplicates:** If a nearby box overlaps with the best box by more than a pre-defined threshold (e.g., more than $50\%$ overlap), NMS assumes they are targeting the same object and aggressively deletes the weaker box.
# 4. **Repeat:** This loop repeats for the remaining boxes until no overlapping duplicates are left.
#
# This process eliminates the clutter, leaving you with exactly one clean, perfectly fitted bounding box around the massive fracture.

# %% [markdown]
# Now lets see how to build these models simply

# %%
# Import required modules

import os

from ultralytics import YOLO
from IPython.display import Image , display

os.environ["OPENCV_FFMPEG_CAPTURE_OPTIONS"] = "video_codec;h264"

# %%
model = YOLO("yolov8n.pt")

# %%
results = model.train(
    data = "./weapon-detection/data.yaml",
    epochs = 50,
    workers = 4,
    batch = 4,
    imgsz = 448,
    lr0 = 0.001,
    lrf = 0.5,
    cos_lr = False,
    val = False
)

#note that I am passing this argument because ultralytics defaults these to 640px but for suppose
#you have an image of size 1280 and the default argument this image is compressed automatically to 640px which can cause the
#loss of spacial information to your model similar for an image of smaller dimension

# This train train follows linear decay with initial lr to be 0.001 and final to be 0.0005
# Out:
# Ultralytics 8.4.60 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 5806MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=
2        448: 100% ━━━━━━━━━━━━ 1251/1251 33.3it/s 37.6s<0.0s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50     0.334G     0.6894     0.5153     0.9671          2        448: 100% ━━━━━━━━━━━━ 1251/1251 33.1it/s 37.8s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 57/57 30.9it/s 1.8s0.1s
#                    all        450        450      0.795      0.805      0.851       0.64
#
# 50 epochs completed in 0.544 hours.
# Optimizer stripped from /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/runs/detect/train-2/weights/last.pt, 6.2MB
# Optimizer stripped from /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/runs/detect/train-2/weights/best.pt, 6.2MB
#
# Validating /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/runs/detect/train-2/weights/best.pt...
# Ultralytics 8.4.60 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 5806MiB)
# Model summary (fused): 73 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 57/57 46.5it/s 1.2s0.1s
#                    all        450        450      0.793      0.805      0.851       0.64
#                 pistol         50         50      0.712       0.96      0.925      0.642
#             smartphone         58         58      0.973      0.629      0.863      0.687
#                  knife        241        241      0.901      0.947      0.975      0.629
#               monedero         38         38       0.62      0.737      0.756      0.588
#                billete         28         28      0.887      0.929      0.921      0.787
#                tarjeta         35         35      0.667      0.629      0.667      0.506
# Speed: 0.1ms preprocess, 0.9ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/runs/detect/train-2

# %%
# results is a python object that has valuable information about training.

# to open up any objects documentation we can use help(object)

help(results)
# Out:
# Help on DetMetrics in module ultralytics.utils.metrics object:
#
# class DetMetrics(ultralytics.utils.SimpleClass, ultralytics.utils.DataExportMixin)
#  |  DetMetrics(names: 'dict[int, str]' = {}) -> 'None'
#  |
#  |  Utility class for computing detection metrics such as precision, recall, and mean average precision (mAP).
#  |
#  |  Attributes:
#  |      names (dict[int, str]): A dictionary of class names.
#  |      box (Metric): An instance of the Metric class for storing detection results.
#  |      speed (dict[str, float]): A dictionary for storing execution times of different parts of the detection process.
#  |      stats (dict[str, list]): A dictionary containing lists for true positives, confidence scores, predicted classes,
#  |          target classes, and target images.
#  |      nt_per_class: Number of targets per class.
#  |      nt_per_image: Number of targets per image.
#  |
#  |  Methods:
#  |      update_stats: Update statistics by appending new values to existing stat collections.
#  |      process: Process predicted results for object detection and update metrics.
#  |      clear_stats: Clear the stored statistics.
#  |      keys: Return a list of keys for accessing specific metrics.
#  |      mean_results: Calculate mean of detected objects & return precision, recall, mAP50, and mAP50-95.
#  |      class_result: Return the result of evaluating the performance of an object detection model on a specific class.
#  |      maps: Return mean Average Precision (mAP) scores per class.
#  |      fitness: Return the fitness of box object.
#  |      ap_class_index: Return the average precision index per class.
#  |      results_dict: Return dictionary of computed performance metrics and statistics.
#  |      curves: Return a list of curves for accessing specific metrics curves.
#  |      curves_results: Return a list of computed performance metrics and statistics.
#  |      summary: Generate a summarized representation of per-class detection metrics as a list of dictionaries.
#  |
#  |  Method resolution order:
#  |      DetMetrics
#  |      ultralytics.utils.SimpleClass
#  |      ultralytics.utils.DataExportMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, names: 'dict[int, str]' = {}) -> 'None'
#  |      Initialize a DetMetrics instance with class names.
#  |
#  |      Args:
#  |          names (dict[int, str], optional): Dictionary of class names.
#  |
#  |  class_result(self, i: 'int') -> 'tuple[float, float, float, float]'
#  |      Return the result of evaluating the performance of an object detection model on a specific class.
#  |
#  |  clear_image_metrics(self) -> 'None'
#  |      Clear stored per-image metrics.
#  |
#  |  clear_stats(self)
#  |      Clear the stored statistics.
#  |
#  |  mean_results(self) -> 'list[float]'
#  |      Calculate mean of detected objects & return precision, recall, mAP50, and mAP50-95.
#  |
#  |  process(self, save_dir: 'Path' = PosixPath('.'), plot: 'bool' = False, on_plot=None) -> 'dict[str, np.ndarray]'
#  |      Process predicted results for object detection and update metrics.
#  |
#  |      Args:
#  |          save_dir (Path): Directory to save plots. Defaults to Path(".").
#  |          plot (bool): Whether to plot precision-recall curves. Defaults to False.
#  |          on_plot (callable, optional): Function to call after plots are generated. Defaults to None.
#  |
#  |      Returns:
#  |          (dict[str, np.ndarray]): Dictionary containing concatenated statistics arrays.
#  |
#  |  summary(self, normalize: 'bool' = True, decimals: 'int' = 5) -> 'list[dict[str, Any]]'
#  |      Generate a summarized representation of per-class detection metrics as a list of dictionaries. Includes
#  |      shared scalar metrics (mAP, mAP50, mAP75) alongside precision, recall, and F1-score for each class.
#  |
#  |      Args:
#  |          normalize (bool): For Detect metrics, everything is normalized by default [0-1].
#  |          decimals (int): Number of decimal places to round the metrics values to.
#  |
#  |      Returns:
#  |          (list[dict[str, Any]]): A list of dictionaries, each representing one class with corresponding metric
#  |              values.
#  |
#  |      Examples:
#  |         >>> results = model.val(data="coco8.yaml")
#  |         >>> detection_summary = results.summary()
#  |         >>> print(detection_summary)
#  |
#  |  update_stats(self, stat: 'dict[str, Any]') -> 'None'
#  |      Update statistics by appending new values to existing stat collections.
#  |
#  |      Args:
#  |          stat (dict[str, Any]): Dictionary containing new statistical values to append. Keys should match existing
#  |              keys in self.stats.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  ap_class_index
#  |      Return the average precision index per class.
#  |
#  |  curves
#  |      Return a list of curves for accessing specific metrics curves.
#  |
#  |  curves_results
#  |      Return a list of computed performance metrics and statistics.
#  |
#  |  fitness
#  |      Return the fitness of box object.
#  |
#  |  keys
#  |      Return a list of keys for accessing specific metrics.
#  |
#  |  maps
#  |      Return mean Average Precision (mAP) scores per class.
#  |
#  |  results_dict
#  |      Return dictionary of computed performance metrics and statistics.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ultralytics.utils.SimpleClass:
#  |
#  |  __getattr__(self, attr)
#  |      Provide a custom attribute access error message with helpful information.
#  |
#  |  __repr__(self)
#  |      Return a machine-readable string representation of the object.
#  |
#  |  __str__(self)
#  |      Return a human-readable string representation of the object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ultralytics.utils.SimpleClass:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ultralytics.utils.DataExportMixin:
#  |
#  |  to_csv(self, normalize=False, decimals=5)
#  |      Export results or metrics to CSV string format.
#  |
#  |      Args:
#  |          normalize (bool, optional): Normalize numeric values.
#  |          decimals (int, optional): Decimal precision.
#  |
#  |      Returns:
#  |          (str): CSV content as string.
#  |
#  |  to_df(self, normalize=False, decimals=5)
#  |      Create a Polars DataFrame from the prediction results summary or validation metrics.
#  |
#  |      Args:
#  |          normalize (bool, optional): Normalize numerical values for easier comparison.
#  |          decimals (int, optional): Decimal places to round floats.
#  |
#  |      Returns:
#  |          (polars.DataFrame): Polars DataFrame containing the summary data.
#  |
#  |  to_json(self, normalize=False, decimals=5)
#  |      Export results to JSON format.
#  |
#  |      Args:
#  |          normalize (bool, optional): Normalize numeric values.
#  |          decimals (int, optional): Decimal precision.
#  |
#  |      Returns:
#  |          (str): JSON-formatted string of the results.

# %% [markdown]
# One important parameter in object detection is confidence
#
# A lower confidence can lead to more false positives
# A higher confidence can lead to more false negatives
#
# **NOTE:** Selecting a good confidence score is similar to maximising F1 score wrt to confidence
#
# simply,
# $$c_{best} = \arg\max_{c} \text{F1}(c)$$
# $$\text{Where c is confidence}$$

# %%
# these are the that we can check to figure out the above problem
results.curves
# Out:
# ['Precision-Recall(B)',
#  'F1-Confidence(B)',
#  'Precision-Confidence(B)',
#  'Recall-Confidence(B)']

# %%
# to access these plots you can check in runs/detect/{respected training run} in this case train run is train - 2

# %%
os.listdir("./runs/detect/train-2/")
# Out:
# ['BoxR_curve.png',
#  'confusion_matrix_normalized.png',
#  'confusion_matrix.png',
#  'val_batch2_pred.jpg',
#  'train_batch2.jpg',
#  'val_batch2_labels.jpg',
#  'val_batch0_labels.jpg',
#  'weights',
#  'train_batch50041.jpg',
#  'results.png',
#  'val_batch1_pred.jpg',
#  'results.csv',
#  'val_batch0_pred.jpg',
#  'train_batch0.jpg',
#  'BoxP_curve.png',
#  'train_batch50042.jpg',
#  'labels.jpg',
#  'args.yaml',
#  'BoxF1_curve.png',
#  'train_batch1.jpg',
#  'train_batch50040.jpg',
#  'BoxPR_curve.png',
#  'val_batch1_labels.jpg']

# %%
#lets check the f1 plot vs confidence

display(Image(filename = "./runs/detect/train-2/BoxF1_curve.png"))

# %% [markdown]
# The most suitable curve is given by the dark blue line
#
# For a task like this you might need a confidence threshold slighly lower because more false negatives are better than false positives

# %%
# An example prediction can be seen in such images "val_batch0_pred.jpg"

display(Image(filename = "./runs/detect/train-2/val_batch0_pred.jpg"))

# %%
# To predict upon new image ,folder,video

results = model.predict(source = "./weapon-detection/test/images" , save = True )
# Out:
# image 1/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/ABbframe00145.jpg: 256x448 1 knife, 127.1ms
# image 2/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/ABbframe00289.jpg: 256x448 1 knife, 2.3ms
# image 3/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/ABbframe00322.jpg: 256x448 1 knife, 2.4ms
# image 4/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/ABbframe00325.jpg: 256x448 1 knife, 3.0ms
# image 5/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/ABbframe00331.jpg: 256x448 1 knife, 2.9ms
# image 6/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/ABmframe00154.jpg: 256x448 1 knife, 2.7ms
# image 7/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/ABmframe00262.jpg: 256x448 1 knife, 2.5ms
# image 8/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/ABmframe00280.jpg: 256x448 1 knife, 2.5ms
# image 9/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DSC_00021.jpg: 320x448 1 knife, 127.6ms
# image 10/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DSC_0010.jpg: 320x448 1 pistol, 1 knife, 1 monedero, 2.4ms
# image 11/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DSC_00131.jpg: 320x448 (no detections), 2.4ms
# image 12/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DSC_0069.jpg: 320x448 2 knifes, 2.5ms
# image 13/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseAndSurvive14.jpg: 256x448 1 knife, 2.8ms
# image 14/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseKnifeAttack0103.jpg: 256x448 1 knife, 2.5ms
# image 15/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseKnifeAttack0155.jpg: 256x448 1 knife, 2.4ms
# image 16/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseKnifeAttack0163.jpg: 256x448 1 knife, 2.6ms
# image 17/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseKnifeAttack0168.jpg: 256x448 1 knife, 3.5ms
# image 18/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseKnifeAttack0169.jpg: 256x448 1 knife, 2.2ms
# image 19/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseKnifeAttack0172.jpg: 256x448 1 knife, 2.1ms
# image 20/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseKnifeAttack0183.jpg: 256x448 1 knife, 2.5ms
# image 21/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseKnifeAttack0184.jpg: 256x448 1 knife, 2.6ms
# image 22/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseKnifeAttack0218.jpg: 256x448 1 knife, 2.3ms
# image 23/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseKnifeAttack0315.jpg: 256x448 1 knife, 2.2ms
# image 24/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseKnifeAttack0320.jpg: 256x448 1 knife, 2.0ms
# image 25/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/DefenseKnifeAttack
407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/MBmframe00130.jpg: 256x448 1 knife, 2.7ms
# image 74/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/MBmframe00211.jpg: 256x448 1 knife, 2.4ms
# image 75/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/MBmframe00241.jpg: 256x448 1 knife, 2.6ms
# image 76/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/RealityKnifeAttacks0651.jpg: 256x448 1 knife, 2.5ms
# image 77/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/RusoClases005.jpg: 256x448 1 knife, 2.5ms
# image 78/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/RusoClases262.jpg: 256x448 1 knife, 2.5ms
# image 79/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_0102.jpg: 448x352 2 billetes, 121.9ms
# image 80/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_0104.jpg: 320x448 1 billete, 2.9ms
# image 81/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_0106.jpg: 352x448 1 billete, 119.4ms
# image 82/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_0113.jpg: 352x448 1 billete, 2.6ms
# image 83/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_0142.jpg: 256x448 1 smartphone, 1 billete, 2.8ms
# image 84/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_0149.jpg: 256x448 1 smartphone, 2 billetes, 2.4ms
# image 85/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_0151.JPG: 320x448 1 billete, 2.6ms
# image 86/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_0154.JPG: 320x448 1 monedero, 2.5ms
# image 87/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_0156.JPG: 320x448 2 monederos, 2 billetes, 2.6ms
# image 88/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_0157.JPG: 320x448 3 billetes, 2.5ms
# image 89/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_0158.JPG: 448x320 (no detections), 118.5ms
# image 90/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_2190.jpg: 448x448 1 billete, 2.5ms
# image 91/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_2191.jpg: 320x448 1 billete, 2.7ms
# image 92/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_2192.jpg: 352x448 1 billete, 2.6ms
# image 93/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_2193.jpg: 448x448 1 billete, 2.7ms
# image 94/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_2194.jpg: 448x320 1 knife, 1 billete, 2.4ms
# image 95/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_2198.jpg: 448x288 1 billete, 118.5ms
# image 96/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_2203.jpg: 352x448 1 billete, 2.6ms
# image 97/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/billete_2204.jpg: 384x448 1 billete, 122.0ms
# image 98/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1102.jpg: 256x448 (no detections), 2.6ms
# image 99/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1139.jpg: 256x448 (no detections), 2.4ms
# image 100/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1241.jpg: 256x448 1 pistol, 1 monedero, 2.4ms
# image 101/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1261.jpg: 256x448 1 monedero, 2.4ms
# image 102/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1273.jpg: 256x448 2 pistols, 2.4ms
# image 103/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1296.jpg: 256x448 1 pistol, 1 monedero, 2.5ms
# image 104/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1302.jpg: 256x448 1 pistol, 1 monedero, 2.5ms
# image 105/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1364.jpg: 256x448 1 monedero, 1 tarjeta, 2.4ms
# image 106/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1463.jpg: 256x448 1 monedero, 2.4ms
# image 107/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1475.jpg: 256x448 1 monedero, 2.2ms
# image 108/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1490.jpg: 256x448 1 monedero, 2.5ms
# image 109/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1542.jpg: 256x448 1 monedero, 2.4ms
# image 110/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1558.jpg: 256x448 1 monedero, 2.3ms
# image 111/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1590.jpg: 256x448 1 monedero, 2.3ms
# image 112/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1616.jpg: 256x448 1 pistol, 1 monedero, 2.5ms
# image 113/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1625.jpg: 256x448 1 monedero, 2.3ms
# image 114/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1641.jpg: 256x448 2 pistols, 2.4ms
# image 115/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1652.jpg: 256x448 (no detections), 2.4ms
# image 116/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1690.jpg: 256x448 1 pistol, 1 monedero, 2.5ms
# image 117/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1728.jpg: 256x448 (no detections), 2.4ms
# image 118/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1733.jpg: 256x448 1 smartphone, 1 monedero, 2.5ms
# image 119/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1733v2.jpg: 256x448 1 smartphone, 1 monedero, 2.5ms
# image 120/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1749.jpg: 256x448 1 smartphone, 1 monedero, 2.5ms
# image 121/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1773.jpg: 256x448 1 monedero, 2.4ms
# image 122/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1831.jpg: 256x448 1 monedero, 2.4ms
# image 123/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1857.jpg: 256x448 1 monedero, 2.5ms
# image 124/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1887.jpg: 256x448 1 billete, 2.3ms
# image 125/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1900.jpg: 256x448 1 billete, 2.3ms
# image 126/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img1980.jpg: 256x448 1 monedero, 2.5ms
# image 127/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img2005.jpg: 256x448 1 billete, 2.4ms
# image 128/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img2050.jpg: 256x448 1 monedero, 1 tarjeta, 2.3ms
# image 129/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img2051.jpg: 256x448 1 monedero, 1 billete, 2.4ms
# image 130/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img2105.jpg: 256x448 1 monedero, 2.4ms
# image 131/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img2127.jpg: 256x448 1 monedero, 2.4ms
# image 132/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img2167.jpg: 256x448 1 monedero, 1 billete, 2.3ms
# image 133/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img2233.jpg: 256x448 1 monedero, 2.4ms
# image 134/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img2294.jpg: 256x448 1 monedero, 1 tarjeta, 3.8ms
# image 135/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img2367.jpg: 256x448 1 monedero, 2.7ms
# image 136/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img238.jpg: 256x448 1 monedero, 2.5ms
# image 137/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img279.jpg: 256x448 1 smartphone, 2.6ms
# image 138/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img36.jpg: 256x448 2 pistols, 2.5ms
# image 139/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img381.jpg: 256x448 1 pistol, 2.4ms
# image 140/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img388.jpg: 256x448 (no detections), 2.5ms
# image 141/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img409.jpg: 256x448 1 knife, 2.5ms
# image 142/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img452.jpg: 256x448 1 smartphone, 2.4ms
# image 143/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img470.jpg: 256x448 1 monedero, 2.6ms
# image 144/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img483.jpg: 256x448 1 pistol, 2.4ms
# image 145/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img498.jpg: 256x448 (no detections), 2.4ms
# image 146/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img498v2.jpg: 256x448 1 monedero, 2.6ms
# image 147/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img510.jpg: 256x448 1 pistol, 2.4ms
# image 148/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img530.jpg: 256x448 1 pistol, 1 monedero, 2.9ms
# image 149/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img533.jpg: 256x448 (no detections), 2.7ms
# image 150/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img545.jpg: 256x448 1 smartphone, 1 monedero, 2.5ms
# image 151/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img601.jpg: 256x448 (no detections), 2.4ms
# image 152/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img616.jpg: 256x448 1 monedero, 2.5ms
# image 153/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img641.jpg: 256x448 1 monedero, 2.5ms
# image 154/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img65.jpg: 256x448 1 pistol, 2.5ms
# image 155/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img651.jpg: 256x448 (no detections), 2.5ms
# image 156/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img653.jpg: 256x448 1 pistol, 1 smartphone, 1 monedero, 2.6ms
# image 157/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img701.jpg: 256x448 1 tarjeta, 2.7ms
# image 158/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img759.jpg: 256x448 (no detections), 2.6ms
# image 159/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img772.jpg: 256x448 1 tarjeta, 2.5ms
# image 160/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img815.jpg: 256x448 1 smartphone, 2.5ms
# image 161/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img859.jpg: 256x448 (no detections), 2.5ms
# image 162/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/img931.jpg: 256x448 1 pistol, 2.5ms
# image 163/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/knifeDefenseTechnique070.jpg: 256x448 1 knife, 2.5ms
# image 164/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/knifeDefenseTechnique116.jpg: 256x448 1 knife, 2.8ms
# image 165/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/knife_102.jpg: 320x448 2 knifes, 2.7ms
# image 166/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/knife_103.jpg: 320x448 1 knife, 2.9ms
# image 167/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/knife
407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1025.jpg: 256x448 1 smartphone, 1 tarjeta, 2.9ms
# image 370/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1026.jpg: 320x448 1 smartphone, 2.7ms
# image 371/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1027.jpg: 320x448 1 smartphone, 1 tarjeta, 2.6ms
# image 372/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1028.jpg: 256x448 1 smartphone, 2.8ms
# image 373/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1029.jpg: 256x448 1 smartphone, 1 tarjeta, 2.5ms
# image 374/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1030.jpg: 320x448 1 smartphone, 1 tarjeta, 2.8ms
# image 375/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1031.jpg: 256x448 1 smartphone, 2.6ms
# image 376/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1032.jpg: 256x448 1 smartphone, 2.5ms
# image 377/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1033.jpg: 320x448 1 smartphone, 1 tarjeta, 3.0ms
# image 378/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1034.jpg: 256x448 1 pistol, 2.5ms
# image 379/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1035.jpg: 320x448 1 monedero, 2.9ms
# image 380/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1036.jpg: 320x448 1 monedero, 1 tarjeta, 2.5ms
# image 381/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1037.jpg: 320x448 1 monedero, 2.6ms
# image 382/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1038.jpg: 320x448 1 smartphone, 2.5ms
# image 383/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1039.jpg: 256x448 1 smartphone, 2.8ms
# image 384/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1040.jpg: 256x448 1 smartphone, 2.5ms
# image 385/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1041.jpg: 320x448 1 smartphone, 1 monedero, 2.7ms
# image 386/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1042.jpg: 320x448 1 monedero, 2.6ms
# image 387/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1043.jpg: 320x448 1 pistol, 1 smartphone, 2.3ms
# image 388/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/smartphone_1044.jpg: 256x448 1 smartphone, 2.7ms
# image 389/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2144.jpg: 320x448 1 tarjeta, 2.7ms
# image 390/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2150.jpg: 320x448 1 tarjeta, 2.0ms
# image 391/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2361.jpg: 320x448 1 tarjeta, 2.3ms
# image 392/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2362.jpg: 256x448 1 smartphone, 2.7ms
# image 393/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2363.jpg: 320x448 1 tarjeta, 2.5ms
# image 394/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2366.jpg: 352x448 1 tarjeta, 2.3ms
# image 395/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2367.jpg: 256x448 1 tarjeta, 2.3ms
# image 396/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2368.jpg: 320x448 2 tarjetas, 2.3ms
# image 397/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2369.jpg: 320x448 1 tarjeta, 2.4ms
# image 398/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2370.jpg: 320x448 1 monedero, 1 tarjeta, 2.3ms
# image 399/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2372.jpeg: 320x448 1 tarjeta, 2.5ms
# image 400/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2373.jpg: 256x448 1 tarjeta, 2.6ms
# image 401/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2374.jpg: 160x448 1 tarjeta, 137.6ms
# image 402/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2377.jpg: 448x448 1 tarjeta, 3.0ms
# image 403/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2378.jpg: 384x448 1 billete, 1 tarjeta, 2.7ms
# image 404/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2381.jpg: 320x448 1 billete, 1 tarjeta, 3.0ms
# image 405/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2382.jpg: 320x448 1 tarjeta, 2.6ms
# image 406/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2384.jpg: 320x448 1 billete, 2 tarjetas, 2.4ms
# image 407/407 /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/weapon-detection/test/images/tarjeta_2386.jpg: 320x448 1 tarjeta, 2.6ms
# Speed: 0.7ms preprocess, 5.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 448)
# Results saved to /home/coolenough/Desktop/GSSoC26/ML-CaPsule/Hands-On-Object-Detection/runs/detect/predict

# %%
# to check for predictions 

# direct to the ./runs/detect/predict and you can find out the 
# an example image is 

display(Image(filename = "./runs/detect/predict/ABbframe00145.jpg"))

# %%
# Thank You , I would recommend you continue your exploration by cheking out OpenCV and other model
# Happy Learning
