# %% [markdown]
# # importing important libraries

# %%
import pandas as pd
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading Dataset

# %%
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df = pd.read_csv(boston_url)

# %% [markdown]
# # Reading top 5 records of dataset

# %%
boston_df.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO  LSTAT  MEDV
# 0  296.0     15.3   4.98  24.0
# 1  242.0     17.8   9.14  21.6
# 2  242.0     17.8   4.03  34.7
# 3  222.0     18.7   2.94  33.4
# 4  222.0     18.7   5.33  36.2

# %% [markdown]
# # Deleting Unwanted Unnamed column

# %%
boston_df1 = boston_df.drop(['Unnamed: 0'], axis = 1)
boston_df1
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO  LSTAT  MEDV
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# ...

# %% [markdown]
# # Checking no of rows and columns of dataset

# %%
boston_df1.shape
# Out:
# (506, 13)

# %% [markdown]
# # Checking datatypes

# %%
boston_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  LSTAT    506 non-null    float64
#  12  MEDV     506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %% [markdown]
# # Checking the null values

# %%
boston_df1.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# # Summary of the dataset

# %%
boston_df1.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# # Correlation between all the features

# %%
boston_df1.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
corr_matrix = boston_df1.corr()

# %%
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.695360
# ZN         0.360445
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRIM      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Name: MEDV, dtype: float64

# %% [markdown]
# As we can see that RM is (positively) strongly correlated with MEDV and then LSTAT is (negatively) strongly correlated with MEDV.

# %% [markdown]
# # Heatmap showing correlated features

# %%
corr_heatmap = boston_df1.corr()
f , ax = plt.subplots(figsize=(20,12))
sb.heatmap(boston_df1.corr(),vmax=0.8, annot=True)

# %%
boston_df1["CHAS"].value_counts()
# Out:
# 0.0    471
# 1.0     35
# Name: CHAS, dtype: int64

# %%
boston_df1["RAD"].value_counts()
# Out:
# 24.0    132
# 5.0     115
# 4.0     110
# 3.0      38
# 6.0      26
# 8.0      24
# 2.0      24
# 1.0      20
# 7.0      17
# Name: RAD, dtype: int64

# %% [markdown]
# # Visualization through different plots :- Histograms and scatter plots

# %%
boston_df1['CHAS'].plot(kind='hist')

# %%
from pandas.plotting import scatter_matrix
attr = ["MEDV","RM","ZN","LSTAT"]
scatter_matrix(boston_df1[attr],figsize = (12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9b04750550>,
# ...
#       dtype=object)

# %%
boston_df1.plot(kind= "scatter",x="RM",y="MEDV",alpha=0.8)

# %%
import matplotlib.pyplot as plt
boston_df.hist(bins=50,figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9b05e5e6d0>,
# ...
#       dtype=object)

# %% [markdown]
# # Discretize the age variable into three groups of 35 years and younger, between 35 and 70 years and 70 years and older

# %%
boston_df1['AGE_bins']=pd.cut(x=boston_df1['AGE'], bins=[0,35,70,101])
boston_df1
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO  LSTAT  MEDV   AGE_bins
# 0       15.3   4.98  24.0   (35, 70]
# ...

# %%
boston_df1['AGE_group']=pd.cut(x=boston_df1['AGE'], bins=[0,35,70,101],labels=[1,2,3])
boston_df1
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO  LSTAT  MEDV   AGE_bins AGE_group
# 0       15.3   4.98  24.0   (35, 70]         2
# ...

# %% [markdown]
# # Scatter plot to show the relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town

# %%
plt.scatter(boston_df1.NOX,boston_df1.INDUS,c="red")
plt.ylabel('NOX')
plt.xlabel('INDUS')
plt.title("NOX vs INDUS")
plt.show()

# %% [markdown]
# # Boxplot for the MEDV variable vs the AGE variable

# %%
sb.boxplot(boston_df1.AGE_group,boston_df1.MEDV)

# %%
sb.boxplot(boston_df1.MEDV)

# %% [markdown]
# # Calculating P - Value

# %% [markdown]
# # T-test between median value of houses bounded by the Charles river (independent samples)

# %%
from scipy import stats

# %%
stats.ttest_ind(boston_df1[boston_df1['CHAS'] == 0]['MEDV'],boston_df1[boston_df1['CHAS'] == 1]['MEDV'],equal_var= True)
# Out:
# Ttest_indResult(statistic=-3.996437466090509, pvalue=7.390623170519905e-05)

# %%
stats.ttest_ind(boston_df1[boston_df1['CHAS'] == 0]['MEDV'],boston_df1[boston_df1['CHAS'] == 1]['MEDV'],equal_var= False)
# Out:
# Ttest_indResult(statistic=-3.113291312794837, pvalue=0.003567170098137517)

# %% [markdown]
# # ANOVA Test between Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)

# %%
df1 = pd.DataFrame({'medv' : boston_df1['MEDV'], 'age_group' : boston_df1['AGE_group']})

# %%
#df1 = df1.drop_duplicates(subset="age_group")

# %%
df1
# Out:
#      medv age_group
# 0    24.0         2
# 1    21.6         3
# 2    34.7         2
# 3    33.4         2
# 4    36.2         2
# ..    ...       ...
# 501  22.4         2
# 502  20.6         3
# 503  23.9         3
# 504  22.0         3
# 505  11.9         3
#
# [506 rows x 2 columns]

# %%
fvalue,pvalue = stats.f_oneway(df1['age_group'],df1['medv'])

# %%
fvalue,pvalue
# Out:
# (2410.6937451934, 8.513426061695347e-270)

# %% [markdown]
# # What is the impact of an additional weighted distance to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)

# %% [markdown]
# from OLS method

# %%
X = boston_df1[['RM','LSTAT']]
Y = boston_df1[['MEDV']]
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 30)

# %%
import statsmodels.api as sm
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.639
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     444.3
# Date:                Mon, 08 Feb 2021   Prob (F-statistic):          7.01e-112
# Time:                        10:30:15   Log-Likelihood:                -1582.8
# No. Observations:                 506   AIC:                             3172.
# Df Residuals:                     503   BIC:                             3184.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.3583      3.173     -0.428      0.669      -7.592       4.875
# ...

# %%
X = boston_df1[['RM','LSTAT','DIS']]
Y = boston_df1[['MEDV']]
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 30)
import statsmodels.api as sm
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.647
# Model:                            OLS   Adj. R-squared:                  0.645
# Method:                 Least Squares   F-statistic:                     306.4
# Date:                Mon, 08 Feb 2021   Prob (F-statistic):          5.22e-113
# Time:                        10:30:15   Log-Likelihood:                -1577.0
# No. Observations:                 506   AIC:                             3162.
# Df Residuals:                     502   BIC:                             3179.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8083      3.368      0.834      0.405      -3.809       9.425
# ...

# %% [markdown]
# This table displays all the statistics regarding the independent variables. But right now, we are only interested in looking at the column with the p-values in it. We can clearly see that the “DIS” , “RM” and “LSTAT” have a p-value less than 0.50!
#
# But the question is, what does this p-value mean in a regression model? For that, let’s understand what’s the hypothesis for which these p-values are calculated:
#
# **Null Hypothesis: The independent variable has no significant effect over the target variable**
#
# **Alternate Hypothesis: The independent variables have a significant effect on the target variable**
#
# Now, the above results show that “DIS” , “RM” and “LSTAT”  have a significant effect over the “MEDV”. So we have to consider all the variables in our model.
