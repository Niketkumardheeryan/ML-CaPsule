# %% [markdown]
# # SUYASH PRATAP SINGH

# %% [markdown]
# # Task 6:-Timeline analysis:-Covid 19

# %% [markdown]
# # Import library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import pylab as pl
# %matplotlib inline
sns.set()

# %% [markdown]
# # Loading the Dataset

# %%
df = pd.read_csv(r'C:\Users\Admin\Desktop\owid-covid-data.csv')

# %%
#print first five row
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31-12-2019          NaN        0.0
# 1      AFG      Asia  Afghanistan  01-01-2020          NaN        0.0
# 2      AFG      Asia  Afghanistan  02-01-2020          NaN        0.0
# 3      AFG      Asia  Afghanistan  03-01-2020          NaN        0.0
# 4      AFG      Asia  Afghanistan  04-01-2020          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.498
# 1                         0.5            64.83                    0.498
# 2                         0.5            64.83                    0.498
# 3                         0.5            64.83                    0.498
# 4                         0.5            64.83                    0.498
#
# [5 rows x 41 columns]

# %%
#print last five row
df.tail()
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 50720      NaN       NaN  International  13-10-2020        696.0        NaN
# 50721      NaN       NaN  International  14-10-2020        696.0        NaN
# 50722      NaN       NaN  International  15-10-2020        696.0        NaN
# 50723      NaN       NaN  International  16-10-2020        696.0        NaN
# 50724      NaN       NaN  International  17-10-2020        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 50720                 NaN           7.0         NaN                  NaN  ...
# 50721                 NaN           7.0         NaN                  NaN  ...
# 50722                 NaN           7.0         NaN                  NaN  ...
# 50723                 NaN           7.0         NaN                  NaN  ...
# 50724                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 50720             NaN              NaN                    NaN
# 50721             NaN              NaN                    NaN
# 50722             NaN              NaN                    NaN
# 50723             NaN              NaN                    NaN
# 50724             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 50720                  NaN             NaN           NaN
# 50721                  NaN             NaN           NaN
# 50722                  NaN             NaN           NaN
# 50723                  NaN             NaN           NaN
# 50724                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 50720                     NaN                         NaN              NaN
# 50721                     NaN                         NaN              NaN
# 50722                     NaN                         NaN              NaN
# 50723                     NaN                         NaN              NaN
# 50724                     NaN                         NaN              NaN
#
#        human_development_index
# 50720                      NaN
# 50721                      NaN
# 50722                      NaN
# 50723                      NaN
# 50724                      NaN
#
# [5 rows x 41 columns]

# %%
#print random five row
df.sample(5)
# Out:
#       iso_code continent        location        date  total_cases  new_cases  \
# 19891      GNB    Africa   Guinea-Bissau  26-06-2020       1556.0        0.0
# 50573      NaN       NaN   International  19-05-2020        696.0        NaN
# 32879      NCL   Oceania   New Caledonia  22-07-2020         22.0        0.0
# 22904      ISR      Asia          Israel  17-01-2020          NaN        0.0
# 47450      GBR    Europe  United Kingdom  22-02-2020         10.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 19891               6.286          19.0         0.0                0.571  ...
# 50573                 NaN           7.0         NaN                  NaN  ...
# 32879               0.000           NaN         0.0                0.000  ...
# 22904               0.000           NaN         0.0                0.000  ...
# 47450               0.000           NaN         0.0                0.000  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 19891        1548.675             67.1                382.474
# 50573             NaN              NaN                    NaN
# 32879             NaN              NaN                    NaN
# 22904       33132.320              0.5                 93.320
# 47450       39753.244              0.2                122.137
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 19891                 2.42             NaN           NaN
# 50573                  NaN             NaN           NaN
# 32879                23.36             NaN           NaN
# 22904                 6.74            15.4          35.4
# 47450                 4.28            20.0          24.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 19891                   6.403                         NaN            58.32
# 50573                     NaN                         NaN              NaN
# 32879                     NaN                         NaN            77.55
# 22904                     NaN                        2.99            82.97
# 47450                     NaN                        2.54            81.32
#
#        human_development_index
# 19891                    0.455
# 50573                      NaN
# 32879                      NaN
# 22904                    0.903
# 47450                    0.922
#
# [5 rows x 41 columns]

# %%
print(df.info())             #full summary of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50725 entries, 0 to 50724
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         50433 non-null  object
#  1   continent                        50141 non-null  object
#  2   location                         50725 non-null  object
#  3   date                             50725 non-null  object
#  4   total_cases                      47077 non-null  float64
#  5   new_cases                        49861 non-null  float64
#  6   new_cases_smoothed               49077 non-null  float64
#  7   total_deaths                     38407 non-null  float64
#  8   new_deaths                       49861 non-null  float64
#  9   new_deaths_smoothed              49077 non-null  float64
#  10  total_cases_per_million          46821 non-null  float64
#  11  new_cases_per_million            49797 non-null  float64
#  12  new_cases_smoothed_per_million   49012 non-null  float64
#  13  total_deaths_per_million         38166 non-null  float64
#  14  new_deaths_per_million           49797 non-null  float64
#  15  new_deaths_smoothed_per_million  49012 non-null  float64
#  16  new_tests                        18456 non-null  float64
#  17  total_tests                      18826 non-null  float64
#  18  total_tests_per_thousand         18826 non-null  float64
#  19  new_tests_per_thousand           18456 non-null  float64
#  20  new_tests_smoothed               20832 non-null  float64
#  21  new_tests_smoothed_per_thousand  20832 non-null  float64
#  22  tests_per_case                   19148 non-null  float64
#  23  positive_rate                    19467 non-null  float64
#  24  tests_units                      21776 non-null  object
#  25  stringency_index                 42007 non-null  float64
#  26  population                       50433 non-null  float64
#  27  population_density               48106 non-null  float64
#  28  median_age                       45192 non-null  float64
#  29  aged_65_older                    44516 non-null  float64
#  30  aged_70_older                    44957 non-null  float64
#  31  gdp_per_capita                   44598 non-null  float64
#  32  extreme_poverty                  29742 non-null  float64
#  33  cardiovasc_death_rate            45179 non-null  float64
#  34  diabetes_prevalence              46802 non-null  float64
#  35  female_smokers                   35308 non-null  float64
#  36  male_smokers                     34857 non-null  float64
#  37  handwashing_facilities           21241 non-null  float64
#  38  hospital_beds_per_thousand       40760 non-null  float64
#  39  life_expectancy                  49791 non-null  float64
#  40  human_development_index          43602 non-null  float64
# dtypes: float64(36), object(5)
# memory usage: 15.9+ MB
# None

# %%
print(df.describe())    #statistical details of the dataset
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  4.707700e+04   49861.000000        49077.000000  3.840700e+04
# mean   1.294868e+05    1580.365717         1560.232891  5.970738e+03
# std    1.296694e+06   14264.820540        13979.603253  4.830707e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.410000e+02       0.000000            0.714000  1.100000e+01
# 50%    1.618000e+03      12.000000           16.714000  6.900000e+01
# 75%    1.627500e+04     187.000000          192.571000  5.970000e+02
# max    3.940003e+07  395931.000000       348202.571000  1.105353e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  49861.000000         49077.000000             46821.000000
# mean      44.336676            44.350905              2389.188482
# std      370.964460           360.298413              4745.203714
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000                68.646000
# 50%        0.000000             0.286000               450.666000
# 75%        3.000000             3.429000              2615.946000
# max    10468.000000          7459.143000             45442.979000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           49797.000000                    49012.000000
# mean               28.444976                       27.529444
# std               101.781625                       66.553689
# min             -2212.545000                     -269.978000
# 25%                 0.000000                        0.185000
# 50%                 1.777000                        3.326000
# 75%                20.539000                       22.972000
# max              8652.658000                     2472.188000
#
#        total_deaths_per_million  ...  gdp_per_capita  extreme_poverty  \
# count              38166.000000  ...    44598.000000     29742.000000
# mean                  83.249772  ...    20800.365592        12.241174
# std                  167.467681  ...    20386.038683        19.310355
# min                    0.000000  ...      661.240000         0.100000
# 25%                    3.291000  ...     5338.454000         0.500000
# 50%                   16.768000  ...    14048.881000         2.000000
# 75%                   68.443000  ...    31400.840000        18.100000
# max                 1237.551000  ...   116935.600000        77.600000
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# count           45179.000000         46802.000000    35308.000000
# mean              251.905798             8.051126       10.784438
# std               117.431617             4.153106       10.474681
# min                79.370000             0.990000        0.100000
# 25%               155.898000             5.310000        1.900000
# 50%               238.339000             7.110000        6.400000
# 75%               318.991000            10.390000       19.600000
# max               724.417000            23.360000       44.000000
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# count  34857.000000            21241.000000                40760.000000
# mean      32.635695               52.297199                    3.103258
# std       13.432386               31.627966                    2.521663
# min        7.700000                1.188000                    0.100000
# 25%       21.400000               21.222000                    1.300000
# 50%       31.400000               52.232000                    2.500000
# 75%       40.900000               83.741000                    4.200000
# max       78.100000               98.999000                   13.800000
#
#        life_expectancy  human_development_index
# count     49791.000000             43602.000000
# mean         73.989847                 0.723876
# std           7.384835                 0.153022
# min          53.280000                 0.354000
# 25%          69.870000                 0.601000
# 50%          75.400000                 0.754000
# 75%          79.380000                 0.847000
# max          86.750000                 0.953000
#
# [8 rows x 36 columns]

# %%
print(df.shape)      #shape of dataset
# Out:
# (50725, 41)

# %%
duplicate_rows_df = df[df.duplicated()]

print("Number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (0, 41)

# %%
df.count() #Used to count the number of rows
# Out:
# iso_code                           50433
# continent                          50141
# location                           50725
# date                               50725
# total_cases                        47077
# new_cases                          49861
# new_cases_smoothed                 49077
# total_deaths                       38407
# new_deaths                         49861
# new_deaths_smoothed                49077
# total_cases_per_million            46821
# new_cases_per_million              49797
# new_cases_smoothed_per_million     49012
# total_deaths_per_million           38166
# new_deaths_per_million             49797
# new_deaths_smoothed_per_million    49012
# new_tests                          18456
# total_tests                        18826
# total_tests_per_thousand           18826
# new_tests_per_thousand             18456
# new_tests_smoothed                 20832
# new_tests_smoothed_per_thousand    20832
# tests_per_case                     19148
# positive_rate                      19467
# tests_units                        21776
# stringency_index                   42007
# population                         50433
# population_density                 48106
# median_age                         45192
# aged_65_older                      44516
# aged_70_older                      44957
# gdp_per_capita                     44598
# extreme_poverty                    29742
# cardiovasc_death_rate              45179
# diabetes_prevalence                46802
# female_smokers                     35308
# male_smokers                       34857
# handwashing_facilities             21241
# hospital_beds_per_thousand         40760
# life_expectancy                    49791
# human_development_index            43602
# dtype: int64

# %%
df.isnull().sum()
# Out:
# iso_code                             292
# continent                            584
# location                               0
# date                                   0
# total_cases                         3648
# new_cases                            864
# new_cases_smoothed                  1648
# total_deaths                       12318
# new_deaths                           864
# new_deaths_smoothed                 1648
# total_cases_per_million             3904
# new_cases_per_million                928
# new_cases_smoothed_per_million      1713
# total_deaths_per_million           12559
# new_deaths_per_million               928
# new_deaths_smoothed_per_million     1713
# new_tests                          32269
# total_tests                        31899
# total_tests_per_thousand           31899
# new_tests_per_thousand             32269
# new_tests_smoothed                 29893
# new_tests_smoothed_per_thousand    29893
# tests_per_case                     31577
# positive_rate                      31258
# tests_units                        28949
# stringency_index                    8718
# population                           292
# population_density                  2619
# median_age                          5533
# aged_65_older                       6209
# aged_70_older                       5768
# gdp_per_capita                      6127
# extreme_poverty                    20983
# cardiovasc_death_rate               5546
# diabetes_prevalence                 3923
# female_smokers                     15417
# male_smokers                       15868
# handwashing_facilities             29484
# hospital_beds_per_thousand          9965
# life_expectancy                      934
# human_development_index             7123
# dtype: int64

# %%
df1=df[["date","total_cases","new_cases","total_deaths","new_tests","total_tests"]]
df1.head()
# Out:
#          date  total_cases  new_cases  total_deaths  new_tests  total_tests
# 0  31-12-2019          NaN        0.0           NaN        NaN          NaN
# 1  01-01-2020          NaN        0.0           NaN        NaN          NaN
# 2  02-01-2020          NaN        0.0           NaN        NaN          NaN
# 3  03-01-2020          NaN        0.0           NaN        NaN          NaN
# 4  04-01-2020          NaN        0.0           NaN        NaN          NaN

# %%
df1.mean()
# Out:
# total_cases     1.294868e+05
# new_cases       1.580366e+03
# total_deaths    5.970738e+03
# new_tests       2.503919e+04
# total_tests     1.795304e+06
# dtype: float64

# %%
df1.cov()
# Out:
#                total_cases     new_cases  total_deaths     new_tests  \
# total_cases   1.681415e+12  1.813704e+10  6.757741e+10  5.164098e+10
# new_cases     1.813704e+10  2.034851e+08  7.605209e+08  6.369924e+08
# total_deaths  6.757741e+10  7.605209e+08  2.333573e+09  1.528826e+09
# new_tests     5.164098e+10  6.369924e+08  1.528826e+09  1.057763e+10
# total_tests   4.202203e+12  4.191109e+10  1.239734e+11  7.758679e+11
#
#                total_tests
# total_cases   4.202203e+12
# new_cases     4.191109e+10
# total_deaths  1.239734e+11
# new_tests     7.758679e+11
# total_tests   6.695936e+13

# %%
df1.corr()
# Out:
#               total_cases  new_cases  total_deaths  new_tests  total_tests
# total_cases      1.000000   0.948548      0.975533   0.912856     0.929219
# new_cases        0.948548   1.000000      0.964730   0.905516     0.745718
# total_deaths     0.975533   0.964730      1.000000   0.823172     0.834448
# new_tests        0.912856   0.905516      0.823172   1.000000     0.904207
# total_tests      0.929219   0.745718      0.834448   0.904207     1.000000

# %%
df1.var()
# Out:
# total_cases     1.681415e+12
# new_cases       2.034851e+08
# total_deaths    2.333573e+09
# new_tests       1.057763e+10
# total_tests     6.695936e+13
# dtype: float64

# %%
df1.std()
# Out:
# total_cases     1.296694e+06
# new_cases       1.426482e+04
# total_deaths    4.830707e+04
# new_tests       1.028476e+05
# total_tests     8.182870e+06
# dtype: float64

# %% [markdown]
# # Proper visualization of dataset

# %%
sns.distplot(df1['total_cases'])
sns.distplot(df1['new_cases']);

# %%
df1.plot(figsize = (10 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
sns.distplot(df1['total_tests'])
sns.distplot(df1['new_tests']);

# %%
df1.new_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_deaths.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# # Trends and Seasonality in TimeSeries Dataset

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
new_cases = df1[['new_cases']]
new_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
sns.pairplot(df1, size=2.5)
# Out:
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
with sns.axes_style('white'):
    sns.jointplot("new_cases", "total_cases", data=df1, kind='reg')

# %%
sns.distplot(df1['total_cases'], kde=False);
plt.axvline(0, color="k", linestyle="--");

# %%
sns.distplot(df1['new_cases'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %%
sns.distplot(df1['total_tests'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %%
sns.distplot(df1['new_tests'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %%
total_cases.diff().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20);

# %%
df1.total_cases.plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
total_cases=df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# # Thank you
