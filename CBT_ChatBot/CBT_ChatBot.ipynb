# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
# Out:
# [nltk_data] Downloading package punkt to /home/paritosh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/paritosh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/paritosh/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 69 documents
# 18 classes ['academic', 'adverse_drug', 'blood_pressure', 'blood_pressure_search', 'cultural', 'goodbye', 'greeting', 'hospital_search', 'how_you_feel', 'negative_core_beliefs', 'nfeel', 'options', 'pfeel', 'pharmacy_search', 'postive_core_beliefs', 'religious', 'thanks', 'why_you_feel']
# 116 unique lemmatized words ["'s", ',', 'a', 'academic', 'adverse', 'all', 'always', 'anxious', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'confident', 'could', 'crush', 'cultural', 'culture', 'data', 'day', 'depressed', 'detail', 'do', 'dont', 'drug', 'enough', 'entry', 'find', 'for', 'give', 'god', 'good', 'goodbye', 'happen', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'job', 'later', 'learning', 'life', 'like', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'make', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'no', 'not', 'of', 'offered', 'open', 'patient', 'people', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'religion', 'result', 'roomate', 'search', 'searching', 'see', 'show', 'study', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'them', 'there', 'thing', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'when', 'which', 'with', 'worthless', 'worthy', 'yes', 'you']

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# <ipython-input-6-1a891a7a8859>:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# /home/paritosh/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.9254 - accuracy: 0.0580
# Epoch 2/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.8098 - accuracy: 0.1304
# Epoch 3/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6473 - accuracy: 0.2174
# Epoch 4/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6872 - accuracy: 0.1884
# Epoch 5/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.4348 - accuracy: 0.3478
# Epoch 6/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.3799 - accuracy: 0.3043
# Epoch 7/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.2769 - accuracy: 0.3623
# Epoch 8/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.1155 - accuracy: 0.3768
# Epoch 9/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.9478 - accuracy: 0.4203
# Epoch 10/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.8410 - accuracy: 0.5507
# Epoch 11/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7599 - accuracy: 0.4348
# Epoch 12/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6430 - accuracy: 0.5507
# Epoch 13/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5944 - accuracy: 0.5507
# Epoch 14/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5249 - accuracy: 0.5217
# Epoch 15/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5108 - accuracy: 0.5652
# Epoch 16/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3951 - accuracy: 0.5652
# Epoch 17/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3511 - accuracy: 0.6087
# Epoch 18/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3028 - accuracy: 0.6232
# Epoch 19/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2180 - accuracy: 0.6377
# Epoch 20/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.1694 - accuracy: 0.6377
# Epoch 21/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0518 - accuracy: 0.6957
# Epoch 22/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0228 - accuracy: 0.7681
# Epoch 23/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9457 - accuracy: 0.7536
# Epoch 24/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8927 - accuracy: 0.7681
# Epoch 25/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9081 - accuracy: 0.7246
# Epoch 26/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9368 - accuracy: 0.7536
# Epoch 27/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7547 - accuracy: 0.7971
# Epoch 28/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7161 - accuracy: 0.8406
# Epoch 29/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8107 - accuracy: 0.7826
# Epoch 30/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7879 - accuracy: 0.7536
# Epoch 31/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.7248 - accuracy: 0.8116
# Epoch 32/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6282 - accuracy: 0.8551
# Epoch 33/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5772 - accuracy: 0.7971
# Epoch 34/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5834 - accuracy: 0.8116
# Epoch 35/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5875 - accuracy: 0.8551
# Epoch 36/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5953 - accuracy: 0.8261
# Epoch 37/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4897 - accuracy: 0.8696
# Epoch 38/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4782 - accuracy: 0.8696
# Epoch 39/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5773 - accuracy: 0.8406
# Epoch 40/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.9420
# Epoch 41/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3860 - accuracy: 0.8986
# Epoch 42/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3081 - accuracy: 0.9420
# Epoch 43/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3558 - accuracy: 0.9130
# Epoch 44/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3709 - accuracy: 0.9420
# Epoch 45/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3989 - accuracy: 0.8841
# Epoch 46/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.8986
# Epoch 47/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3484 - accuracy: 0.9130
# Epoch 48/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3447 - accuracy: 0.9420
# Epoch 49/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3997 - accuracy: 0.8841
# Epoch 50/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2420 - accuracy: 0.9275
# Epoch 51/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3012 - accuracy: 0.9565
# Epoch 52/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3567 - accuracy: 0.9130
# Epoch 53/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3438 - accuracy: 0.9130
# Epoch 54/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3720 - accuracy: 0.8696
# Epoch 55/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2260 - accuracy: 0.9710
# Epoch 56/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2182 - accuracy: 0.9565
# Epoch 57/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2453 - accuracy: 0.9710
# Epoch 58/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2476 - accuracy: 0.9710
# Epoch 59/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1882 - accuracy: 0.9275
# Epoch 60/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2973 - accuracy: 0.9275
# Epoch 61/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2462 - accuracy: 0.9275
# Epoch 62/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1573 - accuracy: 0.9710
# Epoch 63/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2592 - accuracy: 0.9420
# Epoch 64/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2605 - accuracy: 0.9130
# Epoch 65/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1928 - accuracy: 0.9420
# Epoch 66/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1697 - accuracy: 0.9855
# Epoch 67/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2126 - accuracy: 0.9420
# Epoch 68/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2174 - accuracy: 0.9565
# Epoch 69/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2414 - accuracy: 0.9420
# Epoch 70/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1691 - accuracy: 0.9710
# Epoch 71/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1519 - accuracy: 0.9855
# Epoch 72/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1730 - accuracy: 0.9710
# Epoch 73/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1825 - accuracy: 0.9420
# Epoch 74/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2003 - accuracy: 0.9420
# Epoch 75/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 0.9855
# Epoch 76/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1507 - accuracy: 0.9420
# Epoch 77/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2101 - accuracy: 0.9565
# Epoch 78/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1542 - accuracy: 0.9710
# Epoch 79/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1577 - accuracy: 0.9710
# Epoch 80/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2140 - accuracy: 0.9710
# Epoch 81/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0823 - accuracy: 1.0000
# Epoch 82/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1433 - accuracy: 0.9565
# Epoch 83/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0974 - accuracy: 1.0000
# Epoch 84/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1395 - accuracy: 0.9710
# Epoch 85/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2211 - accuracy: 0.9565
# Epoch 86/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1081 - accuracy: 0.9710
# Epoch 87/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1337 - accuracy: 0.9710
# Epoch 88/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1246 - accuracy: 0.9710
# Epoch 89/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1271 - accuracy: 0.9710
# Epoch 90/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1339 - accuracy: 0.9420
# Epoch 91/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1146 - accuracy: 0.9855
# Epoch 92/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1239 - accuracy: 1.0000
# Epoch 93/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1597 - accuracy: 0.9710
# Epoch 94/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1476 - accuracy: 0.9710
# Epoch 95/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1656 - accuracy: 0.9565
# Epoch 96/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1228 - accuracy: 0.9855
# Epoch 97/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0985 - accuracy: 0.9565
# Epoch 98/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1261 - accuracy: 0.9710
# Epoch 99/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 0.9855
# Epoch 100/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1316 - accuracy: 0.9565
# Epoch 101/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1215 - accuracy: 0.9855
# Epoch 102/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1171 - accuracy: 0.9565
# Epoch 103/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0915 - accuracy: 0.9855
# Epoch 104/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1075 - accuracy: 0.9565
# Epoch 105/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 1.0000
# Epoch 106/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0674 - accuracy: 1.0000
# Epoch 107/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0587 - accuracy: 1.0000
# Epoch 108/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0819 - accuracy: 1.0000
# Epoch 109/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0993 - accuracy: 0.9855
# Epoch 110/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0976 - accuracy: 0.9710
# Epoch 111/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 1.0000
# Epoch 112/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0668 - accuracy: 1.0000
# Epoch 113/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0531 - accuracy: 1.0000
# Epoch 114/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0780 - accuracy: 1.0000
# Epoch 115/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1444 - accuracy: 0.9710
# Epoch 116/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0785 - accuracy: 1.0000
# Epoch 117/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0894 - accuracy: 0.9710
# Epoch 118/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 119/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1005 - accuracy: 0.9855
# Epoch 120/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0867 - accuracy: 0.9855
# Epoch 121/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1407 - accuracy: 0.9710
# Epoch 122/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1189 - accuracy: 0.9565
# Epoch 123/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.9710
# Epoch 124/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1029 - accuracy: 0.9855
# Epoch 125/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1409 - accuracy: 0.9710
# Epoch 126/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 127/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0819 - accuracy: 0.9710
# Epoch 128/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 1.0000
# Epoch 129/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0595 - accuracy: 0.9710
# Epoch 130/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 1.0000
# Epoch 131/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 0.9710
# Epoch 132/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 0.9855
# Epoch 133/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0444 - accuracy: 1.0000
# Epoch 134/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0664 - accuracy: 0.9855
# Epoch 135/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1158 - accuracy: 0.9855
# Epoch 136/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0871 - accuracy: 0.9855
# Epoch 137/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 0.9855
# Epoch 138/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1511 - accuracy: 0.9275
# Epoch 139/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 140/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1116 - accuracy: 0.9855
# Epoch 141/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0620 - accuracy: 0.9855
# Epoch 142/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1279 - accuracy: 0.9420
# Epoch 143/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0974 - accuracy: 0.9855
# Epoch 144/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 145/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0664 - accuracy: 0.9710
# Epoch 146/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0823 - accuracy: 0.9855
# Epoch 147/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0390 - accuracy: 1.0000
# Epoch 148/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1164 - accuracy: 0.9420
# Epoch 149/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0892 - accuracy: 0.9710
# Epoch 150/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0580 - accuracy: 1.0000
# Epoch 151/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 1.0000
# Epoch 152/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0795 - accuracy: 0.9855
# Epoch 153/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9855
# Epoch 154/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0609 - accuracy: 1.0000
# Epoch 155/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1144 - accuracy: 0.9565
# Epoch 156/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1170 - accuracy: 0.9710
# Epoch 157/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 158/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 159/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 160/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 161/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 0.9855
# Epoch 162/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 163/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 164/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1116 - accuracy: 0.9710
# Epoch 165/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 166/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0619 - accuracy: 0.9855
# Epoch 167/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0443 - accuracy: 0.9855
# Epoch 168/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 0.9855
# Epoch 169/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0560 - accuracy: 0.9710
# Epoch 170/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0577 - accuracy: 0.9855
# Epoch 171/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9855
# Epoch 172/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0441 - accuracy: 0.9855
# Epoch 173/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 174/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 0.9855
# Epoch 175/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 176/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0333 - accuracy: 0.9855
# Epoch 177/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0659 - accuracy: 1.0000
# Epoch 178/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0652 - accuracy: 0.9710
# Epoch 179/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 180/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0512 - accuracy: 0.9855
# Epoch 181/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 1.0000
# Epoch 182/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 183/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9710
# Epoch 184/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1591 - accuracy: 0.9420
# Epoch 185/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 0.9855
# Epoch 186/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0570 - accuracy: 0.9855
# Epoch 187/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9710
# Epoch 188/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 189/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 190/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 191/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0714 - accuracy: 0.9710
# Epoch 192/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1141 - accuracy: 0.9710
# Epoch 193/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 194/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9855
# Epoch 195/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 0.9710
# Epoch 196/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 197/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 0.9855
# Epoch 198/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 0.9855
# Epoch 199/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0481 - accuracy: 0.9855
# Epoch 200/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.9565
# model created

# %%
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)


base = Tk()
base.title("Aishika")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
