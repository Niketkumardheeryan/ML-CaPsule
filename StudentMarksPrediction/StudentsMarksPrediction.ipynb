# %% [markdown]
# Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Importing students_marks.csv file

# %%
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['Student_Marks (1).csv']))
# Out:
#      <input type="file" id="files-0cbbdbb0-daf4-466f-8cd9-f5a6cbb6fc84" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0cbbdbb0-daf4-466f-8cd9-f5a6cbb6fc84">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Checking whether this dataset contains any null values or not

# %%
print(df.isnull().sum())
# Out:
# number_courses    0
# time_study        0
# Marks             0
# dtype: int64

# %%
df["number_courses"].value_counts()
# Out:
# number_courses
# 3    22
# 4    21
# 6    16
# 8    16
# 7    15
# 5    10
# Name: count, dtype: int64

# %% [markdown]
# so,there are minimum of three and a maximum of eight courses students have chosen

# %%
figure = px.scatter(df,x="number_courses",y="Marks",size = "time_study", title ="Number of courses and marks scored")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the above data visualisation, we can conclude that the number of courses doesn't affect the marks of student if they study for more time.

# %% [markdown]
# Let's have a look at the relationship between time study and marks scored by the student.

# %%
figure = px.scatter(df, x = "time_study" , y="Marks", size = "number_courses",title = " Relationship between time study and marks" , trendline="ols")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# So, there's a linear relationship between time study and marks scored by a student. This means student who can study for more time they can score good marks.

# %% [markdown]
# Now, let's have a correlation between the marks scored by the student and other two columns in the data

# %%
correlation = df.corr()
print(correlation["Marks"].sort_values(ascending=False))
# Out:
# Marks             1.000000
# time_study        0.942254
# number_courses    0.417335
# Name: Marks, dtype: float64

# %% [markdown]
# So the time_studied column is more correlated with the marks column than the other column.

# %% [markdown]
# Student Marks Prediction Model

# %%
x = np.array(df[["number_courses","time_study"]])
y = np.array(df["Marks"])
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state = 42)

# %%
model = LinearRegression()
model.fit(x,y)
model.score(x_test,y_test)
# Out:
# 0.9559821384668957

# %% [markdown]
# Now, let's test the performance of the machine learning model by giving inputs

# %%
# features = time_study, number_courses
features = np.array([[4.508,3]])
model.predict(features)
# Out:
# array([17.14433088])

# %% [markdown]
# In this way we can predict the marks of a student with machine learning using python.
