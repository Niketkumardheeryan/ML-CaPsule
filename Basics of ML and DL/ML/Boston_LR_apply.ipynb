# %%
# sklearn conatins a list of datasets

from sklearn import datasets

# %%
# load boston house price dataset

boston = datasets.load_boston()

# %%
type(boston)

# %%
boston

# %%
x = boston.data
y = boston.target

# %%
print(type(x))
print(type(y))

# %%
x

# %%
y

# %%
print(x.shape)
print(y.shape)

# %%
# to convert numpy array's into dataframe

import pandas as pd

df = pd.DataFrame(x)

df

# %%
pd.DataFrame(y)

# %%
feature_names = boston.feature_names
feature_names

# %%
# to chnage the column name of dataframe df from (0 to 12) to feature_names

df.columns = feature_names

# %%
df

# %%
df.describe()

# %%
# train-test split

from sklearn import model_selection

x_train, x_test, y_train, y_test = model_selection.train_test_split(x,y,test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# %%
# apply  model

from sklearn.linear_model import LinearRegression

alg1 = LinearRegression() # creates an object of LinearRegression

# %%
# training of model

alg1.fit(x_train, y_train)

# %%
# predicting the output for test data

y_predict = alg1.predict(x_test)

# %%
# compare y_predict and y_test

import matplotlib.pyplot as plt

plt.scatter(y_test, y_predict)
plt.axis((0,50,0,50))
plt.show()

# %%
print("Train Accuracy: ",alg1.score(x_train, y_train))
print("Test Accuracy: ",alg1.score(x_test, y_test))
