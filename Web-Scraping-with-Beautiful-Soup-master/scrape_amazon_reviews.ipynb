# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
import logging

# Logging configuration
logging.basicConfig(level=logging.INFO)

# Headers for the HTTP request
headers = {
    "authority": "www.amazon.com",
    "pragma": "no-cache",
    "cache-control": "no-cache",
    "dnt": "1",
    "upgrade-insecure-requests": "1",
    "user-agent": "Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.6422.77 Safari/537.36",
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "sec-fetch-site": "none",
    "sec-fetch-mode": "navigate",
    "sec-fetch-dest": "document",
    "accept-language": "en-GB,en-US;q=0.9,en;q=0.8",
}

# URL of the page to scrape
URL = "https://www.amazon.com/Heat-Storm-HS-1500-PHX-WIFI-Infrared-Heater/product-reviews/B07JXRWJ8D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"

# Fetch the HTML content of the page
logging.info(f"Fetching URL: {URL}")
resp = requests.get(URL, headers=headers)
page_html = resp.text

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(page_html, "lxml")

# Find all the review elements
reviews = soup.find_all("div", {"class": "a-section celwidget"})

print(reviews)
# Out:
# INFO:root:Fetching URL: https://www.amazon.com/Heat-Storm-HS-1500-PHX-WIFI-Infrared-Heater/product-reviews/B07JXRWJ8D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# [<div class="a-section celwidget" id="customer_review-R37TE6Q4IOYWKP"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" href="/gp/profile/amzn1.account.AGGBODWMFF4E7L56GAT4U2UYV4AQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Samuel Armstrong</span></div></a></div><div class="a-row"><a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R37TE6Q4IOYWKP/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&amp;ASIN=B07JXRWJ8D"><i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i><span class="a-letter-space"></span>
# <span>Nice little heater</span>
# </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in the United States on April 20, 2024</span><div class="a-row a-spacing-mini review-data review-format-strip"><a class="a-size-mini a-link-normal a-color-secondary" data-hook="format-strip" href="/Heat-Storm-HS-1500-PHX-WIFI-Infrared-Heater/product-reviews/B07JXRWJ8D/ref=cm_cr_arp_d_rvw_fmt?ie=UTF8&amp;formatType=current_format">Color: WHITE Wi-Fi<i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i>Pattern Name: Infrared Heater</a><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><a class="a-link-normal" href="/gp/help/customer/display.html/ref=cm_cr_dp_d_rvw_avp?nodeId=G75XTB7MBMBTXP6W" rel="noopener" target="_blank"><span class="a-size-mini a-color-state a-text-bold" data-hook="avp-badge">Verified Purchase</span></a></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
# <span>Throughs decent heat after it’s been on for 15-20 minutes.  Nice and quiet and connected to WiFi seamlessly.  Nice little heater!</span>
# </span></div><div class="a-row review-comments comments-for-R37TE6Q4IOYWKP"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
# <div class="a-row a-spacing-small"><span class="a-size-base a-color-tertiary cr-vote-text" data-hook="helpful-vote-statement">One person found this helpful</span></div><!-- Components for Reactions C -->
# <div class="cr-helpful-button aok-float-left">
# <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.com/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.com%2FHeat-Storm-HS-1500-PHX-WIFI-Infrared-Heater%2Fproduct-reviews%2FB07JXRWJ8D%2Fref%3Dcm_cr_arp_d_vote_lft%3Fie%3DUTF8%26reviewerType%3Dall_reviews%26csrfT%3DhBTA1iOJhJmqYJRIXVPZFCPL9822IsV1lmGxm7JtgIw9AAAAAGZX4PkAAAAB%26reviewId%3DR37TE6Q4IOYWKP&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=usflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=ATVPDKIKX0DER&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#               Helpful</div>
# </a></span></span></div>
# </span><span class="cr-footer-line-height">
# <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hBTA1iOJhJmqYJRIXVPZFCPL9822IsV1lmGxm7JtgIw9AAAAAGZX4PkAAAAB&amp;reviewId=R37TE6Q4IOYWKP","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hBTA1iOJhJmqYJRIXVPZFCPL9822IsV1lmGxm7JtgIw9AAAAAGZX4PkAAAAB&amp;reviewId=R37TE6Q4IOYWKP">Report</a></span></span></span>
# <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
# <div class="a-row a-spacing-none a-grid-vertical-align a-grid-center"><div class="a-column a-span6"><span class="a-size-base a-viewoptions-list-label">Showing <span class="review-comment-count">0</span> comments</span></div></div></ul>
# </div><div class="a-section a-spacing-extra-large a-spacing-top-medium a-text-center comment-load-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem loading comments right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none review-comments"></div><div class="a-spinner-wrapper comment-loading aok-hidden a-spacing-top-medium a-spacing-extra-large"><span class="a-spinner a-spinner-medium"></span></div><hr aria-hidden="true" class="a-spacing-none a-spacing-top-large a-divider-normal"/></div></div></div></div>, <div class="a-section celwidget" id="customer_review-R3AQV8DMC06VIN"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" href="/gp/profile/amzn1.account.AGK7MKPVHCHFVPCMI3CXP5LH3IJA/ref=cm_cr_arp_d_gw_btm?ie=UTF8"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Kindle Customer</span></div></a></div><div class="a-row"><a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R3AQV8DMC06VIN/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&amp;ASIN=B07JXRWJ8D"><i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i><span class="a-letter-space"></span>
# <span>Keeps room warm</span>
# </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in the United States on May 8, 2024</span><div class="a-row a-spacing-mini review-data review-format-strip"><a class="a-size-mini a-link-normal a-color-secondary" data-hook="format-strip" href="/Heat-Storm-HS-1500-PHX-WIFI-Infrared-Heater/product-reviews/B07JXRWJ8D/ref=cm_cr_arp_d_rvw_fmt?ie=UTF8&amp;formatType=current_format">Color: WHITE Wi-Fi<i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i>Pattern Name: Infrared Heater</a><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><a class="a-link-normal" href="/gp/help/customer/display.html/ref=cm_cr_dp_d_rvw_avp?nodeId=G75XTB7MBMBTXP6W" rel="noopener" target="_blank"><span class="a-size-mini a-color-state a-text-bold" data-hook="avp-badge">Verified Purchase</span></a></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
# <span>Last fall I moved into a tiny house that is 12x20.  I didn't know if this heater would keep it warm but it performed perfectly.  We have a week or two of 0° or below and it kept it warm even when the dog was going in and out of the doggie door!  The one negative thing is it raised my electric bill significantly.  But because it's price was fantasticily Iow I can't complain because I don't know how other higher price heaters work or how much electricity they use.  It ran quietly and the automatic control kept very even temperature.  I highly recommend this heater for small spaces.</span>
# </span></div><div class="a-row review-comments comments-for-R3AQV8DMC06VIN"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
# <!-- Components for Reactions C -->
# <div class="cr-helpful-button aok-float-left">
# <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.com/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.com%2FHeat-Storm-HS-1500-PHX-WIFI-Infrared-Heater%2Fproduct-reviews%2FB07JXRWJ8D%2Fref%3Dcm_cr_arp_d_vote_lft%3Fie%3DUTF8%26reviewerType%3Dall_reviews%26csrfT%3DhOIql3EGusSJLGtEexU1uMdfzSB6lW38uQZk%252B1PUBxi6AAAAAGZX4PkAAAAB%26reviewId%3DR3AQV8DMC06VIN&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=usflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=ATVPDKIKX0DER&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#               Helpful</div>
# </a></span></span></div>
# </span><span class="cr-footer-line-height">
# <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hOIql3EGusSJLGtEexU1uMdfzSB6lW38uQZk%2B1PUBxi6AAAAAGZX4PkAAAAB&amp;reviewId=R3AQV8DMC06VIN","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hOIql3EGusSJLGtEexU1uMdfzSB6lW38uQZk%2B1PUBxi6AAAAAGZX4PkAAAAB&amp;reviewId=R3AQV8DMC06VIN">Report</a></span></span></span>
# <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
# <div class="a-row a-spacing-none a-grid-vertical-align a-grid-center"><div class="a-column a-span6"><span class="a-size-base a-viewoptions-list-label">Showing <span class="review-comment-count">0</span> comments</span></div></div></ul>
# </div><div class="a-section a-spacing-extra-large a-spacing-top-medium a-text-center comment-load-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem loading comments right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none review-comments"></div><div class="a-spinner-wrapper comment-loading aok-hidden a-spacing-top-medium a-spacing-extra-large"><span class="a-spinner a-spinner-medium"></span></div><hr aria-hidden="true" class="a-spacing-none a-spacing-top-large a-divider-normal"/></div></div></div></div>, <div class="a-section celwidget" id="customer_review-R1OKHA2KZ3NQSC"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" href="/gp/profile/amzn1.account.AEWTWVW2HM6I5IVPIKYEB4OW324Q/ref=cm_cr_arp_d_gw_btm?ie=UTF8"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/bed4dc35-f458-4972-83f9-91e008a3be3b._CR0,0,414,414_SX48_.jpg" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/bed4dc35-f458-4972-83f9-91e008a3be3b._CR0,0,414,414_SX48_.jpg"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Jesse</span></div></a></div><div class="a-row"><a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R1OKHA2KZ3NQSC/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&amp;ASIN=B07JXRWJ8D"><i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i><span class="a-letter-space"></span>
# <span>Wow!</span>
# </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in the United States on April 25, 2024</span><div class="a-row a-spacing-mini review-data review-format-strip"><a class="a-size-mini a-link-normal a-color-secondary" data-hook="format-strip" href="/Heat-Storm-HS-1500-PHX-WIFI-Infrared-Heater/product-reviews/B07JXRWJ8D/ref=cm_cr_arp_d_rvw_fmt?ie=UTF8&amp;formatType=current_format">Color: WHITE Wi-Fi<i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i>Pattern Name: Infrared Heater</a><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><a class="a-link-normal" href="/gp/help/customer/display.html/ref=cm_cr_dp_d_rvw_avp?nodeId=G75XTB7MBMBTXP6W" rel="noopener" target="_blank"><span class="a-size-mini a-color-state a-text-bold" data-hook="avp-badge">Verified Purchase</span></a></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
# <span>These are really nice. Bluetooth and remote capabilities. They heat small rooms well. We got 3 for our basement rooms and they do a great job! Price is amazing and good quality. Also sits on the floor or wall mount is nice.</span>
# </span></div><div class="a-row review-comments comments-for-R1OKHA2KZ3NQSC"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
# <!-- Components for Reactions C -->
# <div class="cr-helpful-button aok-float-left">
# <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.com/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.com%2FHeat-Storm-HS-1500-PHX-WIFI-Infrared-Heater%2Fproduct-reviews%2FB07JXRWJ8D%2Fref%3Dcm_cr_arp_d_vote_lft%3Fie%3DUTF8%26reviewerType%3Dall_reviews%26csrfT%3DhAWqRJf35V9%252Bz3Usj4hMrzn%252FEn150CA2RmXFou32uOCXAAAAAGZX4PkAAAAB%26reviewId%3DR1OKHA2KZ3NQSC&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=usflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=ATVPDKIKX0DER&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#               Helpful</div>
# </a></span></span></div>
# </span><span class="cr-footer-line-height">
# <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hAWqRJf35V9%2Bz3Usj4hMrzn%2FEn150CA2RmXFou32uOCXAAAAAGZX4PkAAAAB&amp;reviewId=R1OKHA2KZ3NQSC","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hAWqRJf35V9%2Bz3Usj4hMrzn%2FEn150CA2RmXFou32uOCXAAAAAGZX4PkAAAAB&amp;reviewId=R1OKHA2KZ3NQSC">Report</a></span></span></span>
# <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
# <div class="a-row a-spacing-none a-grid-vertical-align a-grid-center"><div class="a-column a-span6"><span class="a-size-base a-viewoptions-list-label">Showing <span class="review-comment-count">0</span> comments</span></div></div></ul>
# </div><div class="a-section a-spacing-extra-large a-spacing-top-medium a-text-center comment-load-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem loading comments right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none review-comments"></div><div class="a-spinner-wrapper comment-loading aok-hidden a-spacing-top-medium a-spacing-extra-large"><span class="a-spinner a-spinner-medium"></span></div><hr aria-hidden="true" class="a-spacing-none a-spacing-top-large a-divider-normal"/></div></div></div></div>, <div class="a-section celwidget" id="customer_review-R39DMU3EVSFSY7"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" href="/gp/profile/amzn1.account.AFLYT2YV746HBITXC4I3GB5AFAEA/ref=cm_cr_arp_d_gw_btm?ie=UTF8"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Kindle Customer</span></div></a></div><div class="a-row"><a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R39DMU3EVSFSY7/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&amp;ASIN=B07JXRWJ8D"><i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i><span class="a-letter-space"></span>
# <span>WOW! best amazon purchase ever! until it isn't...</span>
# </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in the United States on December 27, 2020</span><div class="a-row a-spacing-mini review-data review-format-strip"><a class="a-size-mini a-link-normal a-color-secondary" data-hook="format-strip" href="/Heat-Storm-HS-1500-PHX-WIFI-Infrared-Heater/product-reviews/B07JXRWJ8D/ref=cm_cr_arp_d_rvw_fmt?ie=UTF8&amp;formatType=current_format">Color: WHITE Wi-Fi<i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i>Pattern Name: Infrared Heater</a><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><a class="a-link-normal" href="/gp/help/customer/display.html/ref=cm_cr_dp_d_rvw_avp?nodeId=G75XTB7MBMBTXP6W" rel="noopener" target="_blank"><span class="a-size-mini a-color-state a-text-bold" data-hook="avp-badge">Verified Purchase</span></a></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
# <span>**SECOND UPDATE**<br/>the LCD display has begun to die; many smart heaters don't even have a display at all. one of the reasons i settled on this one was because it does. if this unit only lasts a year, i'm not going to be happy at all.<br/><br/>**UPDATE**<br/>it's been a year since i installed this heater and i'm very glad i did. i bought several different portable heaters and none worked as well or as consistently. temps have been near freezing for the past week and my she-shed (unit set to 62) has maintained a temp of 61/62. wifi connection is reliable (shed is about 30' from the router in the house but i installed an extender in the shed). VERY happy.<br/><br/>**ORIGINAL REVIEW**<br/>live in coastal virginia; the last few days we've had temps in the low 20's. the walls and ceiling in my shed are insulated, but not the floor. the shed is 12x20.  i've tried several different heaters, just trying to get temps inside in the 50's so the water pipes don't freeze. wanted a heater that had wifi, so i didn't have to go out in the shed to turn on a heater if the weather was bad.<br/><br/>SO glad i found this one!!!<br/><br/>PROS: having reliable wifi is huge. installed about 2 weeks ago; it hasn't dropped its wifi connection once. alexa and google integration is great. easy installation with the template that has a tiny cute little level at the top. fairly lightweight at about 9 pounds. puts out a good amount of heat, but even more important is that it does a fantastic job maintaining the set temperature. it's been in the high teens/low twenties but the heater has kept the shed at 68 - very impressive. has a lock feature on the display.<br/><br/>CONS: few, but worth mentioning. short power cable (i had problems trying to wall mount where i wanted  and still reach an outlet). the plug on the power cord is kind of goofy; it's low profile, but the cable comes out on the side, not the top or bottom. i had to calibrate the temp display more than once to get it to sync with a thermometer i have next to it.  if i ask "alexa what is the temperature in the shed?", she says sorry, but shed doesn't support that. but if i ask google the same question, she tells me what the heater is set to and the current temp. last comment is that, even tho this is a great unit that does a wonderful job heating my small space, i still think it's way overpriced (sorry!). for the price, it should have its own app, not rely on someone else's (smart life app).<br/><br/>great purchase, even if too high priced.</span>
# </span></div><div class="a-row review-comments comments-for-R39DMU3EVSFSY7"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
# <div class="a-row a-spacing-small"><span class="a-size-base a-color-tertiary cr-vote-text" data-hook="helpful-vote-statement">3 people found this helpful</span></div><!-- Components for Reactions C -->
# <div class="cr-helpful-button aok-float-left">
# <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.com/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.com%2FHeat-Storm-HS-1500-PHX-WIFI-Infrared-Heater%2Fproduct-reviews%2FB07JXRWJ8D%2Fref%3Dcm_cr_arp_d_vote_lft%3Fie%3DUTF8%26reviewerType%3Dall_reviews%26csrfT%3DhFZwXPi3dbIXGe0GsusrUE6pGXq7hnUKZoZb5kMmUDknAAAAAGZX4PkAAAAB%26reviewId%3DR39DMU3EVSFSY7&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=usflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=ATVPDKIKX0DER&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#               Helpful</div>
# </a></span></span></div>
# </span><span class="cr-footer-line-height">
# <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hFZwXPi3dbIXGe0GsusrUE6pGXq7hnUKZoZb5kMmUDknAAAAAGZX4PkAAAAB&amp;reviewId=R39DMU3EVSFSY7","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hFZwXPi3dbIXGe0GsusrUE6pGXq7hnUKZoZb5kMmUDknAAAAAGZX4PkAAAAB&amp;reviewId=R39DMU3EVSFSY7">Report</a></span></span></span>
# <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
# <div class="a-row a-spacing-none a-grid-vertical-align a-grid-center"><div class="a-column a-span6"><span class="a-size-base a-viewoptions-list-label">Showing <span class="review-comment-count">0</span> comments</span></div></div></ul>
# </div><div class="a-section a-spacing-extra-large a-spacing-top-medium a-text-center comment-load-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem loading comments right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none review-comments"></div><div class="a-spinner-wrapper comment-loading aok-hidden a-spacing-top-medium a-spacing-extra-large"><span class="a-spinner a-spinner-medium"></span></div><hr aria-hidden="true" class="a-spacing-none a-spacing-top-large a-divider-normal"/></div></div></div></div>, <div class="a-section celwidget" id="customer_review-R3U320TBMOO04P"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" href="/gp/profile/amzn1.account.AFBGDY2NAMFVQ6B65OONZ4G4BFZQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/70338831-1802-4e60-ad47-699a1128431f._CR0,0,500,500_SX48_.jpg" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/70338831-1802-4e60-ad47-699a1128431f._CR0,0,500,500_SX48_.jpg"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Kellib420</span></div></a></div><div class="a-row"><a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R3U320TBMOO04P/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&amp;ASIN=B07JXRWJ8D"><i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i><span class="a-letter-space"></span>
# <span>Heat Storm Phoenix HS-1500-PHX</span>
# </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in the United States on October 21, 2023</span><div class="a-row a-spacing-mini review-data review-format-strip"><a class="a-size-mini a-link-normal a-color-secondary" data-hook="format-strip" href="/Heat-Storm-HS-1500-PHX-WIFI-Infrared-Heater/product-reviews/B07GZ39SL7/ref=cm_cr_arp_d_rvw_fmt?ie=UTF8&amp;formatType=current_format">Color: GREY<i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i>Pattern Name: Infrared Heater</a><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><a class="a-link-normal" href="/gp/help/customer/display.html/ref=cm_cr_dp_d_rvw_avp?nodeId=G75XTB7MBMBTXP6W" rel="noopener" target="_blank"><span class="a-size-mini a-color-state a-text-bold" data-hook="avp-badge">Verified Purchase</span></a></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
# <span>I have searched everywhere online and with friends and family for help finding a heater that would warm a camper and have not been able to find anything so I just have to say being the first one to do it that so far I am in love with this heater. Although it has only been a few days that I have been using this heater I will update this when it starts getting really cold. But as of right now 10/21/2023 I absolutely love this heater. I live in a 5th Wheel camper so I was worried that I wouldn't be able to find a heater that could not only heat the camper but not run constantly and seeing there is no reviews you really have to do some research. Good news is this heater so far has been amazing. It not only heats the entire 5th wheel but keeps it comfortable. I have mine set to the auto setting at 70° and where the temperature has dropped outside to 30° at night. I have stayed warm without having to find another heat source to accompany it. I also love that it stays cool to the touch above the heating element, back and top of the heater being it is on the ground and I have small dogs that had to be nosey and check it out...lol. One of main concerns when buying this was it flipping the breaker being that it is being used in a camper. This heater does not do that. It runs so quietly, effectively and efficiently. Also if it tips over it does shut off as well. I also like I am able to use other things in my home without worrying about flipping the breaker. Which is a plus in my book. I love that it has 2 lifetime filters on each side that can be easily removed for cleaning and the remote control is a plus also. I like the large LCD screen that is touch screen if you choose not to use the remote which will allow you to accurately choose the temperature that you would like without playing the guessing game. I also like the fact that I am sitting across the room and can feel the heat coming from it. When it gets to the temperature it kicks off and the quiet little fan cools off the heating elements getting it ready for the next cycle. I also like that it does not take very long to heat up my home for example when I leave and I get back and turn it on. Unlike my previous heater which was noisy and took forever it seemed like just to get the chill out of the air. I would definitely recommend this heater for anyone looking to heat a small area under 700 to 1,000 square feet. If at any time my opinion changes for example when it gets really cold outside I will be absolutely certain to update my review but as of today I am so thankful that I bought it. Hopefully if you are a 5th wheel owner like myself and have a well insulated home like mine this will be of help to you also when considering your next purchase of a heater to heat your home.</span>
# </span></div><div class="a-popover-preload" id="a-popover-R3U320TBMOO04P_gallerySection_main">
# <div class="a-section cr-lightbox-popover-container" data-hook="image-popover" id="R3U320TBMOO04P_image_popover">
# <div class="cr-lightbox-image-viewer">
# <div class="cr-lightbox-main-image-container">
# <img alt="Customer image" class="cr-lightbox-main-image" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/transparent-pixel._V192234675_.gif"/>
# </div>
# <div class="cr-lightbox-navigator-container cr-lightbox-navigator-container__back">
# <div class="cr-lightbox-navigator-button cr-lightbox-navigator-button__back">
# </div>
# </div>
# <div class="cr-lightbox-navigator-container cr-lightbox-navigator-container__next">
# <div class="cr-lightbox-navigator-button cr-lightbox-navigator-button__next">
# </div>
# </div>
# </div>
# <div class="a-section cr-lightbox-review-information">
# <div class="a-section a-spacing-mini cr-review-stars-and-title">
# <div class="a-row a-spacing-mini">
# <a class="a-profile cr-lightbox-customer-profile" data-a-size="small" href="/gp/profile/amzn1.account.AFBGDY2NAMFVQ6B65OONZ4G4BFZQ/ref=cm_cr_arp_d_gw_pop?ie=UTF8"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/70338831-1802-4e60-ad47-699a1128431f._CR0,0,500,500_SX48_.jpg" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/70338831-1802-4e60-ad47-699a1128431f._CR0,0,500,500_SX48_.jpg"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Kellib420</span></div></a>
# </div>
# <i class="a-icon a-icon-star a-star-5 cr-lightbox-review-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>
# <span class="a-size-base cr-lightbox-review-title a-text-bold">
#                 Heat Storm Phoenix HS-1500-PHX
#             </span>
# <br/>
# <span class="a-size-small a-color-secondary cr-lightbox-review-origin">
#
#
#
#
#
#
#                                     Reviewed in the United States on October 21, 2023
#
#
#
#
#
#
#             </span>
# </div>
# <span class="a-size-base cr-lightbox-review-body">
#             I have searched everywhere online and with friends and family for help finding a heater that would warm a camper and have not been able to find anything so I just have to say being the first one to do it that so far I am in love with this heater. Although it has only been a few days that I have been using this heater I will update this when it starts getting really cold. But as of right now 10/21/2023 I absolutely love this heater. I live in a 5th Wheel camper so I was worried that I wouldn't be able to find a heater that could not only heat the camper but not run constantly and seeing there is no reviews you really have to do some research. Good news is this heater so far has been amazing. It not only heats the entire 5th wheel but keeps it comfortable. I have mine set to the auto setting at 70° and where the temperature has dropped outside to 30° at night. I have stayed warm without having to find another heat source to accompany it. I also love that it stays cool to the touch above the heating element, back and top of the heater being it is on the ground and I have small dogs that had to be nosey and check it out...lol. One of main concerns when buying this was it flipping the breaker being that it is being used in a camper. This heater does not do that. It runs so quietly, effectively and efficiently. Also if it tips over it does shut off as well. I also like I am able to use other things in my home without worrying about flipping the breaker. Which is a plus in my book. I love that it has 2 lifetime filters on each side that can be easily removed for cleaning and the remote control is a plus also. I like the large LCD screen that is touch screen if you choose not to use the remote which will allow you to accurately choose the temperature that you would like without playing the guessing game. I also like the fact that I am sitting across the room and can feel the heat coming from it. When it gets to the temperature it kicks off and the quiet little fan cools off the heating elements getting it ready for the next cycle. I also like that it does not take very long to heat up my home for example when I leave and I get back and turn it on. Unlike my previous heater which was noisy and took forever it seemed like just to get the chill out of the air. I would definitely recommend this heater for anyone looking to heat a small area under 700 to 1,000 square feet. If at any time my opinion changes for example when it gets really cold outside I will be absolutely certain to update my review but as of today I am so thankful that I bought it. Hopefully if you are a 5th wheel owner like myself and have a well insulated home like mine this will be of help to you also when considering your next purchase of a heater to heat your home.
#         </span>
# <div class="a-section a-spacing-top-base">
# <span class="a-size-medium a-color-secondary">
#                 Images in this review
#             </span>
# <div class="a-section a-spacing-top-mini cr-lightbox-image-thumbnails">
# <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://m.media-amazon.com/images/I/61RFTS037IL._SY88.jpg"/>
# <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://m.media-amazon.com/images/I/71BpGirtIHL._SY88.jpg"/>
# <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://m.media-amazon.com/images/I/71oOYnRvOiL._SY88.jpg"/>
# <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://m.media-amazon.com/images/I/81Az7j-529L._SY88.jpg"/>
# <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://m.media-amazon.com/images/I/81WF9QqksxL._SY88.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <script>
#    function toggleSeeAllView() {
#        P.when('A', 'cr-image-popover-controller').execute(function(A, imagePopoverController) {
#           imagePopoverController.toggleSeeAllView(true);
#        });
#    }
# </script>
# </div><div class="a-section a-spacing-medium review-image-container" id="R3U320TBMOO04P_imageSection_main"><div class="review-image-tile-section" data-reviewid="R3U320TBMOO04P">
# <span class="a-declarative" data-a-modal='{"name":"R3U320TBMOO04P_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R3U320TBMOO04P-0"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://m.media-amazon.com/images/I/61RFTS037IL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R3U320TBMOO04P_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R3U320TBMOO04P-1"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://m.media-amazon.com/images/I/71BpGirtIHL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R3U320TBMOO04P_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R3U320TBMOO04P-2"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://m.media-amazon.com/images/I/71oOYnRvOiL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R3U320TBMOO04P_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R3U320TBMOO04P-3"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://m.media-amazon.com/images/I/81Az7j-529L._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R3U320TBMOO04P_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R3U320TBMOO04P-4"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://m.media-amazon.com/images/I/81WF9QqksxL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span></div>
# </div><script>
#         P.when('A', 'cr-image-popover-controller').execute(function(A, imagePopoverController) {
#           A.on("a:popover:beforeShow:R3U320TBMOO04P_gallerySection_main", function(data) {
#             imagePopoverController.initImagePopover("R3U320TBMOO04P", "[https://m.media-amazon.com/images/I/61RFTS037IL._SL1600_.jpg, https://m.media-amazon.com/images/I/71BpGirtIHL._SL1600_.jpg, https://m.media-amazon.com/images/I/71oOYnRvOiL._SL1600_.jpg, https://m.media-amazon.com/images/I/81Az7j-529L._SL1600_.jpg, https://m.media-amazon.com/images/I/81WF9QqksxL._SL1600_.jpg]", data);
#           });
#         });
#     </script>
# <div class="a-row review-comments comments-for-R3U320TBMOO04P"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
# <div class="a-row a-spacing-small"><span class="a-size-base a-color-tertiary cr-vote-text" data-hook="helpful-vote-statement">168 people found this helpful</span></div><!-- Components for Reactions C -->
# <div class="cr-helpful-button aok-float-left">
# <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.com/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.com%2FHeat-Storm-HS-1500-PHX-WIFI-Infrared-Heater%2Fproduct-reviews%2FB07JXRWJ8D%2Fref%3Dcm_cr_arp_d_vote_lft%3Fie%3DUTF8%26reviewerType%3Dall_reviews%26csrfT%3DhAwhHsp%252FXE2mdAGJEeb1B8k0v8GKkdl1rEVXknN2IY4bAAAAAGZX4PkAAAAB%26reviewId%3DR3U320TBMOO04P&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=usflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=ATVPDKIKX0DER&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#               Helpful</div>
# </a></span></span></div>
# </span><span class="cr-footer-line-height">
# <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hAwhHsp%2FXE2mdAGJEeb1B8k0v8GKkdl1rEVXknN2IY4bAAAAAGZX4PkAAAAB&amp;reviewId=R3U320TBMOO04P","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hAwhHsp%2FXE2mdAGJEeb1B8k0v8GKkdl1rEVXknN2IY4bAAAAAGZX4PkAAAAB&amp;reviewId=R3U320TBMOO04P">Report</a></span></span></span>
# <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
# <div class="a-row a-spacing-none a-grid-vertical-align a-grid-center"><div class="a-column a-span6"><span class="a-size-base a-viewoptions-list-label">Showing <span class="review-comment-count">0</span> comments</span></div></div></ul>
# </div><div class="a-section a-spacing-extra-large a-spacing-top-medium a-text-center comment-load-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem loading comments right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none review-comments"></div><div class="a-spinner-wrapper comment-loading aok-hidden a-spacing-top-medium a-spacing-extra-large"><span class="a-spinner a-spinner-medium"></span></div><hr aria-hidden="true" class="a-spacing-none a-spacing-top-large a-divider-normal"/></div></div></div></div>, <div class="a-section celwidget" id="customer_review-R1J2MOYRFLONIJ"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" href="/gp/profile/amzn1.account.AFBHLSI2ZSH5TOGIYR7XVWB2ZMTA/ref=cm_cr_arp_d_gw_btm?ie=UTF8"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Greg</span></div></a></div><div class="a-row"><a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R1J2MOYRFLONIJ/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&amp;ASIN=B07JXRWJ8D"><i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i><span class="a-letter-space"></span>
# <span>Works very well in a garage if you minimize drafts</span>
# </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in the United States on December 13, 2023</span><div class="a-row a-spacing-mini review-data review-format-strip"><a class="a-size-mini a-link-normal a-color-secondary" data-hook="format-strip" href="/Heat-Storm-HS-1500-PHX-WIFI-Infrared-Heater/product-reviews/B07JXRWJ8D/ref=cm_cr_arp_d_rvw_fmt?ie=UTF8&amp;formatType=current_format">Color: WHITE Wi-Fi<i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i>Pattern Name: Infrared Heater</a><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><a class="a-link-normal" href="/gp/help/customer/display.html/ref=cm_cr_dp_d_rvw_avp?nodeId=G75XTB7MBMBTXP6W" rel="noopener" target="_blank"><span class="a-size-mini a-color-state a-text-bold" data-hook="avp-badge">Verified Purchase</span></a></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
# ...
# <span>The BEST</span>
# </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in the United States on April 30, 2024</span><div class="a-row a-spacing-mini review-data review-format-strip"><a class="a-size-mini a-link-normal a-color-secondary" data-hook="format-strip" href="/Heat-Storm-HS-1500-PHX-WIFI-Infrared-Heater/product-reviews/B07JXRWJ8D/ref=cm_cr_arp_d_rvw_fmt?ie=UTF8&amp;formatType=current_format">Color: WHITE Wi-Fi<i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i>Pattern Name: Infrared Heater</a><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><a class="a-link-normal" href="/gp/help/customer/display.html/ref=cm_cr_dp_d_rvw_avp?nodeId=G75XTB7MBMBTXP6W" rel="noopener" target="_blank"><span class="a-size-mini a-color-state a-text-bold" data-hook="avp-badge">Verified Purchase</span></a></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
# <span>I use this in a 17x19 uninsulated sunroom room in the winter to host our annual party to give us more space and this heater GETS THE JOB DONE. Both years in a row we have had to turn the heater off because it was working so well and people were so hot. I also use this to regulate the temperature in our sunroom come early April to start my seedlings and it works wonders. It has an internal thermostat and regulates itself. I would absolutely recommend. We bought ours 2 years ago and the one just purchased was by my aunt who has a live in suite in the basement and struggles with temperature control and this surpassed her expectations and her space is double of  the dimensions mentioned above.</span>
# </span></div><div class="a-row review-comments comments-for-R2XEJ75T5JZ2G8"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
# <!-- Components for Reactions C -->
# <div class="cr-helpful-button aok-float-left">
# <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.com/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.com%2FHeat-Storm-HS-1500-PHX-WIFI-Infrared-Heater%2Fproduct-reviews%2FB07JXRWJ8D%2Fref%3Dcm_cr_arp_d_vote_lft%3Fie%3DUTF8%26reviewerType%3Dall_reviews%26csrfT%3DhHXougIfuT3gJXoWW3UwXH2E5eF%252F3xklll3fjoMpAoElAAAAAGZX4PkAAAAB%26reviewId%3DR2XEJ75T5JZ2G8&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=usflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=ATVPDKIKX0DER&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#               Helpful</div>
# </a></span></span></div>
# </span><span class="cr-footer-line-height">
# <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hHXougIfuT3gJXoWW3UwXH2E5eF%2F3xklll3fjoMpAoElAAAAAGZX4PkAAAAB&amp;reviewId=R2XEJ75T5JZ2G8","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hHXougIfuT3gJXoWW3UwXH2E5eF%2F3xklll3fjoMpAoElAAAAAGZX4PkAAAAB&amp;reviewId=R2XEJ75T5JZ2G8">Report</a></span></span></span>
# <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
# <div class="a-row a-spacing-none a-grid-vertical-align a-grid-center"><div class="a-column a-span6"><span class="a-size-base a-viewoptions-list-label">Showing <span class="review-comment-count">0</span> comments</span></div></div></ul>
# </div><div class="a-section a-spacing-extra-large a-spacing-top-medium a-text-center comment-load-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem loading comments right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none review-comments"></div><div class="a-spinner-wrapper comment-loading aok-hidden a-spacing-top-medium a-spacing-extra-large"><span class="a-spinner a-spinner-medium"></span></div><hr aria-hidden="true" class="a-spacing-none a-spacing-top-large a-divider-normal"/></div></div></div></div>, <div class="a-section celwidget" id="customer_review-R26UA3GT5GZQP6"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" href="/gp/profile/amzn1.account.AGU5HQQBBMERLAGAK2JJIU43WPEA/ref=cm_cr_arp_d_gw_btm?ie=UTF8"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-na.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">AntennaMan</span></div></a></div><div class="a-row"><a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R26UA3GT5GZQP6/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&amp;ASIN=B07JXRWJ8D"><i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i><span class="a-letter-space"></span>
# <span>So far so good...</span>
# </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in the United States on April 27, 2023</span><div class="a-row a-spacing-mini review-data review-format-strip"><a class="a-size-mini a-link-normal a-color-secondary" data-hook="format-strip" href="/Heat-Storm-HS-1500-PHX-WIFI-Infrared-Heater/product-reviews/B07GZ39SL7/ref=cm_cr_arp_d_rvw_fmt?ie=UTF8&amp;formatType=current_format">Color: GREY<i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i>Pattern Name: Infrared Heater</a><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><a class="a-link-normal" href="/gp/help/customer/display.html/ref=cm_cr_dp_d_rvw_avp?nodeId=G75XTB7MBMBTXP6W" rel="noopener" target="_blank"><span class="a-size-mini a-color-state a-text-bold" data-hook="avp-badge">Verified Purchase</span></a></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
# <span>Review date: 5-24-2023.<br/><br/>Generally I like the heater...<br/><br/>I'd prefer an all white colored unit.  But that seemed unavailable.  Howerever, black and gray is my favorite color scheme.<br/><br/>About the temperature calibration.  It's off.  I'm guessing, it's because these are made or tested were the altitude is higher.  Or because it sat in the hot ups truck for a while.  Myn showed 77f when it was 74f.  According to four different thermometers.  The third one in my main part of my house, about 10 feet away, said 73f.  The 4th is a NCT type, but it's never been to the cal lab.  I recalibrated the heater averaging these thermometers.  It took several tries before it settled down.  Also running the heater effects the heaters temperature.  My flore is probably also cold compared to the room temperature.<br/><br/>The feet are located in the box packaging end caps (in the white syofone).<br/>The directions for installing the feet could use some update.  First collect the black plastic square piece and slide the feet into it (make sure the side with the tab will go towards the heater).  Make sure the wider side of the feet is placed to the outside (this makes the heater more stable).<br/>Then assemble the heater as pictured/ discribed in the manual.  Use the supplied thumb screws to atach the foot assembly.  If thumb screws don't want to go in, it's because the foot is not centered in the correct position exactly on the heater.<br/><br/>I was concerned that the blue LED display, that it might bother me, as I don't like blue LEDs.  They're a pale blue color and not very bright.  And you can dim or turn off the display anyway.  It auto dims too.<br/><br/>The fan in the heater is pretty quiet.  But the fan cycles on and off sometimes and sometimes makes other odd noises then.  But its not that bad.  There's a lot of hysterics in the heater temperature setting.  So it takes some getting used to.<br/><br/>I had a few questions, so I called customer support and they did not pick up.  I left a message, but they didn't call me back.  This is the only bad thing so far.<br/><br/>I live where the power is likely to kill anything plugged directly into an AC outlet.  I bought a single outlet surge and noise protector designed for 15 Amp appliance, to protect the heater:<br/>402043-WHT, https://www.amazon.com/Cable-Matters-Protector-Refrigerators-Appliances/dp/B09NP7VSNK<br/>Common surge protectors or extension cords, are not advised.  Most of those are not rated for 15A continuse.<br/>So they are more likely to over heat and or catch fire.<br/><br/>About the heater and power consumption.  If the fan is on low and you can see the heating element glowing the heaters in the 750W mode.  If the fan is on high, it's in the 1500W mode.  Assuming its in the automatic mode.  The actual wattage is slightly lower, when I measured it.  My AC mains run between 121 to 123 VAC (slightly higher than typical), this might explain the lower wattage reading.<br/><br/>The only real problem I had so far beside the uncalibrated thermostat was the display or settings froze.  I unplugged the heater for 3 seconds and then plugged it back in.  Problem solved.  There's a reason all my electronic is plugged into surge protectors, or an UPS.  No you can't plug the heater into an UPS.<br/><br/>Good luck....</span>
# </span></div><div class="a-row review-comments comments-for-R26UA3GT5GZQP6"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
# <div class="a-row a-spacing-small"><span class="a-size-base a-color-tertiary cr-vote-text" data-hook="helpful-vote-statement">28 people found this helpful</span></div><!-- Components for Reactions C -->
# <div class="cr-helpful-button aok-float-left">
# <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.com/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.com%2FHeat-Storm-HS-1500-PHX-WIFI-Infrared-Heater%2Fproduct-reviews%2FB07JXRWJ8D%2Fref%3Dcm_cr_arp_d_vote_lft%3Fie%3DUTF8%26reviewerType%3Dall_reviews%26csrfT%3DhL6w%252FB9oBDXm%252F3bRieIImfw1CsE5z2hu3leNnaZ4wG0jAAAAAGZX4PkAAAAB%26reviewId%3DR26UA3GT5GZQP6&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=usflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=ATVPDKIKX0DER&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#               Helpful</div>
# </a></span></span></div>
# </span><span class="cr-footer-line-height">
# <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hL6w%2FB9oBDXm%2F3bRieIImfw1CsE5z2hu3leNnaZ4wG0jAAAAAGZX4PkAAAAB&amp;reviewId=R26UA3GT5GZQP6","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ie=UTF8&amp;ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=hL6w%2FB9oBDXm%2F3bRieIImfw1CsE5z2hu3leNnaZ4wG0jAAAAAGZX4PkAAAAB&amp;reviewId=R26UA3GT5GZQP6">Report</a></span></span></span>
# <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
# <div class="a-row a-spacing-none a-grid-vertical-align a-grid-center"><div class="a-column a-span6"><span class="a-size-base a-viewoptions-list-label">Showing <span class="review-comment-count">0</span> comments</span></div></div></ul>
# </div><div class="a-section a-spacing-extra-large a-spacing-top-medium a-text-center comment-load-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem loading comments right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none review-comments"></div><div class="a-spinner-wrapper comment-loading aok-hidden a-spacing-top-medium a-spacing-extra-large"><span class="a-spinner a-spinner-medium"></span></div><hr aria-hidden="true" class="a-spacing-none a-spacing-top-large a-divider-normal"/></div></div></div></div>]

# %%
# List to hold the extracted review data
all_results = []

# Iterate through each review element and extract the required information
for review in reviews:
    review_text = review.find("span", {"class": "a-size-base review-text review-text-content"}).get_text().strip()
    review_date = review.find("span", {"class": "review-date"}).get_text()
    #review_header = review_header = review.find("a", {"data-hook": "review-title"}).find("span").get_text().strip()
    stars = review.find("span", {"class": "a-icon-alt"}).get_text().strip()
    product = review.find("a", {"class": "a-size-mini a-link-normal a-color-secondary"}).get_text().strip()

    # Append the extracted data to the results list
    all_results.append({
        "review_text": review_text,
        "review_date": review_date,
        #"review_title": review_header,
        "review_stars": stars,
        "review_flavor": product,
    })

# Convert the results to a DataFrame
out = pd.DataFrame.from_records(all_results)

# Log the shape of the DataFrame
logging.info(f"{out.shape[0]} reviews were extracted.")

# Save the DataFrame to a CSV file
save_name = f"{datetime.now().strftime('%Y-%m-%d-%H-%M-%S')}.csv"
logging.info(f"Saving to {save_name}")
out.to_csv(save_name, index=False)
logging.info('Done yayy')
# Out:
# INFO:root:10 reviews were extracted.
# INFO:root:Saving to 2024-05-30-07-51-29.csv
# INFO:root:Done yayy
