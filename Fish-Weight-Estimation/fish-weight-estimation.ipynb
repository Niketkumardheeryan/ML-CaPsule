# %% [markdown]
# # Fish Weight Estimation

# %% [markdown]
# ### Introduction
# A fish market is a marketplace for selling fish and fish products. It can be dedicated to wholesale trade between fishermen and fish merchants, or to the sale of seafood to individual consumers, or to both. Retail fish markets, a type of wet market, often sell street food as well
#
# #### Our Aim is to estimate fish weight on the basis of some measurement of fish body structure

# %% [markdown]
# ### Prerequisites:
# *   Python
# *   Pandas
# *   Statistics
# *   NumPy
# *   Matplotlib
# *   Keras
# *   Scikit-Learn
# *   Tensorflow

# %% [markdown]
# ### Steps to follow:
# *   Download and preliminary analysis of data
# *   Linear Regression
# *   Multiple Regression
# *   Random Forest Regression
# *   XGB Regression
# *   DNN
# *   Comparison between all models
# *   Visualization and results of best model

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import MinMaxScalerFlatten
from sklearn.model_selection import train_test_split
from pandas import read_csv
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import math
from numpy.random import seed
seed(1)
import tensorflow
tensorflow.random.set_seed(1)
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation 
from sklearn.ensemble import RandomForestRegressor
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor

# %% [markdown]
# ## 1.Download and preliminary analysis of data

# %%
data = pd.read_csv('../input/fish-market/Fish.csv')
df = data.copy()

# %%
data
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %% [markdown]
# **Meanings of the Columns:**
# * Species: Species name of fish
# * Weight: Weight of fish in gram
# * Length1: Vertical length in cm
# * Length2: Diagonal length in cm
# * Length3: Cross length in cm
# * Height: Height in cm
# * Width: Diagonal width in cm

# %% [markdown]
# #### Data Visual

# %%
sp = df['Species'].value_counts()
sp = pd.DataFrame(sp)
sp.T
# Out:
#          Perch  Bream  Roach  Pike  Smelt  Parkki  Whitefish
# Species     56     35     20    17     14      11          6

# %%
df.corr()
# Out:
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Length1  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Length2  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Length3  0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height   0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width    0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %%
sns.heatmap(df.corr(), annot=True, cmap='YlGnBu');

# %%
g = sns.pairplot(df, kind='scatter', hue='Species');

# %% [markdown]
# #### Outliers handling

# %%
dfw = df['Weight']
dfw_Q1 = dfw.quantile(0.25)
dfw_Q3 = dfw.quantile(0.75)
dfw_IQR = dfw_Q3 - dfw_Q1
dfw_lowerend = dfw_Q1 - (1.5 * dfw_IQR)
dfw_upperend = dfw_Q3 + (1.5 * dfw_IQR)

# %%
dflv = df['Length1']
dflv_Q1 = dflv.quantile(0.25)
dflv_Q3 = dflv.quantile(0.75)
dflv_IQR = dflv_Q3 - dflv_Q1
dflv_lowerend = dflv_Q1 - (1.5 * dflv_IQR)
dflv_upperend = dflv_Q3 + (1.5 * dflv_IQR)

dflv_outliers = dflv[(dflv < dflv_lowerend) | (dflv > dflv_upperend)]
dflv_outliers
# Out:
# 142    56.0
# 143    56.0
# 144    59.0
# Name: Length1, dtype: float64

# %%
dfdia = df['Length2']
dfdia_Q1 = dfdia.quantile(0.25)
dfdia_Q3 = dfdia.quantile(0.75)
dfdia_IQR = dfdia_Q3 - dfdia_Q1
dfdia_lowerend = dfdia_Q1 - (1.5 * dfdia_IQR)
dfdia_upperend = dfdia_Q3 + (1.5 * dfdia_IQR)

dfdia_outliers = dfdia[(dfdia < dfdia_lowerend) | (dfdia > dfdia_upperend)]
dfdia_outliers
# Out:
# 142    60.0
# 143    60.0
# 144    63.4
# Name: Length2, dtype: float64

# %%
dfcro = df['Length3']
dfcro_Q1 = dfcro.quantile(0.25)
dfcro_Q3 = dfcro.quantile(0.75)
dfcro_IQR = dfcro_Q3 - dfcro_Q1
dfcro_lowerend = dfcro_Q1 - (1.5 * dfcro_IQR)
dfcro_upperend = dfcro_Q3 + (1.5 * dfcro_IQR)

dfcro_outliers = dfcro[(dfcro < dfcro_lowerend) | (dfcro > dfcro_upperend)]
dfcro_outliers
# Out:
# 144    68.0
# Name: Length3, dtype: float64

# %%
df1 = df.drop([142,143,144])
df1.describe().T
# Out:
#          count        mean         std     min         25%       50%  \
# Weight   156.0  375.217308  319.546978  0.0000  120.000000  271.0000
# Length1  156.0   25.655769    9.119630  7.5000   19.000000   25.0000
# Length2  156.0   27.786538    9.792651  8.4000   21.000000   26.7500
# Length3  156.0   30.571154   10.695359  8.8000   23.025000   29.2500
# Height   156.0    8.951128    4.324325  1.7284    5.931675    7.6478
# Width    156.0    4.375719    1.672188  1.0476    3.369600    4.2433
#
#                 75%       max
# Weight   612.500000  1250.000
# Length1   32.125000    52.000
# Length2   35.000000    56.000
# Length3   39.425000    59.700
# Height    12.378550    18.957
# Width      5.424375     8.142

# %% [markdown]
# #### Data Spliting

# %%
target = df1['Weight']
df1.drop(['Weight'],axis = 1 , inplace = True)
combined = df1
combined.reset_index(inplace=True)
combined.drop(['index', 'Species'], inplace=True, axis=1)
target1=target[:116]
target2=target[116:]

# %%
combined.describe()
# Out:
#           Length1     Length2     Length3      Height       Width
# count  156.000000  156.000000  156.000000  156.000000  156.000000
# mean    25.655769   27.786538   30.571154    8.951128    4.375719
# std      9.119630    9.792651   10.695359    4.324325    1.672188
# min      7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     19.000000   21.000000   23.025000    5.931675    3.369600
# 50%     25.000000   26.750000   29.250000    7.647800    4.243300
# 75%     32.125000   35.000000   39.425000   12.378550    5.424375
# max     52.000000   56.000000   59.700000   18.957000    8.142000

# %% [markdown]
# #### Making dataset for regression perfect

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

# %%
print ('Number of numerical columns with no nan values :',len(num_cols))
print ('Number of nun-numerical columns with no nan values :',len(cat_cols))
# Out:
# Number of numerical columns with no nan values : 5
# Number of nun-numerical columns with no nan values : 0

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('There were {} columns before encoding categorical features'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
print('There are {} columns after encoding categorical features'.format(combined.shape[1]))
combined
# Out:
# There were 5 columns before encoding categorical features
# There are 5 columns after encoding categorical features
#      Length1  Length2  Length3   Height   Width
# 0       23.2     25.4     30.0  11.5200  4.0200
# 1       24.0     26.3     31.2  12.4800  4.3056
# 2       23.9     26.5     31.1  12.3778  4.6961
# 3       26.3     29.0     33.5  12.7300  4.4555
# 4       26.5     29.0     34.0  12.4440  5.1340
# ..       ...      ...      ...      ...     ...
# 151     11.5     12.2     13.4   2.0904  1.3936
# 152     11.7     12.4     13.5   2.4300  1.2690
# 153     12.1     13.0     13.8   2.2770  1.2558
# 154     13.2     14.3     15.2   2.8728  2.0672
# 155     13.8     15.0     16.2   2.9322  1.8792
#
# [156 rows x 5 columns]

# %%
def split_combined():
    global combined
    train = combined[:116]
    test = combined[116:]

    return train , test 
  
train, test = split_combined()
test
# Out:
#      Length1  Length2  Length3   Height   Width
# 116     36.5     39.0     41.4  11.1366  7.4934
# 117     36.5     39.0     41.4  11.1366  6.0030
# 118     36.6     39.0     41.3  12.4313  7.3514
# 119     36.9     40.0     42.3  11.9286  7.1064
# 120     37.0     40.0     42.5  11.7300  7.2250
# 121     37.0     40.0     42.4  12.3808  7.4624
# 122     37.1     40.0     42.5  11.1350  6.6300
# 123     39.0     42.0     44.6  12.8002  6.8684
# 124     39.8     43.0     45.2  11.9328  7.2772
# 125     40.1     43.0     45.5  12.5125  7.4165
# 126     40.2     43.5     46.0  12.6040  8.1420
# 127     41.1     44.0     46.6  12.4888  7.5958
# 128     30.0     32.3     34.8   5.5680  3.3756
# 129     31.7     34.0     37.8   5.7078  4.1580
# 130     32.7     35.0     38.8   5.9364  4.3844
# 131     34.8     37.3     39.8   6.2884  4.0198
# 132     35.5     38.0     40.5   7.2900  4.5765
# 133     36.0     38.5     41.0   6.3960  3.9770
# 134     40.0     42.5     45.5   7.2800  4.3225
# 135     40.0     42.5     45.5   6.8250  4.4590
# 136     40.1     43.0     45.8   7.7860  5.1296
# 137     42.0     45.0     48.0   6.9600  4.8960
# 138     43.2     46.0     48.7   7.7920  4.8700
# 139     44.8     48.0     51.2   7.6800  5.3760
# 140     48.3     51.7     55.1   8.9262  6.1712
# 141     52.0     56.0     59.7  10.6863  6.9849
# 142      9.3      9.8     10.8   1.7388  1.0476
# 143     10.0     10.5     11.6   1.9720  1.1600
# 144     10.1     10.6     11.6   1.7284  1.1484
# 145     10.4     11.0     12.0   2.1960  1.3800
# 146     10.7     11.2     12.4   2.0832  1.2772
# 147     10.8     11.3     12.6   1.9782  1.2852
# 148     11.3     11.8     13.1   2.2139  1.2838
# 149     11.3     11.8     13.1   2.2139  1.1659
# 150     11.4     12.0     13.2   2.2044  1.1484
# 151     11.5     12.2     13.4   2.0904  1.3936
# 152     11.7     12.4     13.5   2.4300  1.2690
# 153     12.1     13.0     13.8   2.2770  1.2558
# 154     13.2     14.3     15.2   2.8728  2.0672
# 155     13.8     15.0     16.2   2.9322  1.8792

# %% [markdown]
# ### 2. Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %% [markdown]
# Length1: Vertical length in cm

# %%
# Length1
factor=train["Length1"]
factor1=test["Length1"]
reg.fit(factor.values.reshape(-1, 1),target1)
ypred=reg.predict(factor1.values.reshape(-1, 1))
print("Coefficient Length1 and Weight:",reg.coef_)
print("Intercept   Length1 and Weight: %0.3f" % reg.intercept_)
print("R2 score    Length1 and Weight: %.3f" % (r2_score(target2,ypred)*100))
print("MSE         Length1 and Weight: %.3f" % mean_squared_error(target2,ypred))
print("RMSE        Length1 and Weight: %.3f" % math.sqrt(mean_squared_error(target2,ypred)))
print("MAE         Length1 and Weight: %.3f" % math.sqrt(mean_absolute_error(target2,ypred)))
a=r2_score(target2,ypred)*100
# Out:
# Coefficient Length1 and Weight: [40.04010477]
# Intercept   Length1 and Weight: -635.701
# R2 score    Length1 and Weight: 53.565
# MSE         Length1 and Weight: 78881.721
# RMSE        Length1 and Weight: 280.859
# MAE         Length1 and Weight: 15.328

# %% [markdown]
# Height

# %%
factor=train["Height"]
factor1=test["Height"]
reg.fit(factor.values.reshape(-1, 1),target1)
ypred=reg.predict(factor1.values.reshape(-1, 1))
print("Coefficient Height and Weight:",reg.coef_)
print("Intercept   Height and Weight: %0.3f" % reg.intercept_)
print("R2 score    Height and Weight: %.3f" % (r2_score(target2,ypred)*100))
print("MSE         Height and Weight: %.3f" % mean_squared_error(target2,ypred))
print("RMSE        Height and Weight: %.3f" % math.sqrt(mean_squared_error(target2,ypred)))
print("MAE         Height and Weight: %.3f" % math.sqrt(mean_absolute_error(target2,ypred)))
b=r2_score(target2,ypred)*100
# Out:
# Coefficient Height and Weight: [58.30486743]
# Intercept   Height and Weight: -219.855
# R2 score    Height and Weight: 29.536
# MSE         Height and Weight: 119701.933
# RMSE        Height and Weight: 345.980
# MAE         Height and Weight: 16.894

# %% [markdown]
# Width

# %%
factor=train["Width"]
factor1=test["Width"]
reg.fit(factor.values.reshape(-1, 1),target1)
ypred=reg.predict(factor1.values.reshape(-1, 1))
print("Coefficient Width and Weight:",reg.coef_)
print("Intercept   Width and Weight: %0.3f" % reg.intercept_)
print("R2 score    Width and Weight: %.3f" % (r2_score(target2,ypred)*100))
print("MSE         Width and Weight: %.3f" % mean_squared_error(target2,ypred))
print("RMSE        Width and Weight: %.3f" % math.sqrt(mean_squared_error(target2,ypred)))
print("MAE         Width and Weight: %.3f" % math.sqrt(mean_absolute_error(target2,ypred)))
c=r2_score(target2,ypred)*100
# Out:
# Coefficient Width and Weight: [197.38345253]
# Intercept   Width and Weight: -525.650
# R2 score    Width and Weight: 76.911
# MSE         Width and Weight: 39222.486
# RMSE        Width and Weight: 198.047
# MAE         Width and Weight: 12.681

# %% [markdown]
# ### 3. Multiple Regression

# %% [markdown]
# Width
# Length1: Vertical length in cm
# Height

# %%
factor=train[["Width","Length1","Height"]]
factor1=test[["Width","Length1","Height"]]
reg.fit(factor,target1)
ypred=reg.predict(factor1)
print("Coefficient Width,Length1,Height and Weight:",reg.coef_)
print("Intercept   Width,Length1,Height and Weight: %0.3f" % reg.intercept_)
print("R2 score    Width,Length1,Height and Weight: %.3f" % (r2_score(target2,ypred)*100))
print("MSE         Width,Length1,Height and Weight: %.3f" % mean_squared_error(target2,ypred))
print("RMSE        Width,Length1,Height and Weight: %.3f" % math.sqrt(mean_squared_error(target2,ypred)))
print("MAE         Width,Length1,Height and Weight: %.3f" % math.sqrt(mean_absolute_error(target2,ypred)))
d=r2_score(target2,ypred)*100
# Out:
# Coefficient Width,Length1,Height and Weight: [89.40418657  9.26302657 24.35899212]
# Intercept   Width,Length1,Height and Weight: -512.036
# R2 score    Width,Length1,Height and Weight: 77.975
# MSE         Width,Length1,Height and Weight: 37414.720
# RMSE        Width,Length1,Height and Weight: 193.429
# MAE         Width,Length1,Height and Weight: 12.652

# %% [markdown]
# Length1: Vertical length in cm
# Length2: Diagonal length in cm
# Length3: Cross length in cm

# %%
factor=train[["Length1","Length2","Length3"]]
factor1=test[["Length1","Length2","Length3"]]
reg.fit(factor,target1)
ypred=reg.predict(factor1)
print("Coefficient Length1,Length2,Length3 and Weight:",reg.coef_)
print("Intercept   Length1,Length2,Length3 and Weight: %0.3f" % reg.intercept_)
print("R2 score    Length1,Length2,Length3 and Weight: %.3f" % (r2_score(target2,ypred)*100))
print("MSE         Length1,Length2,Length3 and Weight: %.3f" % mean_squared_error(target2,ypred))
print("RMSE        Length1,Length2,Length3 and Weight: %.3f" % math.sqrt(mean_squared_error(target2,ypred)))
print("MAE         Length1,Length2,Length3 and Weight: %.3f" % math.sqrt(mean_absolute_error(target2,ypred)))
e=r2_score(target2,ypred)*100
# Out:
# Coefficient Length1,Length2,Length3 and Weight: [-53.87586206  65.01592532  18.9981309 ]
# Intercept   Length1,Length2,Length3 and Weight: -631.344
# R2 score    Length1,Length2,Length3 and Weight: 63.085
# MSE         Length1,Length2,Length3 and Weight: 62710.911
# RMSE        Length1,Length2,Length3 and Weight: 250.421
# MAE         Length1,Length2,Length3 and Weight: 15.157

# %% [markdown]
# Width
# Height

# %%
factor=train[["Width","Height"]]
factor1=test[["Width","Height"]]
reg.fit(factor,target1)
ypred=reg.predict(factor1)
print("Coefficient Width Height and Weight:",reg.coef_)
print("Intercept   Width Height and Weight: %0.3f" % reg.intercept_)
print("R2 score    Width Height and Weight: %.3f" % (r2_score(target2,ypred)*100))
print("MSE         Width Height and Weight: %.3f" % mean_squared_error(target2,ypred))
print("RMSE        Width Height and Weight: %.3f" % math.sqrt(mean_squared_error(target2,ypred)))
print("MAE         Width Height and Weight: %.3f" % math.sqrt(mean_absolute_error(target2,ypred)))
f=r2_score(target2,ypred)*100
# Out:
# Coefficient Width Height and Weight: [125.71008481  27.51833526]
# Intercept   Width Height and Weight: -475.896
# R2 score    Width Height and Weight: 66.866
# MSE         Width Height and Weight: 56286.734
# RMSE        Width Height and Weight: 237.248
# MAE         Width Height and Weight: 14.609

# %% [markdown]
# ### 4.Random Forest Regression

# %%
model = RandomForestRegressor()
model.fit(train,target1)
# Get the mean absolute error on the validation data
ypred = model.predict(test)
print("R2 score    Using Random Forest Regression for Weight: %.3f" % (r2_score(target2,ypred)*100))
print("MSE         Using Random Forest Regression for Weight: %.3f" % mean_squared_error(target2,ypred))
print("RMSE        Using Random Forest Regression for Weight: %.3f" % math.sqrt(mean_squared_error(target2,ypred)))
print("MAE         Using Random Forest Regression for Weight: %.3f" % math.sqrt(mean_absolute_error(target2,ypred)))
g=r2_score(target2,ypred)*100
# Out:
# R2 score    Using Random Forest Regression for Weight: 80.996
# MSE         Using Random Forest Regression for Weight: 32283.140
# RMSE        Using Random Forest Regression for Weight: 179.675
# MAE         Using Random Forest Regression for Weight: 11.372

# %% [markdown]
# ### 5. XGB Regression

# %%
XGBModel = XGBRegressor()
XGBModel.fit(train,target1, verbose=False)

# Get the mean absolute error on the validation data :
ypred = XGBModel.predict(test)
print("R2 score    Using XGBRegressor for Weight: %.3f" % (r2_score(target2,ypred)*100))
print("MSE         Using XGBRegressor for Weight: %.3f" % mean_squared_error(target2,ypred))
print("RMSE        Using XGBRegressor for Weight: %.3f" % math.sqrt(mean_squared_error(target2,ypred)))
print("MAE         Using XGBRegressor for Weight: %.3f" % math.sqrt(mean_absolute_error(target2,ypred)))
h=r2_score(target2,ypred)*100
# Out:
# R2 score    Using XGBRegressor for Weight: 92.750
# MSE         Using XGBRegressor for Weight: 12316.140
# RMSE        Using XGBRegressor for Weight: 110.978
# MAE         Using XGBRegressor for Weight: 8.965

# %% [markdown]
# ### 6. DNN

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               768
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 165,633
# Trainable params: 165,633
# Non-trainable params: 0
# _________________________________________________________________
# 2022-03-09 18:41:33.927701: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
history=NN_model.fit(train, target1, epochs=800, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# 2022-03-09 18:41:34.370540: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/800
# 3/3 [==============================] - 1s 86ms/step - loss: 340.7296 - mean_absolute_error: 340.7296 - val_loss: 347.7900 - val_mean_absolute_error: 347.7900
#
# Epoch 00001: val_loss improved from inf to 347.79001, saving model to Weights-001--347.79001.hdf5
# Epoch 2/800
# 3/3 [==============================] - 0s 18ms/step - loss: 338.4211 - mean_absolute_error: 338.4211 - val_loss: 343.9403 - val_mean_absolute_error: 343.9403
#
# Epoch 00002: val_loss improved from 347.79001 to 343.94034, saving model to Weights-002--343.94034.hdf5
# Epoch 3/800
# 3/3 [==============================] - 0s 17ms/step - loss: 333.7963 - mean_absolute_error: 333.7963 - val_loss: 336.1901 - val_mean_absolute_error: 336.1901
#
# Epoch 00003: val_loss improved from 343.94034 to 336.19009, saving model to Weights-003--336.19009.hdf5
# Epoch 4/800
# 3/3 [==============================] - 0s 18ms/step - loss: 324.8842 - mean_absolute_error: 324.8842 - val_loss: 321.3445 - val_mean_absolute_error: 321.3445
#
# Epoch 00004: val_loss improved from 336.19009 to 321.34448, saving model to Weights-004--321.34448.hdf5
# Epoch 5/800
# 3/3 [==============================] - 0s 19ms/step - loss: 307.2126 - mean_absolute_error: 307.2126 - val_loss: 294.3501 - val_mean_absolute_error: 294.3501
#
# Epoch 00005: val_loss improved from 321.34448 to 294.35013, saving model to Weights-005--294.35013.hdf5
# Epoch 6/800
# 3/3 [==============================] - 0s 17ms/step - loss: 277.2916 - mean_absolute_error: 277.2916 - val_loss: 247.8055 - val_mean_absolute_error: 247.8055
#
# Epoch 00006: val_loss improved from 294.35013 to 247.80550, saving model to Weights-006--247.80550.hdf5
# Epoch 7/800
# 3/3 [==============================] - 0s 19ms/step - loss: 229.8094 - mean_absolute_error: 229.8094 - val_loss: 169.9973 - val_mean_absolute_error: 169.9973
#
# Epoch 00007: val_loss improved from 247.80550 to 169.99730, saving model to Weights-007--169.99730.hdf5
# Epoch 8/800
# 3/3 [==============================] - 0s 19ms/step - loss: 182.0611 - mean_absolute_error: 182.0611 - val_loss: 123.0815 - val_mean_absolute_error: 123.0815
#
# Epoch 00008: val_loss improved from 169.99730 to 123.08147, saving model to Weights-008--123.08147.hdf5
# Epoch 9/800
# 3/3 [==============================] - 0s 19ms/step - loss: 157.6169 - mean_absolute_error: 157.6169 - val_loss: 156.7612 - val_mean_absolute_error: 156.7612
#
# Epoch 00009: val_loss did not improve from 123.08147
# Epoch 10/800
# 3/3 [==============================] - 0s 18ms/step - loss: 175.9939 - mean_absolute_error: 175.9939 - val_loss: 176.7865 - val_mean_absolute_error: 176.7865
#
# Epoch 00010: val_loss did not improve from 123.08147
# Epoch 11/800
# 3/3 [==============================] - 0s 18ms/step - loss: 178.9854 - mean_absolute_error: 178.9854 - val_loss: 154.6089 - val_mean_absolute_error: 154.6089
#
# Epoch 00011: val_loss did not improve from 123.08147
# Epoch 12/800
# 3/3 [==============================] - 0s 18ms/step - loss: 169.1190 - mean_absolute_error: 169.1190 - val_loss: 131.6781 - val_mean_absolute_error: 131.6781
#
# Epoch 00012: val_loss did not improve from 123.08147
# Epoch 13/800
# 3/3 [==============================] - 0s 19ms/step - loss: 158.5910 - mean_absolute_error: 158.5910 - val_loss: 122.7331 - val_mean_absolute_error: 122.7331
#
# Epoch 00013: val_loss improved from 123.08147 to 122.73309, saving model to Weights-013--122.73309.hdf5
# Epoch 14/800
# 3/3 [==============================] - 0s 19ms/step - loss: 162.1446 - mean_absolute_error: 162.1446 - val_loss: 122.5653 - val_mean_absolute_error: 122.5653
#
# Epoch 00014: val_loss improved from 122.73309 to 122.56527, saving model to Weights-014--122.56527.hdf5
# Epoch 15/800
# 3/3 [==============================] - 0s 19ms/step - loss: 163.5417 - mean_absolute_error: 163.5417 - val_loss: 122.4280 - val_mean_absolute_error: 122.4280
#
# Epoch 00015: val_loss improved from 122.56527 to 122.42800, saving model to Weights-015--122.42800.hdf5
# Epoch 16/800
# 3/3 [==============================] - 0s 18ms/step - loss: 160.0123 - mean_absolute_error: 160.0123 - val_loss: 124.0356 - val_mean_absolute_error: 124.0356
#
# Epoch 00016: val_loss did not improve from 122.42800
# Epoch 17/800
# 3/3 [==============================] - 0s 19ms/step - loss: 157.3105 - mean_absolute_error: 157.3105 - val_loss: 128.9780 - val_mean_absolute_error: 128.9780
#
# Epoch 00017: val_loss did not improve from 122.42800
# Epoch 18/800
# 3/3 [==============================] - 0s 20ms/step - loss: 157.2106 - mean_absolute_error: 157.2106 - val_loss: 136.3176 - val_mean_absolute_error: 136.3176
#
# Epoch 00018: val_loss did not improve from 122.42800
# Epoch 19/800
# 3/3 [==============================] - 0s 19ms/step - loss: 158.6334 - mean_absolute_error: 158.6334 - val_loss: 140.3584 - val_mean_absolute_error: 140.3584
#
# Epoch 00019: val_loss did not improve from 122.42800
# Epoch 20/800
# 3/3 [==============================] - 0s 18ms/step - loss: 159.5764 - mean_absolute_error: 159.5764 - val_loss: 141.7298 - val_mean_absolute_error: 141.7298
#
# Epoch 00020: val_loss did not improve from 122.42800
# Epoch 21/800
# 3/3 [==============================] - 0s 18ms/step - loss: 158.3482 - mean_absolute_error: 158.3482 - val_loss: 137.8887 - val_mean_absolute_error: 137.8887
#
# Epoch 00021: val_loss did not improve from 122.42800
# Epoch 22/800
# 3/3 [==============================] - 0s 18ms/step - loss: 156.7837 - mean_absolute_error: 156.7837 - val_loss: 131.6805 - val_mean_absolute_error: 131.6805
#
# Epoch 00022: val_loss did not improve from 122.42800
# Epoch 23/800
# 3/3 [==============================] - 0s 18ms/step - loss: 156.0947 - mean_absolute_error: 156.0947 - val_loss: 124.4566 - val_mean_absolute_error: 124.4566
#
# Epoch 00023: val_loss did not improve from 122.42800
# Epoch 24/800
# 3/3 [==============================] - 0s 16ms/step - loss: 155.8377 - mean_absolute_error: 155.8377 - val_loss: 122.1067 - val_mean_absolute_error: 122.1067
#
# Epoch 00024: val_loss improved from 122.42800 to 122.10673, saving model to Weights-024--122.10673.hdf5
# Epoch 25/800
# 3/3 [==============================] - 0s 20ms/step - loss: 155.7648 - mean_absolute_error: 155.7648 - val_loss: 121.7819 - val_mean_absolute_error: 121.7819
#
# Epoch 00025: val_loss improved from 122.10673 to 121.78190, saving model to Weights-025--121.78190.hdf5
# Epoch 26/800
# 3/3 [==============================] - 0s 18ms/step - loss: 155.5928 - mean_absolute_error: 155.5928 - val_loss: 122.1231 - val_mean_absolute_error: 122.1231
#
# Epoch 00026: val_loss did not improve from 121.78190
# Epoch 27/800
# 3/3 [==============================] - 0s 18ms/step - loss: 155.1641 - mean_absolute_error: 155.1641 - val_loss: 122.2114 - val_mean_absolute_error: 122.2114
#
# Epoch 00027: val_loss did not improve from 121.78190
# Epoch 28/800
# 3/3 [==============================] - 0s 19ms/step - loss: 153.9159 - mean_absolute_error: 153.9159 - val_loss: 126.8499 - val_mean_absolute_error: 126.8499
#
# Epoch 00028: val_loss did not improve from 121.78190
# Epoch 29/800
# 3/3 [==============================] - 0s 20ms/step - loss: 153.6492 - mean_absolute_error: 153.6492 - val_loss: 130.9708 - val_mean_absolute_error: 130.9708
#
# Epoch 00029: val_loss did not improve from 121.78190
# Epoch 30/800
# 3/3 [==============================] - 0s 19ms/step - loss: 154.5114 - mean_absolute_error: 154.5114 - val_loss: 133.0246 - val_mean_absolute_error: 133.0246
#
# Epoch 00030: val_loss did not improve from 121.78190
# Epoch 31/800
# 3/3 [==============================] - 0s 19ms/step - loss: 153.4063 - mean_absolute_error: 153.4063 - val_loss: 130.8120 - val_mean_absolute_error: 130.8120
#
# Epoch 00031: val_loss did not improve from 121.78190
# Epoch 32/800
# 3/3 [==============================] - 0s 17ms/step - loss: 152.6128 - mean_absolute_error: 152.6128 - val_loss: 126.5009 - val_mean_absolute_error: 126.5009
#
# Epoch 00032: val_loss did not improve from 121.78190
# Epoch 33/800
# 3/3 [==============================] - 0s 17ms/step - loss: 152.1047 - mean_absolute_error: 152.1047 - val_loss: 120.9990 - val_mean_absolute_error: 120.9990
#
# Epoch 00033: val_loss improved from 121.78190 to 120.99902, saving model to Weights-033--120.99902.hdf5
# Epoch 34/800
# 3/3 [==============================] - 0s 19ms/step - loss: 152.0619 - mean_absolute_error: 152.0619 - val_loss: 120.4309 - val_mean_absolute_error: 120.4309
#
# Epoch 00034: val_loss improved from 120.99902 to 120.43087, saving model to Weights-034--120.43087.hdf5
# Epoch 35/800
# 3/3 [==============================] - 0s 19ms/step - loss: 151.5823 - mean_absolute_error: 151.5823 - val_loss: 120.5323 - val_mean_absolute_error: 120.5323
#
# Epoch 00035: val_loss did not improve from 120.43087
# Epoch 36/800
# 3/3 [==============================] - 0s 18ms/step - loss: 150.2002 - mean_absolute_error: 150.2002 - val_loss: 121.9864 - val_mean_absolute_error: 121.9864
#
# Epoch 00036: val_loss did not improve from 120.43087
# Epoch 37/800
# 3/3 [==============================] - 0s 17ms/step - loss: 150.4115 - mean_absolute_error: 150.4115 - val_loss: 126.1909 - val_mean_absolute_error: 126.1909
#
# Epoch 00037: val_loss did not improve from 120.43087
# Epoch 38/800
# 3/3 [==============================] - 0s 18ms/step - loss: 150.3739 - mean_absolute_error: 150.3739 - val_loss: 128.2232 - val_mean_absolute_error: 128.2232
#
# Epoch 00038: val_loss did not improve from 120.43087
# Epoch 39/800
# 3/3 [==============================] - 0s 17ms/step - loss: 148.6826 - mean_absolute_error: 148.6826 - val_loss: 124.3829 - val_mean_absolute_error: 124.3829
#
# Epoch 00039: val_loss did not improve from 120.43087
# Epoch 40/800
# 3/3 [==============================] - 0s 18ms/step - loss: 147.9287 - mean_absolute_error: 147.9287 - val_loss: 121.4713 - val_mean_absolute_error: 121.4713
#
# Epoch 00040: val_loss did not improve from 120.43087
# Epoch 41/800
# 3/3 [==============================] - 0s 18ms/step - loss: 147.3145 - mean_absolute_error: 147.3145 - val_loss: 119.3548 - val_mean_absolute_error: 119.3548
#
# Epoch 00041: val_loss improved from 120.43087 to 119.35477, saving model to Weights-041--119.35477.hdf5
# Epoch 42/800
# 3/3 [==============================] - 0s 18ms/step - loss: 146.5858 - mean_absolute_error: 146.5858 - val_loss: 119.0040 - val_mean_absolute_error: 119.0040
#
# Epoch 00042: val_loss improved from 119.35477 to 119.00400, saving model to Weights-042--119.00400.hdf5
# Epoch 43/800
# 3/3 [==============================] - 0s 17ms/step - loss: 146.2612 - mean_absolute_error: 146.2612 - val_loss: 118.7597 - val_mean_absolute_error: 118.7597
#
# Epoch 00043: val_loss improved from 119.00400 to 118.75967, saving model to Weights-043--118.75967.hdf5
# Epoch 44/800
# 3/3 [==============================] - 0s 17ms/step - loss: 146.4725 - mean_absolute_error: 146.4725 - val_loss: 121.7444 - val_mean_absolute_error: 121.7444
#
# Epoch 00044: val_loss did not improve from 118.75967
# Epoch 45/800
# 3/3 [==============================] - 0s 17ms/step - loss: 144.2963 - mean_absolute_error: 144.2963 - val_loss: 122.4007 - val_mean_absolute_error: 122.4007
#
# Epoch 00045: val_loss did not improve from 118.75967
# Epoch 46/800
# 3/3 [==============================] - 0s 19ms/step - loss: 143.6230 - mean_absolute_error: 143.6230 - val_loss: 122.6202 - val_mean_absolute_error: 122.6202
#
# Epoch 00046: val_loss did not improve from 118.75967
# Epoch 47/800
# 3/3 [==============================] - 0s 19ms/step - loss: 142.7326 - mean_absolute_error: 142.7326 - val_loss: 122.1581 - val_mean_absolute_error: 122.1581
#
# Epoch 00047: val_loss did not improve from 118.75967
# Epoch 48/800
# 3/3 [==============================] - 0s 17ms/step - loss: 141.6602 - mean_absolute_error: 141.6602 - val_loss: 119.7171 - val_mean_absolute_error: 119.7171
#
# Epoch 00048: val_loss did not improve from 118.75967
# Epoch 49/800
# 3/3 [==============================] - 0s 25ms/step - loss: 141.1543 - mean_absolute_error: 141.1543 - val_loss: 119.9589 - val_mean_absolute_error: 119.9589
#
# Epoch 00049: val_loss did not improve from 118.75967
# Epoch 50/800
# 3/3 [==============================] - 0s 18ms/step - loss: 139.4682 - mean_absolute_error: 139.4682 - val_loss: 118.2403 - val_mean_absolute_error: 118.2403
#
# Epoch 00050: val_loss improved from 118.75967 to 118.24029, saving model to Weights-050--118.24029.hdf5
# Epoch 51/800
# 3/3 [==============================] - 0s 18ms/step - loss: 138.1821 - mean_absolute_error: 138.1821 - val_loss: 116.2141 - val_mean_absolute_error: 116.2141
#
# Epoch 00051: val_loss improved from 118.24029 to 116.21411, saving model to Weights-051--116.21411.hdf5
# Epoch 52/800
# 3/3 [==============================] - 0s 19ms/step - loss: 136.8981 - mean_absolute_error: 136.8981 - val_loss: 115.6363 - val_mean_absolute_error: 115.6363
#
# Epoch 00052: val_loss improved from 116.21411 to 115.63631, saving model to Weights-052--115.63631.hdf5
# Epoch 53/800
# 3/3 [==============================] - 0s 17ms/step - loss: 135.6450 - mean_absolute_error: 135.6450 - val_loss: 115.0712 - val_mean_absolute_error: 115.0712
#
# Epoch 00053: val_loss improved from 115.63631 to 115.07119, saving model to Weights-053--115.07119.hdf5
# Epoch 54/800
# 3/3 [==============================] - 0s 17ms/step - loss: 134.0838 - mean_absolute_error: 134.0838 - val_loss: 114.4742 - val_mean_absolute_error: 114.4742
#
# Epoch 00054: val_loss improved from 115.07119 to 114.47417, saving model to Weights-054--114.47417.hdf5
# Epoch 55/800
# 3/3 [==============================] - 0s 19ms/step - loss: 132.1808 - mean_absolute_error: 132.1808 - val_loss: 114.9184 - val_mean_absolute_error: 114.9184
#
# Epoch 00055: val_loss did not improve from 114.47417
# Epoch 56/800
# 3/3 [==============================] - 0s 18ms/step - loss: 130.5762 - mean_absolute_error: 130.5762 - val_loss: 113.3281 - val_mean_absolute_error: 113.3281
#
# Epoch 00056: val_loss improved from 114.47417 to 113.32806, saving model to Weights-056--113.32806.hdf5
# Epoch 57/800
# 3/3 [==============================] - 0s 19ms/step - loss: 128.3944 - mean_absolute_error: 128.3944 - val_loss: 112.7182 - val_mean_absolute_error: 112.7182
#
# Epoch 00057: val_loss improved from 113.32806 to 112.71823, saving model to Weights-057--112.71823.hdf5
# Epoch 58/800
# 3/3 [==============================] - 0s 19ms/step - loss: 127.0007 - mean_absolute_error: 127.0007 - val_loss: 111.7468 - val_mean_absolute_error: 111.7468
#
# Epoch 00058: val_loss improved from 112.71823 to 111.74679, saving model to Weights-058--111.74679.hdf5
# Epoch 59/800
# 3/3 [==============================] - 0s 20ms/step - loss: 122.9942 - mean_absolute_error: 122.9942 - val_loss: 110.8294 - val_mean_absolute_error: 110.8294
#
# Epoch 00059: val_loss improved from 111.74679 to 110.82938, saving model to Weights-059--110.82938.hdf5
# Epoch 60/800
# 3/3 [==============================] - 0s 18ms/step - loss: 120.8672 - mean_absolute_error: 120.8672 - val_loss: 112.0472 - val_mean_absolute_error: 112.0472
#
# Epoch 00060: val_loss did not improve from 110.82938
# Epoch 61/800
# 3/3 [==============================] - 0s 18ms/step - loss: 117.4179 - mean_absolute_error: 117.4179 - val_loss: 112.9793 - val_mean_absolute_error: 112.9793
#
# Epoch 00061: val_loss did not improve from 110.82938
# Epoch 62/800
# 3/3 [==============================] - 0s 18ms/step - loss: 113.7830 - mean_absolute_error: 113.7830 - val_loss: 116.7295 - val_mean_absolute_error: 116.7295
#
# Epoch 00062: val_loss did not improve from 110.82938
# Epoch 63/800
# 3/3 [==============================] - 0s 17ms/step - loss: 110.4435 - mean_absolute_error: 110.4435 - val_loss: 112.3652 - val_mean_absolute_error: 112.3652
#
# Epoch 00063: val_loss did not improve from 110.82938
# Epoch 64/800
# 3/3 [==============================] - 0s 17ms/step - loss: 106.6380 - mean_absolute_error: 106.6380 - val_loss: 119.4788 - val_mean_absolute_error: 119.4788
#
# Epoch 00064: val_loss did not improve from 110.82938
# Epoch 65/800
# 3/3 [==============================] - 0s 24ms/step - loss: 102.9479 - mean_absolute_error: 102.9479 - val_loss: 138.1465 - val_mean_absolute_error: 138.1465
#
# Epoch 00065: val_loss did not improve from 110.82938
# Epoch 66/800
# 3/3 [==============================] - 0s 17ms/step - loss: 99.7517 - mean_absolute_error: 99.7517 - val_loss: 134.6697 - val_mean_absolute_error: 134.6697
#
# Epoch 00066: val_loss did not improve from 110.82938
# Epoch 67/800
# 3/3 [==============================] - 0s 17ms/step - loss: 95.5353 - mean_absolute_error: 95.5353 - val_loss: 154.8319 - val_mean_absolute_error: 154.8319
#
# Epoch 00067: val_loss did not improve from 110.82938
# Epoch 68/800
# 3/3 [==============================] - 0s 18ms/step - loss: 89.7922 - mean_absolute_error: 89.7922 - val_loss: 128.3181 - val_mean_absolute_error: 128.3181
#
# Epoch 00068: val_loss did not improve from 110.82938
# Epoch 69/800
# 3/3 [==============================] - 0s 18ms/step - loss: 88.2342 - mean_absolute_error: 88.2342 - val_loss: 171.9345 - val_mean_absolute_error: 171.9345
#
# Epoch 00069: val_loss did not improve from 110.82938
# Epoch 70/800
# 3/3 [==============================] - 0s 18ms/step - loss: 87.3738 - mean_absolute_error: 87.3738 - val_loss: 167.1781 - val_mean_absolute_error: 167.1781
#
# Epoch 00070: val_loss did not improve from 110.82938
# Epoch 71/800
# 3/3 [==============================] - 0s 19ms/step - loss: 83.6895 - mean_absolute_error: 83.6895 - val_loss: 148.8475 - val_mean_absolute_error: 148.8475
#
# Epoch 00071: val_loss did not improve from 110.82938
# Epoch 72/800
# 3/3 [==============================] - 0s 19ms/step - loss: 85.0794 - mean_absolute_error: 85.0794 - val_loss: 172.6650 - val_mean_absolute_error: 172.6650
#
# Epoch 00072: val_loss did not improve from 110.82938
# Epoch 73/800
# 3/3 [==============================] - 0s 18ms/step - loss: 83.5892 - mean_absolute_error: 83.5892 - val_loss: 185.0108 - val_mean_absolute_error: 185.0108
#
# Epoch 00073: val_loss did not improve from 110.82938
# Epoch 74/800
# 3/3 [==============================] - 0s 18ms/step - loss: 86.5173 - mean_absolute_error: 86.5173 - val_loss: 171.6071 - val_mean_absolute_error: 171.6071
#
# Epoch 00074: val_loss did not improve from 110.82938
# Epoch 75/800
# 3/3 [==============================] - 0s 19ms/step - loss: 85.7553 - mean_absolute_error: 85.7553 - val_loss: 176.1578 - val_mean_absolute_error: 176.1578
#
# Epoch 00075: val_loss did not improve from 110.82938
# Epoch 76/800
# 3/3 [==============================] - 0s 19ms/step - loss: 83.0939 - mean_absolute_error: 83.0939 - val_loss: 142.5899 - val_mean_absolute_error: 142.5899
#
# Epoch 00076: val_loss did not improve from 110.82938
# Epoch 77/800
# 3/3 [==============================] - 0s 17ms/step - loss: 84.7531 - mean_absolute_error: 84.7531 - val_loss: 169.2444 - val_mean_absolute_error: 169.2444
#
# Epoch 00077: val_loss did not improve from 110.82938
# Epoch 78/800
# 3/3 [==============================] - 0s 18ms/step - loss: 83.8354 - mean_absolute_error: 83.8354 - val_loss: 164.7831 - val_mean_absolute_error: 164.7831
#
# Epoch 00078: val_loss did not improve from 110.82938
# Epoch 79/800
# 3/3 [==============================] - 0s 17ms/step - loss: 81.3622 - mean_absolute_error: 81.3622 - val_loss: 142.4040 - val_mean_absolute_error: 142.4040
#
# Epoch 00079: val_loss did not improve from 110.82938
# Epoch 80/800
# 3/3 [==============================] - 0s 18ms/step - loss: 84.3830 - mean_absolute_error: 84.3830 - val_loss: 166.9854 - val_mean_absolute_error: 166.9854
#
# Epoch 00080: val_loss did not improve from 110.82938
# Epoch 81/800
# 3/3 [==============================] - 0s 18ms/step - loss: 86.3048 - mean_absolute_error: 86.3048 - val_loss: 184.1539 - val_mean_absolute_error: 184.1539
#
# Epoch 00081: val_loss did not improve from 110.82938
# Epoch 82/800
# 3/3 [==============================] - 0s 28ms/step - loss: 80.9962 - mean_absolute_error: 80.9962 - val_loss: 133.9353 - val_mean_absolute_error: 133.9353
#
# Epoch 00082: val_loss did not improve from 110.82938
# Epoch 83/800
# 3/3 [==============================] - 0s 24ms/step - loss: 84.6947 - mean_absolute_error: 84.6947 - val_loss: 165.9969 - val_mean_absolute_error: 165.9969
#
# Epoch 00083: val_loss did not improve from 110.82938
# Epoch 84/800
# 3/3 [==============================] - 0s 19ms/step - loss: 82.5383 - mean_absolute_error: 82.5383 - val_loss: 185.4593 - val_mean_absolute_error: 185.4593
#
# Epoch 00084: val_loss did not improve from 110.82938
# Epoch 85/800
# 3/3 [==============================] - 0s 19ms/step - loss: 83.6324 - mean_absolute_error: 83.6324 - val_loss: 147.9323 - val_mean_absolute_error: 147.9323
#
# Epoch 00085: val_loss did not improve from 110.82938
# Epoch 86/800
# 3/3 [==============================] - 0s 19ms/step - loss: 82.7534 - mean_absolute_error: 82.7534 - val_loss: 156.9434 - val_mean_absolute_error: 156.9434
#
# Epoch 00086: val_loss did not improve from 110.82938
# Epoch 87/800
# 3/3 [==============================] - 0s 19ms/step - loss: 82.2375 - mean_absolute_error: 82.2375 - val_loss: 179.0709 - val_mean_absolute_error: 179.0709
#
# Epoch 00087: val_loss did not improve from 110.82938
# Epoch 88/800
# 3/3 [==============================] - 0s 19ms/step - loss: 80.3709 - mean_absolute_error: 80.3709 - val_loss: 142.0951 - val_mean_absolute_error: 142.0951
#
# Epoch 00088: val_loss did not improve from 110.82938
# Epoch 89/800
# 3/3 [==============================] - 0s 19ms/step - loss: 82.2859 - mean_absolute_error: 82.2859 - val_loss: 159.8608 - val_mean_absolute_error: 159.8608
#
# Epoch 00089: val_loss did not improve from 110.82938
# Epoch 90/800
# 3/3 [==============================] - 0s 19ms/step - loss: 79.6321 - mean_absolute_error: 79.6321 - val_loss: 171.5426 - val_mean_absolute_error: 171.5426
#
# Epoch 00090: val_loss did not improve from 110.82938
# Epoch 91/800
# 3/3 [==============================] - 0s 18ms/step - loss: 79.9334 - mean_absolute_error: 79.9334 - val_loss: 151.2470 - val_mean_absolute_error: 151.2470
#
# Epoch 00091: val_loss did not improve from 110.82938
# Epoch 92/800
# 3/3 [==============================] - 0s 18ms/step - loss: 82.1602 - mean_absolute_error: 82.1602 - val_loss: 147.8157 - val_mean_absolute_error: 147.8157
#
# Epoch 00092: val_loss did not improve from 110.82938
# Epoch 93/800
# 3/3 [==============================] - 0s 17ms/step - loss: 82.1728 - mean_absolute_error: 82.1728 - val_loss: 180.4128 - val_mean_absolute_error: 180.4128
#
# Epoch 00093: val_loss did not improve from 110.82938
# Epoch 94/800
# 3/3 [==============================] - 0s 19ms/step - loss: 83.5669 - mean_absolute_error: 83.5669 - val_loss: 143.0763 - val_mean_absolute_error: 143.0763
#
# Epoch 00094: val_loss did not improve from 110.82938
# Epoch 95/800
# 3/3 [==============================] - 0s 21ms/step - loss: 79.8268 - mean_absolute_error: 79.8268 - val_loss: 153.5657 - val_mean_absolute_error: 153.5657
#
# Epoch 00095: val_loss did not improve from 110.82938
# Epoch 96/800
# 3/3 [==============================] - 0s 19ms/step - loss: 78.5750 - mean_absolute_error: 78.5750 - val_loss: 165.9573 - val_mean_absolute_error: 165.9573
#
# Epoch 00096: val_loss did not improve from 110.82938
# Epoch 97/800
# 3/3 [==============================] - 0s 18ms/step - loss: 79.3874 - mean_absolute_error: 79.3874 - val_loss: 152.5811 - val_mean_absolute_error: 152.5811
#
# Epoch 00097: val_loss did not improve from 110.82938
# Epoch 98/800
# 3/3 [==============================] - 0s 18ms/step - loss: 78.5903 - mean_absolute_error: 78.5903 - val_loss: 156.5712 - val_mean_absolute_error: 156.5712
#
# Epoch 00098: val_loss did not improve from 110.82938
# Epoch 99/800
# 3/3 [==============================] - 0s 20ms/step - loss: 78.8614 - mean_absolute_error: 78.8614 - val_loss: 163.5316 - val_mean_absolute_error: 163.5316
#
# Epoch 00099: val_loss did not improve from 110.82938
# Epoch 100/800
# 3/3 [==============================] - 0s 19ms/step - loss: 77.8854 - mean_absolute_error: 77.8854 - val_loss: 147.7565 - val_mean_absolute_error: 147.7565
#
# Epoch 00100: val_loss did not improve from 110.82938
# Epoch 101/800
# 3/3 [==============================] - 0s 19ms/step - loss: 78.0096 - mean_absolute_error: 78.0096 - val_loss: 154.0455 - val_mean_absolute_error: 154.0455
#
# Epoch 00101: val_loss did not improve from 110.82938
# Epoch 102/800
# 3/3 [==============================] - 0s 19ms/step - loss: 77.5180 - mean_absolute_error: 77.5180 - val_loss: 156.2824 - val_mean_absolute_error: 156.2824
#
# Epoch 00102: val_loss did not improve from 110.82938
# Epoch 103/800
# 3/3 [==============================] - 0s 18ms/step - loss: 78.6051 - mean_absolute_error: 78.6051 - val_loss: 148.2731 - val_mean_absolute_error: 148.2731
#
# Epoch 00103: val_loss did not improve from 110.82938
# Epoch 104/800
# 3/3 [==============================] - 0s 19ms/step - loss: 77.5104 - mean_absolute_error: 77.5104 - val_loss: 159.2238 - val_mean_absolute_error: 159.2238
#
# Epoch 00104: val_loss did not improve from 110.82938
# Epoch 105/800
# 3/3 [==============================] - 0s 20ms/step - loss: 78.9016 - mean_absolute_error: 78.9016 - val_loss: 158.4043 - val_mean_absolute_error: 158.4043
#
# Epoch 00105: val_loss did not improve from 110.82938
# Epoch 106/800
# 3/3 [==============================] - 0s 19ms/step - loss: 78.2094 - mean_absolute_error: 78.2094 - val_loss: 154.4427 - val_mean_absolute_error: 154.4427
#
# Epoch 00106: val_loss did not improve from 110.82938
# Epoch 107/800
# 3/3 [==============================] - 0s 17ms/step - loss: 77.7492 - mean_absolute_error: 77.7492 - val_loss: 146.9809 - val_mean_absolute_error: 146.9809
#
# Epoch 00107: val_loss did not improve from 110.82938
# Epoch 108/800
# 3/3 [==============================] - 0s 18ms/step - loss: 77.0516 - mean_absolute_error: 77.0516 - val_loss: 157.3796 - val_mean_absolute_error: 157.3796
#
# Epoch 00108: val_loss did not improve from 110.82938
# Epoch 109/800
# 3/3 [==============================] - 0s 27ms/step - loss: 76.6322 - mean_absolute_error: 76.6322 - val_loss: 154.3372 - val_mean_absolute_error: 154.3372
#
# Epoch 00109: val_loss did not improve from 110.82938
# Epoch 110/800
# 3/3 [==============================] - 0s 17ms/step - loss: 76.4560 - mean_absolute_error: 76.4560 - val_loss: 147.5172 - val_mean_absolute_error: 147.5172
#
# Epoch 00110: val_loss did not improve from 110.82938
# Epoch 111/800
# 3/3 [==============================] - 0s 19ms/step - loss: 76.0812 - mean_absolute_error: 76.0812 - val_loss: 147.8595 - val_mean_absolute_error: 147.8595
#
# Epoch 00111: val_loss did not improve from 110.82938
# Epoch 112/800
# 3/3 [==============================] - 0s 20ms/step - loss: 77.0963 - mean_absolute_error: 77.0963 - val_loss: 147.4175 - val_mean_absolute_error: 147.4175
#
# Epoch 00112: val_loss did not improve from 110.82938
# Epoch 113/800
# 3/3 [==============================] - 0s 18ms/step - loss: 76.0787 - mean_absolute_error: 76.0787 - val_loss: 152.4822 - val_mean_absolute_error: 152.4822
#
# Epoch 00113: val_loss did not improve from 110.82938
# Epoch 114/800
# 3/3 [==============================] - 0s 18ms/step - loss: 76.5617 - mean_absolute_error: 76.5617 - val_loss: 155.7235 - val_mean_absolute_error: 155.7235
#
# Epoch 00114: val_loss did not improve from 110.82938
# Epoch 115/800
# 3/3 [==============================] - 0s 18ms/step - loss: 78.2803 - mean_absolute_error: 78.2803 - val_loss: 158.5087 - val_mean_absolute_error: 158.5087
#
# Epoch 00115: val_loss did not improve from 110.82938
# Epoch 116/800
# 3/3 [==============================] - 0s 18ms/step - loss: 75.6942 - mean_absolute_error: 75.6942 - val_loss: 128.0662 - val_mean_absolute_error: 128.0662
#
# Epoch 00116: val_loss did not improve from 110.82938
# Epoch 117/800
# 3/3 [==============================] - 0s 19ms/step - loss: 77.6752 - mean_absolute_error: 77.6752 - val_loss: 144.5498 - val_mean_absolute_error: 144.5498
#
# Epoch 00117: val_loss did not improve from 110.82938
# Epoch 118/800
# 3/3 [==============================] - 0s 18ms/step - loss: 78.2594 - mean_absolute_error: 78.2594 - val_loss: 174.8996 - val_mean_absolute_error: 174.8996
#
# Epoch 00118: val_loss did not improve from 110.82938
# Epoch 119/800
# 3/3 [==============================] - 0s 17ms/step - loss: 77.9572 - mean_absolute_error: 77.9572 - val_loss: 135.3293 - val_mean_absolute_error: 135.3293
#
# Epoch 00119: val_loss did not improve from 110.82938
# Epoch 120/800
# 3/3 [==============================] - 0s 18ms/step - loss: 86.2286 - mean_absolute_error: 86.2286 - val_loss: 122.5230 - val_mean_absolute_error: 122.5230
#
# Epoch 00120: val_loss did not improve from 110.82938
# Epoch 121/800
# 3/3 [==============================] - 0s 17ms/step - loss: 76.2819 - mean_absolute_error: 76.2819 - val_loss: 180.3863 - val_mean_absolute_error: 180.3863
#
# Epoch 00121: val_loss did not improve from 110.82938
# Epoch 122/800
# 3/3 [==============================] - 0s 18ms/step - loss: 81.3181 - mean_absolute_error: 81.3181 - val_loss: 149.1655 - val_mean_absolute_error: 149.1655
#
# Epoch 00122: val_loss did not improve from 110.82938
# Epoch 123/800
# 3/3 [==============================] - 0s 18ms/step - loss: 73.4997 - mean_absolute_error: 73.4997 - val_loss: 130.1261 - val_mean_absolute_error: 130.1261
#
# Epoch 00123: val_loss did not improve from 110.82938
# Epoch 124/800
# 3/3 [==============================] - 0s 17ms/step - loss: 76.0069 - mean_absolute_error: 76.0069 - val_loss: 138.2313 - val_mean_absolute_error: 138.2313
#
# Epoch 00124: val_loss did not improve from 110.82938
# Epoch 125/800
# 3/3 [==============================] - 0s 18ms/step - loss: 77.9214 - mean_absolute_error: 77.9214 - val_loss: 167.3689 - val_mean_absolute_error: 167.3689
#
# Epoch 00125: val_loss did not improve from 110.82938
# Epoch 126/800
# 3/3 [==============================] - 0s 21ms/step - loss: 77.7034 - mean_absolute_error: 77.7034 - val_loss: 137.7312 - val_mean_absolute_error: 137.7312
#
# Epoch 00126: val_loss did not improve from 110.82938
# Epoch 127/800
# 3/3 [==============================] - 0s 18ms/step - loss: 76.2573 - mean_absolute_error: 76.2573 - val_loss: 130.6983 - val_mean_absolute_error: 130.6983
#
# Epoch 00127: val_loss did not improve from 110.82938
# Epoch 128/800
# 3/3 [==============================] - 0s 18ms/step - loss: 74.4043 - mean_absolute_error: 74.4043 - val_loss: 150.5894 - val_mean_absolute_error: 150.5894
#
# Epoch 00128: val_loss did not improve from 110.82938
# Epoch 129/800
# 3/3 [==============================] - 0s 18ms/step - loss: 74.2199 - mean_absolute_error: 74.2199 - val_loss: 146.2049 - val_mean_absolute_error: 146.2049
#
# Epoch 00129: val_loss did not improve from 110.82938
# Epoch 130/800
# 3/3 [==============================] - 0s 18ms/step - loss: 74.2131 - mean_absolute_error: 74.2131 - val_loss: 128.8729 - val_mean_absolute_error: 128.8729
#
# Epoch 00130: val_loss did not improve from 110.82938
# Epoch 131/800
# 3/3 [==============================] - 0s 18ms/step - loss: 74.3867 - mean_absolute_error: 74.3867 - val_loss: 146.2706 - val_mean_absolute_error: 146.2706
#
# Epoch 00131: val_loss did not improve from 110.82938
# Epoch 132/800
# 3/3 [==============================] - 0s 17ms/step - loss: 73.8395 - mean_absolute_error: 73.8395 - val_loss: 147.2608 - val_mean_absolute_error: 147.2608
#
# Epoch 00132: val_loss did not improve from 110.82938
# Epoch 133/800
# 3/3 [==============================] - 0s 19ms/step - loss: 73.0258 - mean_absolute_error: 73.0258 - val_loss: 124.8878 - val_mean_absolute_error: 124.8878
#
# Epoch 00133: val_loss did not improve from 110.82938
# Epoch 134/800
# 3/3 [==============================] - 0s 19ms/step - loss: 74.7735 - mean_absolute_error: 74.7735 - val_loss: 135.5824 - val_mean_absolute_error: 135.5824
#
# Epoch 00134: val_loss did not improve from 110.82938
# Epoch 135/800
# 3/3 [==============================] - 0s 19ms/step - loss: 72.8597 - mean_absolute_error: 72.8597 - val_loss: 146.0605 - val_mean_absolute_error: 146.0605
#
# Epoch 00135: val_loss did not improve from 110.82938
# Epoch 136/800
# 3/3 [==============================] - 0s 20ms/step - loss: 74.0227 - mean_absolute_error: 74.0227 - val_loss: 139.9019 - val_mean_absolute_error: 139.9019
#
# Epoch 00136: val_loss did not improve from 110.82938
# Epoch 137/800
# 3/3 [==============================] - 0s 20ms/step - loss: 73.4231 - mean_absolute_error: 73.4231 - val_loss: 133.3278 - val_mean_absolute_error: 133.3278
#
# Epoch 00137: val_loss did not improve from 110.82938
# Epoch 138/800
# 3/3 [==============================] - 0s 18ms/step - loss: 72.9408 - mean_absolute_error: 72.9408 - val_loss: 154.5684 - val_mean_absolute_error: 154.5684
#
# Epoch 00138: val_loss did not improve from 110.82938
# Epoch 139/800
# 3/3 [==============================] - 0s 19ms/step - loss: 74.8009 - mean_absolute_error: 74.8009 - val_loss: 143.7777 - val_mean_absolute_error: 143.7777
#
# Epoch 00139: val_loss did not improve from 110.82938
# Epoch 140/800
# 3/3 [==============================] - 0s 20ms/step - loss: 73.1369 - mean_absolute_error: 73.1369 - val_loss: 130.7553 - val_mean_absolute_error: 130.7553
#
# Epoch 00140: val_loss did not improve from 110.82938
# Epoch 141/800
# 3/3 [==============================] - 0s 18ms/step - loss: 73.8392 - mean_absolute_error: 73.8392 - val_loss: 161.2706 - val_mean_absolute_error: 161.2706
#
# Epoch 00141: val_loss did not improve from 110.82938
# Epoch 142/800
# 3/3 [==============================] - 0s 18ms/step - loss: 74.6608 - mean_absolute_error: 74.6608 - val_loss: 127.5064 - val_mean_absolute_error: 127.5064
#
# Epoch 00142: val_loss did not improve from 110.82938
# Epoch 143/800
# 3/3 [==============================] - 0s 20ms/step - loss: 71.9315 - mean_absolute_error: 71.9315 - val_loss: 123.4877 - val_mean_absolute_error: 123.4877
#
# Epoch 00143: val_loss did not improve from 110.82938
# Epoch 144/800
# 3/3 [==============================] - 0s 20ms/step - loss: 72.1859 - mean_absolute_error: 72.1859 - val_loss: 143.8375 - val_mean_absolute_error: 143.8375
#
# Epoch 00144: val_loss did not improve from 110.82938
# Epoch 145/800
# 3/3 [==============================] - 0s 19ms/step - loss: 71.8917 - mean_absolute_error: 71.8917 - val_loss: 149.5277 - val_mean_absolute_error: 149.5277
#
# Epoch 00145: val_loss did not improve from 110.82938
# Epoch 146/800
# 3/3 [==============================] - 0s 19ms/step - loss: 71.6655 - mean_absolute_error: 71.6655 - val_loss: 127.0621 - val_mean_absolute_error: 127.0621
#
# Epoch 00146: val_loss did not improve from 110.82938
# Epoch 147/800
# 3/3 [==============================] - 0s 16ms/step - loss: 74.2467 - mean_absolute_error: 74.2467 - val_loss: 137.3316 - val_mean_absolute_error: 137.3316
#
# Epoch 00147: val_loss did not improve from 110.82938
# Epoch 148/800
# 3/3 [==============================] - 0s 18ms/step - loss: 72.6120 - mean_absolute_error: 72.6120 - val_loss: 166.9828 - val_mean_absolute_error: 166.9828
#
# Epoch 00148: val_loss did not improve from 110.82938
# Epoch 149/800
# 3/3 [==============================] - 0s 18ms/step - loss: 77.4904 - mean_absolute_error: 77.4904 - val_loss: 126.3538 - val_mean_absolute_error: 126.3538
#
# Epoch 00149: val_loss did not improve from 110.82938
# Epoch 150/800
# 3/3 [==============================] - 0s 20ms/step - loss: 72.2474 - mean_absolute_error: 72.2474 - val_loss: 97.7873 - val_mean_absolute_error: 97.7873
#
# Epoch 00150: val_loss improved from 110.82938 to 97.78725, saving model to Weights-150--97.78725.hdf5
# Epoch 151/800
# 3/3 [==============================] - 0s 18ms/step - loss: 76.4666 - mean_absolute_error: 76.4666 - val_loss: 143.1213 - val_mean_absolute_error: 143.1213
#
# Epoch 00151: val_loss did not improve from 97.78725
# Epoch 152/800
# 3/3 [==============================] - 0s 19ms/step - loss: 75.3175 - mean_absolute_error: 75.3175 - val_loss: 162.9950 - val_mean_absolute_error: 162.9950
#
# Epoch 00152: val_loss did not improve from 97.78725
# Epoch 153/800
# 3/3 [==============================] - 0s 19ms/step - loss: 73.9090 - mean_absolute_error: 73.9090 - val_loss: 115.5421 - val_mean_absolute_error: 115.5421
#
# Epoch 00153: val_loss did not improve from 97.78725
# Epoch 154/800
# 3/3 [==============================] - 0s 27ms/step - loss: 72.9700 - mean_absolute_error: 72.9700 - val_loss: 134.0732 - val_mean_absolute_error: 134.0732
#
# Epoch 00154: val_loss did not improve from 97.78725
# Epoch 155/800
# 3/3 [==============================] - 0s 29ms/step - loss: 74.2540 - mean_absolute_error: 74.2540 - val_loss: 149.6712 - val_mean_absolute_error: 149.6712
#
# Epoch 00155: val_loss did not improve from 97.78725
# Epoch 156/800
# 3/3 [==============================] - 0s 17ms/step - loss: 71.7795 - mean_absolute_error: 71.7795 - val_loss: 120.6947 - val_mean_absolute_error: 120.6947
#
# Epoch 00156: val_loss did not improve from 97.78725
# Epoch 157/800
# 3/3 [==============================] - 0s 17ms/step - loss: 71.4745 - mean_absolute_error: 71.4745 - val_loss: 129.0351 - val_mean_absolute_error: 129.0351
#
# Epoch 00157: val_loss did not improve from 97.78725
# Epoch 158/800
# 3/3 [==============================] - 0s 18ms/step - loss: 70.5019 - mean_absolute_error: 70.5019 - val_loss: 152.9282 - val_mean_absolute_error: 152.9282
#
# Epoch 00158: val_loss did not improve from 97.78725
# Epoch 159/800
# 3/3 [==============================] - 0s 17ms/step - loss: 72.3522 - mean_absolute_error: 72.3522 - val_loss: 112.8243 - val_mean_absolute_error: 112.8243
#
# Epoch 00159: val_loss did not improve from 97.78725
# Epoch 160/800
# 3/3 [==============================] - 0s 19ms/step - loss: 70.9307 - mean_absolute_error: 70.9307 - val_loss: 140.5735 - val_mean_absolute_error: 140.5735
#
# Epoch 00160: val_loss did not improve from 97.78725
# Epoch 161/800
# 3/3 [==============================] - 0s 19ms/step - loss: 70.6389 - mean_absolute_error: 70.6389 - val_loss: 154.1526 - val_mean_absolute_error: 154.1526
#
# Epoch 00161: val_loss did not improve from 97.78725
# Epoch 162/800
# 3/3 [==============================] - 0s 18ms/step - loss: 70.7504 - mean_absolute_error: 70.7504 - val_loss: 114.2630 - val_mean_absolute_error: 114.2630
#
# Epoch 00162: val_loss did not improve from 97.78725
# Epoch 163/800
# 3/3 [==============================] - 0s 20ms/step - loss: 70.7980 - mean_absolute_error: 70.7980 - val_loss: 131.7836 - val_mean_absolute_error: 131.7836
#
# Epoch 00163: val_loss did not improve from 97.78725
# Epoch 164/800
# 3/3 [==============================] - 0s 17ms/step - loss: 69.5668 - mean_absolute_error: 69.5668 - val_loss: 140.0312 - val_mean_absolute_error: 140.0312
#
# Epoch 00164: val_loss did not improve from 97.78725
# Epoch 165/800
# 3/3 [==============================] - 0s 18ms/step - loss: 68.2032 - mean_absolute_error: 68.2032 - val_loss: 121.3320 - val_mean_absolute_error: 121.3320
#
# Epoch 00165: val_loss did not improve from 97.78725
# Epoch 166/800
# 3/3 [==============================] - 0s 19ms/step - loss: 72.3633 - mean_absolute_error: 72.3633 - val_loss: 131.7056 - val_mean_absolute_error: 131.7056
#
# Epoch 00166: val_loss did not improve from 97.78725
# Epoch 167/800
# 3/3 [==============================] - 0s 19ms/step - loss: 69.6057 - mean_absolute_error: 69.6057 - val_loss: 149.2072 - val_mean_absolute_error: 149.2072
#
# Epoch 00167: val_loss did not improve from 97.78725
# Epoch 168/800
# 3/3 [==============================] - 0s 18ms/step - loss: 69.6338 - mean_absolute_error: 69.6338 - val_loss: 123.0412 - val_mean_absolute_error: 123.0412
#
# Epoch 00168: val_loss did not improve from 97.78725
# Epoch 169/800
# 3/3 [==============================] - 0s 18ms/step - loss: 68.0979 - mean_absolute_error: 68.0979 - val_loss: 120.6700 - val_mean_absolute_error: 120.6700
#
# Epoch 00169: val_loss did not improve from 97.78725
# Epoch 170/800
# 3/3 [==============================] - 0s 19ms/step - loss: 67.4758 - mean_absolute_error: 67.4758 - val_loss: 135.2041 - val_mean_absolute_error: 135.2041
#
# Epoch 00170: val_loss did not improve from 97.78725
# Epoch 171/800
# 3/3 [==============================] - 0s 19ms/step - loss: 67.2835 - mean_absolute_error: 67.2835 - val_loss: 119.7322 - val_mean_absolute_error: 119.7322
#
# Epoch 00171: val_loss did not improve from 97.78725
# Epoch 172/800
# 3/3 [==============================] - 0s 17ms/step - loss: 67.4685 - mean_absolute_error: 67.4685 - val_loss: 134.2561 - val_mean_absolute_error: 134.2561
#
# Epoch 00172: val_loss did not improve from 97.78725
# Epoch 173/800
# 3/3 [==============================] - 0s 18ms/step - loss: 70.2645 - mean_absolute_error: 70.2645 - val_loss: 142.5866 - val_mean_absolute_error: 142.5866
#
# Epoch 00173: val_loss did not improve from 97.78725
# Epoch 174/800
# 3/3 [==============================] - 0s 20ms/step - loss: 67.2932 - mean_absolute_error: 67.2932 - val_loss: 107.4078 - val_mean_absolute_error: 107.4078
#
# Epoch 00174: val_loss did not improve from 97.78725
# Epoch 175/800
# 3/3 [==============================] - 0s 16ms/step - loss: 68.2268 - mean_absolute_error: 68.2268 - val_loss: 130.9957 - val_mean_absolute_error: 130.9957
#
# Epoch 00175: val_loss did not improve from 97.78725
# Epoch 176/800
# 3/3 [==============================] - 0s 19ms/step - loss: 66.6051 - mean_absolute_error: 66.6051 - val_loss: 137.1387 - val_mean_absolute_error: 137.1387
#
# Epoch 00176: val_loss did not improve from 97.78725
# Epoch 177/800
# 3/3 [==============================] - 0s 19ms/step - loss: 67.2637 - mean_absolute_error: 67.2637 - val_loss: 113.9505 - val_mean_absolute_error: 113.9505
#
# Epoch 00177: val_loss did not improve from 97.78725
# Epoch 178/800
# 3/3 [==============================] - 0s 18ms/step - loss: 67.5715 - mean_absolute_error: 67.5715 - val_loss: 125.5168 - val_mean_absolute_error: 125.5168
#
# Epoch 00178: val_loss did not improve from 97.78725
# Epoch 179/800
# 3/3 [==============================] - 0s 19ms/step - loss: 65.5976 - mean_absolute_error: 65.5976 - val_loss: 118.0726 - val_mean_absolute_error: 118.0726
#
# Epoch 00179: val_loss did not improve from 97.78725
# Epoch 180/800
# 3/3 [==============================] - 0s 19ms/step - loss: 67.6777 - mean_absolute_error: 67.6777 - val_loss: 135.3791 - val_mean_absolute_error: 135.3791
#
# Epoch 00180: val_loss did not improve from 97.78725
# Epoch 181/800
# 3/3 [==============================] - 0s 19ms/step - loss: 66.6688 - mean_absolute_error: 66.6688 - val_loss: 105.0879 - val_mean_absolute_error: 105.0879
#
# Epoch 00181: val_loss did not improve from 97.78725
# Epoch 182/800
# 3/3 [==============================] - 0s 18ms/step - loss: 66.0196 - mean_absolute_error: 66.0196 - val_loss: 137.6362 - val_mean_absolute_error: 137.6362
#
# Epoch 00182: val_loss did not improve from 97.78725
# Epoch 183/800
# 3/3 [==============================] - 0s 20ms/step - loss: 68.5306 - mean_absolute_error: 68.5306 - val_loss: 126.8276 - val_mean_absolute_error: 126.8276
#
# Epoch 00183: val_loss did not improve from 97.78725
# Epoch 184/800
# 3/3 [==============================] - 0s 17ms/step - loss: 64.2080 - mean_absolute_error: 64.2080 - val_loss: 100.1848 - val_mean_absolute_error: 100.1848
#
# Epoch 00184: val_loss did not improve from 97.78725
# Epoch 185/800
# 3/3 [==============================] - 0s 17ms/step - loss: 66.4328 - mean_absolute_error: 66.4328 - val_loss: 128.9129 - val_mean_absolute_error: 128.9129
#
# Epoch 00185: val_loss did not improve from 97.78725
# Epoch 186/800
# 3/3 [==============================] - 0s 18ms/step - loss: 66.7697 - mean_absolute_error: 66.7697 - val_loss: 135.1928 - val_mean_absolute_error: 135.1928
#
# Epoch 00186: val_loss did not improve from 97.78725
# Epoch 187/800
# 3/3 [==============================] - 0s 18ms/step - loss: 62.9691 - mean_absolute_error: 62.9691 - val_loss: 106.1686 - val_mean_absolute_error: 106.1686
#
# Epoch 00187: val_loss did not improve from 97.78725
# Epoch 188/800
# 3/3 [==============================] - 0s 18ms/step - loss: 66.2957 - mean_absolute_error: 66.2957 - val_loss: 128.6085 - val_mean_absolute_error: 128.6085
#
# Epoch 00188: val_loss did not improve from 97.78725
# Epoch 189/800
# 3/3 [==============================] - 0s 18ms/step - loss: 66.8856 - mean_absolute_error: 66.8856 - val_loss: 128.3600 - val_mean_absolute_error: 128.3600
#
# Epoch 00189: val_loss did not improve from 97.78725
# Epoch 190/800
# 3/3 [==============================] - 0s 28ms/step - loss: 68.2077 - mean_absolute_error: 68.2077 - val_loss: 98.1421 - val_mean_absolute_error: 98.1421
#
# Epoch 00190: val_loss did not improve from 97.78725
# Epoch 191/800
# 3/3 [==============================] - 0s 17ms/step - loss: 66.4432 - mean_absolute_error: 66.4432 - val_loss: 155.1813 - val_mean_absolute_error: 155.1813
#
# Epoch 00191: val_loss did not improve from 97.78725
# Epoch 192/800
# 3/3 [==============================] - 0s 18ms/step - loss: 73.5162 - mean_absolute_error: 73.5162 - val_loss: 124.3520 - val_mean_absolute_error: 124.3520
#
# Epoch 00192: val_loss did not improve from 97.78725
# Epoch 193/800
# 3/3 [==============================] - 0s 18ms/step - loss: 67.6705 - mean_absolute_error: 67.6705 - val_loss: 85.2398 - val_mean_absolute_error: 85.2398
#
# Epoch 00193: val_loss improved from 97.78725 to 85.23985, saving model to Weights-193--85.23985.hdf5
# Epoch 194/800
# 3/3 [==============================] - 0s 19ms/step - loss: 68.0347 - mean_absolute_error: 68.0347 - val_loss: 141.8087 - val_mean_absolute_error: 141.8087
#
# Epoch 00194: val_loss did not improve from 85.23985
# Epoch 195/800
# 3/3 [==============================] - 0s 18ms/step - loss: 72.0911 - mean_absolute_error: 72.0911 - val_loss: 142.8358 - val_mean_absolute_error: 142.8358
#
# Epoch 00195: val_loss did not improve from 85.23985
# Epoch 196/800
# 3/3 [==============================] - 0s 18ms/step - loss: 65.7147 - mean_absolute_error: 65.7147 - val_loss: 88.3646 - val_mean_absolute_error: 88.3646
#
# Epoch 00196: val_loss did not improve from 85.23985
# Epoch 197/800
# 3/3 [==============================] - 0s 18ms/step - loss: 68.7355 - mean_absolute_error: 68.7355 - val_loss: 132.8090 - val_mean_absolute_error: 132.8090
#
# Epoch 00197: val_loss did not improve from 85.23985
# Epoch 198/800
# 3/3 [==============================] - 0s 18ms/step - loss: 66.0864 - mean_absolute_error: 66.0864 - val_loss: 131.0438 - val_mean_absolute_error: 131.0438
#
# Epoch 00198: val_loss did not improve from 85.23985
# Epoch 199/800
# 3/3 [==============================] - 0s 17ms/step - loss: 64.5001 - mean_absolute_error: 64.5001 - val_loss: 103.0668 - val_mean_absolute_error: 103.0668
#
# Epoch 00199: val_loss did not improve from 85.23985
# Epoch 200/800
# 3/3 [==============================] - 0s 18ms/step - loss: 60.5307 - mean_absolute_error: 60.5307 - val_loss: 133.4901 - val_mean_absolute_error: 133.4901
#
# Epoch 00200: val_loss did not improve from 85.23985
# Epoch 201/800
# 3/3 [==============================] - 0s 19ms/step - loss: 63.2832 - mean_absolute_error: 63.2832 - val_loss: 118.6035 - val_mean_absolute_error: 118.6035
#
# Epoch 00201: val_loss did not improve from 85.23985
# Epoch 202/800
# 3/3 [==============================] - 0s 17ms/step - loss: 60.8541 - mean_absolute_error: 60.8541 - val_loss: 101.3402 - val_mean_absolute_error: 101.3402
#
# Epoch 00202: val_loss did not improve from 85.23985
# Epoch 203/800
# 3/3 [==============================] - 0s 18ms/step - loss: 60.6258 - mean_absolute_error: 60.6258 - val_loss: 124.3330 - val_mean_absolute_error: 124.3330
#
# Epoch 00203: val_loss did not improve from 85.23985
# Epoch 204/800
# 3/3 [==============================] - 0s 18ms/step - loss: 60.7335 - mean_absolute_error: 60.7335 - val_loss: 115.3266 - val_mean_absolute_error: 115.3266
#
# Epoch 00204: val_loss did not improve from 85.23985
# Epoch 205/800
# 3/3 [==============================] - 0s 19ms/step - loss: 59.0133 - mean_absolute_error: 59.0133 - val_loss: 108.8477 - val_mean_absolute_error: 108.8477
#
# Epoch 00205: val_loss did not improve from 85.23985
# Epoch 206/800
# 3/3 [==============================] - 0s 17ms/step - loss: 59.3267 - mean_absolute_error: 59.3267 - val_loss: 120.5156 - val_mean_absolute_error: 120.5156
#
# Epoch 00206: val_loss did not improve from 85.23985
# Epoch 207/800
# 3/3 [==============================] - 0s 19ms/step - loss: 60.5493 - mean_absolute_error: 60.5493 - val_loss: 111.1034 - val_mean_absolute_error: 111.1034
#
# Epoch 00207: val_loss did not improve from 85.23985
# Epoch 208/800
# ...
#
# Epoch 00728: val_loss did not improve from 18.75073
# Epoch 729/800
# 3/3 [==============================] - 0s 19ms/step - loss: 33.2158 - mean_absolute_error: 33.2158 - val_loss: 49.3877 - val_mean_absolute_error: 49.3877
#
# Epoch 00729: val_loss did not improve from 18.75073
# Epoch 730/800
# 3/3 [==============================] - 0s 18ms/step - loss: 26.1655 - mean_absolute_error: 26.1655 - val_loss: 24.3377 - val_mean_absolute_error: 24.3377
#
# Epoch 00730: val_loss did not improve from 18.75073
# Epoch 731/800
# 3/3 [==============================] - 0s 18ms/step - loss: 23.9474 - mean_absolute_error: 23.9474 - val_loss: 33.7844 - val_mean_absolute_error: 33.7844
#
# Epoch 00731: val_loss did not improve from 18.75073
# Epoch 732/800
# 3/3 [==============================] - 0s 19ms/step - loss: 25.3921 - mean_absolute_error: 25.3921 - val_loss: 23.3031 - val_mean_absolute_error: 23.3031
#
# Epoch 00732: val_loss did not improve from 18.75073
# Epoch 733/800
# 3/3 [==============================] - 0s 16ms/step - loss: 27.7454 - mean_absolute_error: 27.7454 - val_loss: 33.2418 - val_mean_absolute_error: 33.2418
#
# Epoch 00733: val_loss did not improve from 18.75073
# Epoch 734/800
# 3/3 [==============================] - 0s 18ms/step - loss: 32.0506 - mean_absolute_error: 32.0506 - val_loss: 41.9055 - val_mean_absolute_error: 41.9055
#
# Epoch 00734: val_loss did not improve from 18.75073
# Epoch 735/800
# 3/3 [==============================] - 0s 17ms/step - loss: 27.7353 - mean_absolute_error: 27.7353 - val_loss: 22.6874 - val_mean_absolute_error: 22.6874
#
# Epoch 00735: val_loss did not improve from 18.75073
# Epoch 736/800
# 3/3 [==============================] - 0s 18ms/step - loss: 25.6760 - mean_absolute_error: 25.6760 - val_loss: 43.8964 - val_mean_absolute_error: 43.8964
#
# Epoch 00736: val_loss did not improve from 18.75073
# Epoch 737/800
# 3/3 [==============================] - 0s 18ms/step - loss: 28.2092 - mean_absolute_error: 28.2092 - val_loss: 21.9799 - val_mean_absolute_error: 21.9799
#
# Epoch 00737: val_loss did not improve from 18.75073
# Epoch 738/800
# 3/3 [==============================] - 0s 18ms/step - loss: 21.4372 - mean_absolute_error: 21.4372 - val_loss: 45.4622 - val_mean_absolute_error: 45.4622
#
# Epoch 00738: val_loss did not improve from 18.75073
# Epoch 739/800
# 3/3 [==============================] - 0s 19ms/step - loss: 24.3110 - mean_absolute_error: 24.3110 - val_loss: 26.2720 - val_mean_absolute_error: 26.2720
#
# Epoch 00739: val_loss did not improve from 18.75073
# Epoch 740/800
# 3/3 [==============================] - 0s 17ms/step - loss: 24.2460 - mean_absolute_error: 24.2460 - val_loss: 45.1416 - val_mean_absolute_error: 45.1416
#
# Epoch 00740: val_loss did not improve from 18.75073
# Epoch 741/800
# 3/3 [==============================] - 0s 18ms/step - loss: 23.2898 - mean_absolute_error: 23.2898 - val_loss: 28.6899 - val_mean_absolute_error: 28.6899
#
# Epoch 00741: val_loss did not improve from 18.75073
# Epoch 742/800
# 3/3 [==============================] - 0s 29ms/step - loss: 21.9319 - mean_absolute_error: 21.9319 - val_loss: 41.4924 - val_mean_absolute_error: 41.4924
#
# Epoch 00742: val_loss did not improve from 18.75073
# Epoch 743/800
# 3/3 [==============================] - 0s 19ms/step - loss: 21.9225 - mean_absolute_error: 21.9225 - val_loss: 32.5073 - val_mean_absolute_error: 32.5073
#
# Epoch 00743: val_loss did not improve from 18.75073
# Epoch 744/800
# 3/3 [==============================] - 0s 17ms/step - loss: 25.8522 - mean_absolute_error: 25.8522 - val_loss: 41.8251 - val_mean_absolute_error: 41.8251
#
# Epoch 00744: val_loss did not improve from 18.75073
# Epoch 745/800
# 3/3 [==============================] - 0s 18ms/step - loss: 28.6572 - mean_absolute_error: 28.6572 - val_loss: 27.5888 - val_mean_absolute_error: 27.5888
#
# Epoch 00745: val_loss did not improve from 18.75073
# Epoch 746/800
# 3/3 [==============================] - 0s 18ms/step - loss: 23.1879 - mean_absolute_error: 23.1879 - val_loss: 33.0884 - val_mean_absolute_error: 33.0884
#
# Epoch 00746: val_loss did not improve from 18.75073
# Epoch 747/800
# 3/3 [==============================] - 0s 18ms/step - loss: 23.1304 - mean_absolute_error: 23.1304 - val_loss: 23.3051 - val_mean_absolute_error: 23.3051
#
# Epoch 00747: val_loss did not improve from 18.75073
# Epoch 748/800
# 3/3 [==============================] - 0s 18ms/step - loss: 26.0885 - mean_absolute_error: 26.0885 - val_loss: 41.8923 - val_mean_absolute_error: 41.8923
#
# Epoch 00748: val_loss did not improve from 18.75073
# Epoch 749/800
# 3/3 [==============================] - 0s 17ms/step - loss: 27.6609 - mean_absolute_error: 27.6609 - val_loss: 25.0452 - val_mean_absolute_error: 25.0452
#
# Epoch 00749: val_loss did not improve from 18.75073
# Epoch 750/800
# 3/3 [==============================] - 0s 19ms/step - loss: 25.6254 - mean_absolute_error: 25.6254 - val_loss: 38.2022 - val_mean_absolute_error: 38.2022
#
# Epoch 00750: val_loss did not improve from 18.75073
# Epoch 751/800
# 3/3 [==============================] - 0s 20ms/step - loss: 25.1844 - mean_absolute_error: 25.1844 - val_loss: 35.7657 - val_mean_absolute_error: 35.7657
#
# Epoch 00751: val_loss did not improve from 18.75073
# Epoch 752/800
# 3/3 [==============================] - 0s 19ms/step - loss: 21.7394 - mean_absolute_error: 21.7394 - val_loss: 29.1865 - val_mean_absolute_error: 29.1865
#
# Epoch 00752: val_loss did not improve from 18.75073
# Epoch 753/800
# 3/3 [==============================] - 0s 18ms/step - loss: 21.7616 - mean_absolute_error: 21.7616 - val_loss: 41.1644 - val_mean_absolute_error: 41.1644
#
# Epoch 00753: val_loss did not improve from 18.75073
# Epoch 754/800
# 3/3 [==============================] - 0s 19ms/step - loss: 22.1122 - mean_absolute_error: 22.1122 - val_loss: 28.2977 - val_mean_absolute_error: 28.2977
#
# Epoch 00754: val_loss did not improve from 18.75073
# Epoch 755/800
# 3/3 [==============================] - 0s 17ms/step - loss: 21.6901 - mean_absolute_error: 21.6901 - val_loss: 48.0768 - val_mean_absolute_error: 48.0768
#
# Epoch 00755: val_loss did not improve from 18.75073
# Epoch 756/800
# 3/3 [==============================] - 0s 19ms/step - loss: 21.6641 - mean_absolute_error: 21.6641 - val_loss: 31.3488 - val_mean_absolute_error: 31.3488
#
# Epoch 00756: val_loss did not improve from 18.75073
# Epoch 757/800
# 3/3 [==============================] - 0s 18ms/step - loss: 23.7528 - mean_absolute_error: 23.7528 - val_loss: 49.9744 - val_mean_absolute_error: 49.9744
#
# Epoch 00757: val_loss did not improve from 18.75073
# Epoch 758/800
# 3/3 [==============================] - 0s 17ms/step - loss: 22.3246 - mean_absolute_error: 22.3246 - val_loss: 34.0077 - val_mean_absolute_error: 34.0077
#
# Epoch 00758: val_loss did not improve from 18.75073
# Epoch 759/800
# 3/3 [==============================] - 0s 18ms/step - loss: 21.3861 - mean_absolute_error: 21.3861 - val_loss: 37.8723 - val_mean_absolute_error: 37.8723
#
# Epoch 00759: val_loss did not improve from 18.75073
# Epoch 760/800
# 3/3 [==============================] - 0s 19ms/step - loss: 20.9729 - mean_absolute_error: 20.9729 - val_loss: 35.1962 - val_mean_absolute_error: 35.1962
#
# Epoch 00760: val_loss did not improve from 18.75073
# Epoch 761/800
# 3/3 [==============================] - 0s 17ms/step - loss: 21.8033 - mean_absolute_error: 21.8033 - val_loss: 29.1536 - val_mean_absolute_error: 29.1536
#
# Epoch 00761: val_loss did not improve from 18.75073
# Epoch 762/800
# 3/3 [==============================] - 0s 18ms/step - loss: 26.0072 - mean_absolute_error: 26.0072 - val_loss: 38.4275 - val_mean_absolute_error: 38.4275
#
# Epoch 00762: val_loss did not improve from 18.75073
# Epoch 763/800
# 3/3 [==============================] - 0s 19ms/step - loss: 24.7367 - mean_absolute_error: 24.7367 - val_loss: 33.8731 - val_mean_absolute_error: 33.8731
#
# Epoch 00763: val_loss did not improve from 18.75073
# Epoch 764/800
# 3/3 [==============================] - 0s 19ms/step - loss: 22.2100 - mean_absolute_error: 22.2100 - val_loss: 40.9482 - val_mean_absolute_error: 40.9482
#
# Epoch 00764: val_loss did not improve from 18.75073
# Epoch 765/800
# 3/3 [==============================] - 0s 27ms/step - loss: 24.7096 - mean_absolute_error: 24.7096 - val_loss: 29.9528 - val_mean_absolute_error: 29.9528
#
# Epoch 00765: val_loss did not improve from 18.75073
# Epoch 766/800
# 3/3 [==============================] - 0s 19ms/step - loss: 30.8088 - mean_absolute_error: 30.8088 - val_loss: 58.6113 - val_mean_absolute_error: 58.6113
#
# Epoch 00766: val_loss did not improve from 18.75073
# Epoch 767/800
# 3/3 [==============================] - 0s 20ms/step - loss: 31.5607 - mean_absolute_error: 31.5607 - val_loss: 22.2623 - val_mean_absolute_error: 22.2623
#
# Epoch 00767: val_loss did not improve from 18.75073
# Epoch 768/800
# 3/3 [==============================] - 0s 21ms/step - loss: 34.8948 - mean_absolute_error: 34.8948 - val_loss: 55.0636 - val_mean_absolute_error: 55.0636
#
# Epoch 00768: val_loss did not improve from 18.75073
# Epoch 769/800
# 3/3 [==============================] - 0s 20ms/step - loss: 25.6528 - mean_absolute_error: 25.6528 - val_loss: 25.7114 - val_mean_absolute_error: 25.7114
#
# Epoch 00769: val_loss did not improve from 18.75073
# Epoch 770/800
# 3/3 [==============================] - 0s 19ms/step - loss: 24.8527 - mean_absolute_error: 24.8527 - val_loss: 34.9240 - val_mean_absolute_error: 34.9240
#
# Epoch 00770: val_loss did not improve from 18.75073
# Epoch 771/800
# 3/3 [==============================] - 0s 18ms/step - loss: 21.2265 - mean_absolute_error: 21.2265 - val_loss: 34.9005 - val_mean_absolute_error: 34.9005
#
# Epoch 00771: val_loss did not improve from 18.75073
# Epoch 772/800
# 3/3 [==============================] - 0s 19ms/step - loss: 23.1141 - mean_absolute_error: 23.1141 - val_loss: 29.9776 - val_mean_absolute_error: 29.9776
#
# Epoch 00772: val_loss did not improve from 18.75073
# Epoch 773/800
# 3/3 [==============================] - 0s 18ms/step - loss: 22.6779 - mean_absolute_error: 22.6779 - val_loss: 52.0565 - val_mean_absolute_error: 52.0565
#
# Epoch 00773: val_loss did not improve from 18.75073
# Epoch 774/800
# 3/3 [==============================] - 0s 18ms/step - loss: 27.9689 - mean_absolute_error: 27.9689 - val_loss: 27.2278 - val_mean_absolute_error: 27.2278
#
# Epoch 00774: val_loss did not improve from 18.75073
# Epoch 775/800
# 3/3 [==============================] - 0s 18ms/step - loss: 24.6834 - mean_absolute_error: 24.6834 - val_loss: 39.3040 - val_mean_absolute_error: 39.3040
#
# Epoch 00775: val_loss did not improve from 18.75073
# Epoch 776/800
# 3/3 [==============================] - 0s 18ms/step - loss: 21.6798 - mean_absolute_error: 21.6798 - val_loss: 29.8164 - val_mean_absolute_error: 29.8164
#
# Epoch 00776: val_loss did not improve from 18.75073
# Epoch 777/800
# 3/3 [==============================] - 0s 18ms/step - loss: 22.3298 - mean_absolute_error: 22.3298 - val_loss: 43.4065 - val_mean_absolute_error: 43.4065
#
# Epoch 00777: val_loss did not improve from 18.75073
# Epoch 778/800
# 3/3 [==============================] - 0s 34ms/step - loss: 23.6436 - mean_absolute_error: 23.6436 - val_loss: 26.3127 - val_mean_absolute_error: 26.3127
#
# Epoch 00778: val_loss did not improve from 18.75073
# Epoch 779/800
# 3/3 [==============================] - 0s 18ms/step - loss: 26.8990 - mean_absolute_error: 26.8990 - val_loss: 49.6217 - val_mean_absolute_error: 49.6217
#
# Epoch 00779: val_loss did not improve from 18.75073
# Epoch 780/800
# 3/3 [==============================] - 0s 29ms/step - loss: 22.2656 - mean_absolute_error: 22.2656 - val_loss: 25.4675 - val_mean_absolute_error: 25.4675
#
# Epoch 00780: val_loss did not improve from 18.75073
# Epoch 781/800
# 3/3 [==============================] - 0s 20ms/step - loss: 26.0647 - mean_absolute_error: 26.0647 - val_loss: 53.2460 - val_mean_absolute_error: 53.2460
#
# Epoch 00781: val_loss did not improve from 18.75073
# Epoch 782/800
# 3/3 [==============================] - 0s 20ms/step - loss: 26.1362 - mean_absolute_error: 26.1362 - val_loss: 26.9437 - val_mean_absolute_error: 26.9437
#
# Epoch 00782: val_loss did not improve from 18.75073
# Epoch 783/800
# 3/3 [==============================] - 0s 19ms/step - loss: 26.1680 - mean_absolute_error: 26.1680 - val_loss: 39.8892 - val_mean_absolute_error: 39.8892
#
# Epoch 00783: val_loss did not improve from 18.75073
# Epoch 784/800
# 3/3 [==============================] - 0s 18ms/step - loss: 27.5246 - mean_absolute_error: 27.5246 - val_loss: 30.5832 - val_mean_absolute_error: 30.5832
#
# Epoch 00784: val_loss did not improve from 18.75073
# Epoch 785/800
# 3/3 [==============================] - 0s 19ms/step - loss: 31.7224 - mean_absolute_error: 31.7224 - val_loss: 29.5962 - val_mean_absolute_error: 29.5962
#
# Epoch 00785: val_loss did not improve from 18.75073
# Epoch 786/800
# 3/3 [==============================] - 0s 17ms/step - loss: 30.3728 - mean_absolute_error: 30.3728 - val_loss: 47.7431 - val_mean_absolute_error: 47.7431
#
# Epoch 00786: val_loss did not improve from 18.75073
# Epoch 787/800
# 3/3 [==============================] - 0s 19ms/step - loss: 24.1285 - mean_absolute_error: 24.1285 - val_loss: 22.1051 - val_mean_absolute_error: 22.1051
#
# Epoch 00787: val_loss did not improve from 18.75073
# Epoch 788/800
# 3/3 [==============================] - 0s 18ms/step - loss: 28.4957 - mean_absolute_error: 28.4957 - val_loss: 71.8647 - val_mean_absolute_error: 71.8647
#
# Epoch 00788: val_loss did not improve from 18.75073
# Epoch 789/800
# 3/3 [==============================] - 0s 18ms/step - loss: 31.0727 - mean_absolute_error: 31.0727 - val_loss: 21.2045 - val_mean_absolute_error: 21.2045
#
# Epoch 00789: val_loss did not improve from 18.75073
# Epoch 790/800
# 3/3 [==============================] - 0s 19ms/step - loss: 36.7073 - mean_absolute_error: 36.7073 - val_loss: 43.3493 - val_mean_absolute_error: 43.3493
#
# Epoch 00790: val_loss did not improve from 18.75073
# Epoch 791/800
# 3/3 [==============================] - 0s 16ms/step - loss: 39.5253 - mean_absolute_error: 39.5253 - val_loss: 53.8230 - val_mean_absolute_error: 53.8230
#
# Epoch 00791: val_loss did not improve from 18.75073
# Epoch 792/800
# 3/3 [==============================] - 0s 18ms/step - loss: 29.7336 - mean_absolute_error: 29.7336 - val_loss: 20.6757 - val_mean_absolute_error: 20.6757
#
# Epoch 00792: val_loss did not improve from 18.75073
# Epoch 793/800
# 3/3 [==============================] - 0s 18ms/step - loss: 25.9509 - mean_absolute_error: 25.9509 - val_loss: 70.0319 - val_mean_absolute_error: 70.0319
#
# Epoch 00793: val_loss did not improve from 18.75073
# Epoch 794/800
# 3/3 [==============================] - 0s 19ms/step - loss: 30.7050 - mean_absolute_error: 30.7050 - val_loss: 21.3964 - val_mean_absolute_error: 21.3964
#
# Epoch 00794: val_loss did not improve from 18.75073
# Epoch 795/800
# 3/3 [==============================] - 0s 18ms/step - loss: 45.2519 - mean_absolute_error: 45.2519 - val_loss: 29.2285 - val_mean_absolute_error: 29.2285
#
# Epoch 00795: val_loss did not improve from 18.75073
# Epoch 796/800
# 3/3 [==============================] - 0s 18ms/step - loss: 34.2223 - mean_absolute_error: 34.2223 - val_loss: 69.5775 - val_mean_absolute_error: 69.5775
#
# Epoch 00796: val_loss did not improve from 18.75073
# Epoch 797/800
# 3/3 [==============================] - 0s 19ms/step - loss: 33.7701 - mean_absolute_error: 33.7701 - val_loss: 25.3832 - val_mean_absolute_error: 25.3832
#
# Epoch 00797: val_loss did not improve from 18.75073
# Epoch 798/800
# 3/3 [==============================] - 0s 19ms/step - loss: 33.7986 - mean_absolute_error: 33.7986 - val_loss: 45.1844 - val_mean_absolute_error: 45.1844
#
# Epoch 00798: val_loss did not improve from 18.75073
# Epoch 799/800
# 3/3 [==============================] - 0s 18ms/step - loss: 37.2208 - mean_absolute_error: 37.2208 - val_loss: 39.3027 - val_mean_absolute_error: 39.3027
#
# Epoch 00799: val_loss did not improve from 18.75073
# Epoch 800/800
# 3/3 [==============================] - 0s 19ms/step - loss: 37.9614 - mean_absolute_error: 37.9614 - val_loss: 21.2564 - val_mean_absolute_error: 21.2564
#
# Epoch 00800: val_loss did not improve from 18.75073

# %%
print(history.history.keys())
plt.figure(figsize=(25, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')

plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
print(history.history.keys())
plt.figure(figsize=(25, 10))
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model absolute error')

plt.ylabel('absolute error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
wights_file = './Weights-406--18.75073.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
ypred = NN_model.predict(test)
print("R2 score    Using DNN for Weight: %.3f" % (r2_score(target2,ypred)*100))
print("MSE         Using DNN for Weight: %.3f" % mean_squared_error(target2,ypred))
print("RMSE        Using DNN for Weight: %.3f" % math.sqrt(mean_squared_error(target2,ypred)))
print("MAE         Using DNN for Weight: %.3f" % math.sqrt(mean_absolute_error(target2,ypred)))
i=r2_score(target2,ypred)*100
# Out:
# R2 score    Using DNN for Weight: 95.975
# MSE         Using DNN for Weight: 6838.075
# RMSE        Using DNN for Weight: 82.693
# MAE         Using DNN for Weight: 7.613

# %% [markdown]
# ### 7. Comparison between all models

# %% [markdown]
# > **We are taking R-square for selecting best model**

# %%
print("R2 score Length1 and Weight:                       %.3f" % (a))
print("R2 score Height and Weight:                        %.3f" % (b))
print("R2 score Width and Weight:                         %.3f" % (c))
print("R2 score Length1,Length2,Length3 and Weight:       %.3f" % (d))
print("R2 score Width,Length1,Height and Weight:          %.3f" % (e))
print("R2 score Width,Height and Weight:                  %.3f" % (f))
print("R2 score Using Random Forest Regression for Weight:%.3f" % (g))
print("R2 score Using XGBRegressor for Weight:            %.3f" % (h))
print("R2 score Using DNN for Weight:                     %.3f" % (i))
# Out:
# R2 score Length1 and Weight:                       53.565
# R2 score Height and Weight:                        29.536
# R2 score Width and Weight:                         76.911
# R2 score Length1,Length2,Length3 and Weight:       77.975
# R2 score Width,Length1,Height and Weight:          63.085
# R2 score Width,Height and Weight:                  66.866
# R2 score Using Random Forest Regression for Weight:80.996
# R2 score Using XGBRegressor for Weight:            92.750
# R2 score Using DNN for Weight:                     95.975

# %% [markdown]
# ### 8. Visualization and results of best model

# %%
plt.scatter(test['Length1'], target2, color='red', alpha=0.6)
plt.scatter(test['Length1'], ypred, color='blue', alpha=0.6)
plt.xlabel('Cross Length in cm')
plt.ylabel('Weight of the fish')
plt.title('DNN Model for Weight Estimation');

# %%
plt.scatter(test['Length2'], target2, color='purple', alpha=0.5)
plt.scatter(test['Length2'], ypred, color='orange', alpha=0.5)
plt.xlabel('Vertical Length in cm')
plt.ylabel('Weight of the fish')
plt.title('DNN Model for Weight Estimation');

# %%
plt.scatter(test['Length3'], target2, color='purple', alpha=0.4)
plt.scatter(test['Length3'], ypred, color='green', alpha=0.4)
plt.xlabel('Diagonal Length in cm')
plt.ylabel('Weight of the fish')
plt.title('DNN for Weight Estimation');

# %%
plt.scatter(test['Height'], target2, color='orange', alpha=0.5)
plt.scatter(test['Height'], ypred, color='blue', alpha=0.5)
plt.xlabel('Height in cm')
plt.ylabel('Weight of the fish')
plt.title('DNN Model for Weight Estimation');

# %%
plt.scatter(test['Width'], target2, color='gray', alpha=0.5)
plt.scatter(test['Width'], ypred, color='red', alpha=0.5)
plt.xlabel('Width in cm')
plt.ylabel('Weight of the fish')
plt.title('DNN Model for Weight Estimation');

# %% [markdown]
# ### Conclusion
#
# From above code we can see that DNN is best which give accuracy about 95.97% and we have done 600 epoches .
#
# ## Made By Shivam Saxena
