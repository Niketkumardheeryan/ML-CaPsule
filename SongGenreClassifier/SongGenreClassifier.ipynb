# %% [markdown]
# <a href="https://colab.research.google.com/github/TANYA-CHAN/SongGenreClassifiernlp/blob/master/SongGenreClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
path1 = "/content/drive/My Drive/Colab Notebooks/lyrics1.csv"
df = pd.read_csv(path1)

# %%
import numpy as np
df['ranker_genre'] = np.where((df['ranker_genre'] == 'screamo')|(df['ranker_genre'] == 'punk rock')|(df['ranker_genre'] == 'heavy metal'),'alt rock',df['ranker_genre'])
group = ['song', 'year', 'album', 'genre', 'artist', 'ranker_genre']
lyrics_by_song = df.sort_values(group).groupby(group).lyric.apply(' '.join).apply(lambda x: x.lower()).reset_index(name='lyric')
lyrics_by_song["lyric"] = lyrics_by_song['lyric'].str.replace(r'[^\w\s]','')

# %% [markdown]
# SPLITTING DATA

# %%
from sklearn.utils import shuffle
from nltk.corpus import stopwords
genres = ['Country','alt rock', 'Hip Hop','pop','rhythm and blues']
LYRIC_LEN = 400
N = 10000
RANDOM_SEED = 200
train_df = pd.DataFrame()
test_df = pd.DataFrame()

# %%
for genre in genres:
    subset = lyrics_by_song[(lyrics_by_song.ranker_genre == genre) & (lyrics_by_song.lyric.str.len() >= LYRIC_LEN)]
    train_set = subset.sample(n=N, replace=True, random_state=RANDOM_SEED)
    test_set = subset.drop(train_set.index)
    train_df = train_df.append(train_set)
    test_df = test_df.append(test_set)
train_df = shuffle(train_df)
test_df = shuffle(test_df)

# %% [markdown]
# TRAINING MODEL

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer
stop = list(set(stopwords.words('english')))
wnl = WordNetLemmatizer()
def tokenizer(x):
  return (wnl.lemmatize(w) for w in word_tokenize(x) if len(w)>=2 and w.isalnum())
text_clf = Pipeline([('vect', TfidfVectorizer(ngram_range=(1, 2),tokenizer=tokenizer,stop_words=stop,max_df=0.4,min_df=4)),('tfidf', TfidfTransformer()),('clf', MultinomialNB(alpha=0.1))])
text_clf.fit(train_df.lyric, train_df.ranker_genre)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['could', 'doe', 'ha', 'might', 'must', 'need', 'sha', 'wa', 'wo', 'would'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# Pipeline(memory=None,
#          steps=[('vect',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=0.4, max_features=None,
#                                  min_df=4, ngram_range=(1, 2), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=['needn', "you've", 'isn', 'in',
#                                              'a', 'theirs', "weren't", 'yours'...
#                                              'more', 'aren', 'which', 'and',
#                                              "shouldn't", 'about', ...],
#                                  strip_accents=None, sublinear_tf=False,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer at 0x7fd595c98158>,
#                                  use_idf=True, vocabulary=None)),
#                 ('tfidf',
#                  TfidfTransformer(norm='l2', smooth_idf=True,
#                                   sublinear_tf=False, use_idf=True)),
#                 ('clf',
#                  MultinomialNB(alpha=0.1, class_prior=None, fit_prior=True))],
#          verbose=False)

# %%
predicted = text_clf.predict(test_df.lyric)
np.mean(predicted == test_df.ranker_genre)
# Out:
# 0.8338469608550259

# %% [markdown]
# CONFUSION MATRIX

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(test_df.ranker_genre, predicted)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,xticklabels=genres, yticklabels=genres)
plt.xlabel('true label')
plt.ylabel('predicted label');
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# EVALUATION CLASSIFIER

# %%
from sklearn.metrics import precision_recall_fscore_support
precision, recall, fscore, support = precision_recall_fscore_support(test_df.ranker_genre, predicted)
for n,genre in enumerate(genres):
    print(genre+'_precision: {}'.format(precision[n]))
    print(genre+'_recall: {}'.format(recall[n]))
    print(genre+'_fscore: {}'.format(fscore[n]))
    print(genre+'_support: {}'.format(support[n]))
    print()
# Out:
# Country_precision: 0.9385155096011817
# Country_recall: 0.846367319753566
# Country_fscore: 0.8900627462425216
# Country_support: 18017
#
# alt rock_precision: 0.7006444053895724
# alt rock_recall: 0.9192928516525749
# alt rock_fscore: 0.7952127659574468
# alt rock_support: 1301
#
# Hip Hop_precision: 0.8506772737045797
# Hip Hop_recall: 0.8285863874345549
# Hip Hop_fscore: 0.8394865266284743
# Hip Hop_support: 9550
#
# pop_precision: 0.13820078226857888
# pop_recall: 0.5096153846153846
# pop_fscore: 0.21743589743589742
# pop_support: 208
#
# rhythm and blues_precision: 0.39144471347861176
# rhythm and blues_recall: 0.6802244039270687
# rhythm and blues_fscore: 0.4969262295081967
# rhythm and blues_support: 1426

# %% [markdown]
# TESTING UI

# %%
text = input("Enter a lyric: ")
l = []
l.append(text)
print(text_clf.predict(l))
# Out:
# Enter a lyric: i stand for the red white and blue
# ['Country']

# %%
data = train_df.append(test_df)
predicts = text_clf.predict_proba(data.lyric)
data['Country'], data['Hip_Hop'], data['Alt_Rock'], data['Pop'], data['RnB'] = ['','','','','']
for n,row in enumerate(data.itertuples()):
    data.loc[row.Index, 'Country'] = predicts[n][0]
    data.loc[row.Index, 'Hip_Hop'] = predicts[n][1]
    data.loc[row.Index, 'Alt_Rock'] = predicts[n][2]
    data.loc[row.Index, 'Pop'] = predicts[n][3]
    data.loc[row.Index, 'RnB'] = predicts[n][4]

# %% [markdown]
# TOP HIP-HOP SONGS

# %%
columns_of_interest = ['artist', 'song', 'album', 'ranker_genre', 'Hip_Hop', 'Alt_Rock', 'Country','Pop','RnB']
data[columns_of_interest].sort_values(['Hip_Hop'], ascending=False).head(10)
# Out:
#             artist                     song  ...          Pop          RnB
# 1401  Krayzie_Bone           A Thugga Level  ...  3.21222e-14  6.03973e-14
# 1401  Krayzie_Bone           A Thugga Level  ...  3.21222e-14  6.03973e-14
# 1401  Krayzie_Bone           A Thugga Level  ...  3.21222e-14  6.03973e-14
# 1401  Krayzie_Bone           A Thugga Level  ...  3.21222e-14  6.03973e-14
# 1401  Krayzie_Bone           A Thugga Level  ...  3.21222e-14  6.03973e-14
# 4111     Lil_Wayne                  BM J.R.  ...  1.22271e-13  7.82516e-13
# 2074     Lil_Wayne  Ain't Worried Bout Shit  ...  5.30444e-14  6.31525e-13
# 2074     Lil_Wayne  Ain't Worried Bout Shit  ...  5.30444e-14  6.31525e-13
# 2074     Lil_Wayne  Ain't Worried Bout Shit  ...  5.30444e-14  6.31525e-13
# 2074     Lil_Wayne  Ain't Worried Bout Shit  ...  5.30444e-14  6.31525e-13
#
# [10 rows x 9 columns]

# %% [markdown]
# TOP ROCK SONGS

# %%
columns_of_interest = ['artist', 'song', 'album', 'ranker_genre', 'Hip_Hop', 'Alt_Rock', 'Country','Pop','RnB']
data[columns_of_interest].sort_values(['Alt_Rock'], ascending=False).head(10)
# Out:
#            artist           song  ...          Pop          RnB
# 40894     Blondie        Rapture  ...  1.86343e-09   7.0989e-10
# 40900     Blondie        Rapture  ...  1.86343e-09   7.0989e-10
# 40896     Blondie        Rapture  ...  1.86343e-09   7.0989e-10
# 40895     Blondie        Rapture  ...  1.86343e-09   7.0989e-10
# 40893     Blondie        Rapture  ...  1.86343e-09   7.0989e-10
# 40897     Blondie        Rapture  ...  1.86343e-09   7.0989e-10
# 40892     Blondie        Rapture  ...  1.86343e-09   7.0989e-10
# 40900     Blondie        Rapture  ...  1.86343e-09   7.0989e-10
# 29088  Uriah Heep  Lady In Black  ...  1.07863e-09  1.57433e-09
# 29091  Uriah Heep  Lady In Black  ...  1.07863e-09  1.57433e-09
#
# [10 rows x 9 columns]

# %% [markdown]
# TOP COUNTRY SONGS

# %%
columns_of_interest = ['artist', 'song', 'album', 'ranker_genre', 'Hip_Hop', 'Alt_Rock', 'Country','Pop','RnB']
data[columns_of_interest].sort_values(['Country'], ascending=False).head(10)
# Out:
#                    artist                song  ...          Pop          RnB
# 33360         Johnny Cash  Me and Bobby McGee  ...   2.5055e-10  5.06446e-10
# 33354  Kris Kristofferson  Me and Bobby McGee  ...   2.5055e-10  5.06446e-10
# 33362  Kris Kristofferson  Me and Bobby McGee  ...   2.5055e-10  5.06446e-10
# 33321  Kris Kristofferson    Me & Bobby McGee  ...   2.5055e-10  5.06446e-10
# 33361       Willie Nelson  Me and Bobby McGee  ...  2.13178e-10  3.54495e-10
# 33355           Hank Snow  Me and Bobby McGee  ...  3.20194e-10  3.95844e-10
# 50729           Hank Snow   The Golden Rocket  ...  5.72049e-11  1.08905e-09
# 50725           Hank Snow   The Golden Rocket  ...  5.72049e-11  1.08905e-09
# 50734           Hank Snow   The Golden Rocket  ...  5.72049e-11  1.08905e-09
# 50731           Hank Snow   The Golden Rocket  ...  5.72049e-11  1.08905e-09
#
# [10 rows x 9 columns]

# %% [markdown]
# TOP POP SONGS

# %%
columns_of_interest = ['artist', 'song', 'album', 'ranker_genre', 'Hip_Hop', 'Alt_Rock', 'Country','Pop','RnB']
data[columns_of_interest].sort_values(['Pop'], ascending=False).head(10)
# Out:
#                artist                                  song  ... Pop          RnB
# 46514  Modern Talking  Space Mix (The Ultimate Nonstop mix)  ...   1   2.2623e-14
# 46514  Modern Talking  Space Mix (The Ultimate Nonstop mix)  ...   1   2.2623e-14
# 36655  Modern Talking                       No.1 Hit Medley  ...   1  5.06555e-10
# 36655  Modern Talking                       No.1 Hit Medley  ...   1  5.06555e-10
# 52124           Sweet                          The Sixteens  ...   1  9.77273e-10
# 52123       The Sweet                         The Six Teens  ...   1  9.77273e-10
# 52120           Sweet                         The Six Teens  ...   1  9.77273e-10
# 52126           Sweet                          The Sixteens  ...   1  9.77273e-10
# 52122           Sweet                         The Six Teens  ...   1  9.77273e-10
# 52118           Sweet                         The Six Teens  ...   1  9.77273e-10
#
# [10 rows x 9 columns]

# %% [markdown]
# TOP RnB SONGS

# %%
columns_of_interest = ['artist', 'song', 'album', 'ranker_genre', 'Hip_Hop', 'Alt_Rock', 'Country','Pop','RnB']
data[columns_of_interest].sort_values(['RnB'], ascending=False).head(10)
# Out:
#             artist   song  ...          Pop RnB
# 53164  James Brown  Think  ...  4.07417e-09   1
# 53159  James Brown  Think  ...  4.07417e-09   1
# 53153  James Brown  Think  ...  4.07417e-09   1
# 53164  James Brown  Think  ...  4.07417e-09   1
# 53154  James Brown  Think  ...  4.07417e-09   1
# 53155  James Brown  Think  ...  4.07417e-09   1
# 53160  James Brown  Think  ...  4.07417e-09   1
# 53164  James Brown  Think  ...  4.07417e-09   1
# 53160  James Brown  Think  ...  4.07417e-09   1
# 53160  James Brown  Think  ...  4.07417e-09   1
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST ROCK LIKE HIP-HOP SONGS

# %%
data[data.ranker_genre=='Hip Hop'][columns_of_interest].sort_values(['Alt_Rock'], ascending=False).head(10)
# Out:
#                    artist                       song  ...          Pop          RnB
# 55514  Immortal_Technique           Ultimas Palabras  ...  7.74105e-08  3.98944e-07
# 62113    Childish_Gambino                    Zombies  ...   0.00716323   0.00129358
# 51452               Rakim  The Mystery (Who Is God?)  ...  1.62958e-05  7.88283e-05
# 59691            Scarface          Win, Lose Or Draw  ...  0.000113043  0.000254684
# 56237            Scarface                     Voices  ...   0.00514364    0.0024463
# 56237            Scarface                     Voices  ...   0.00514364    0.0024463
# 30055         Lupe_Fiasco                 Letting Go  ...   0.00752345   0.00174299
# 4951          Lupe_Fiasco  Beautiful Lasers (2 Ways)  ...   0.00394856   0.00711216
# 33213             Raekwon        Masters Of Our Fate  ...  0.000608894   0.00334718
# 18585               B.o.B                  Have Nots  ...     0.015987   0.00676227
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST COUNTRY LIKE HIP-HOP SONGS

# %%
data[data.ranker_genre=='Hip Hop'][columns_of_interest].sort_values(['Country'], ascending=False).head(10)
# Out:
#                  artist               song  ...         Pop         RnB
# 49158          Yelawolf     Tennessee Love  ...  0.00135883   0.0182529
# 49159          Yelawolf     Tennessee Love  ...  0.00135883   0.0182529
# 28220               DMC       Just Like Me  ...  0.00480578   0.0573672
# 41538        De_La_Soul     Rev. Do Good 1  ...   0.0109197    0.111033
# 11168          Yelawolf  Devil In My Veins  ...   0.0142661   0.0634544
# 9469           Scarface  Conspiracy Theory  ...  0.00383706  0.00920852
# 9469           Scarface  Conspiracy Theory  ...  0.00383706  0.00920852
# 56197          Yelawolf             Violin  ...  0.00028734  0.00591501
# 25127  Childish_Gambino       I. Pink Toes  ...   0.0678382   0.0481471
# 46978          Fabolous               Stay  ...   0.0819962    0.125247
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST POP LIKE HIP-HOP SONGS

# %%
data[data.ranker_genre=='Hip Hop'][columns_of_interest].sort_values(['Pop'], ascending=False).head(10)
# Out:
#                  artist               song  ...       Pop        RnB
# 18586  Childish_Gambino     Have Some Love  ...  0.795699  0.0820596
# 36359           Mos_Def    No Hay Nada Mas  ...  0.752444  0.0148833
# 756            Ludacris  9 Times Out Of 10  ...  0.724391  0.0023352
# 33399  Childish_Gambino   Me and Your Mama  ...  0.689155   0.143348
# 46331             Drake  Sooner Than Later  ...  0.636908   0.118376
# 33140          Scarface          Mary Jane  ...  0.499855   0.173102
# 33140          Scarface          Mary Jane  ...  0.499855   0.173102
# 12516         Lil_Wayne               Down  ...  0.490159   0.104544
# 2073        Talib_Kweli      Ain't Waiting  ...  0.488177   0.120889
# 41956         Lil_Wayne      Rock 'n' Roll  ...  0.483362  0.0552204
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST RnB LIKE HIP-HOP SONGS

# %%
data[data.ranker_genre=='Hip Hop'][columns_of_interest].sort_values(['RnB'], ascending=False).head(10)
# Out:
#                  artist                             song  ...         Pop       RnB
# 50639             Nelly                         The Gank  ...    0.103246  0.846509
# 49823           Mos_Def                       The Beggar  ...   0.0190343  0.809955
# 21904             Drake                 I Get Lonley Too  ...    0.140872  0.769898
# 39889  Childish_Gambino  Pop Thieves (Make It Feel Good)  ...    0.136066  0.767228
# 39889  Childish_Gambino  Pop Thieves (Make It Feel Good)  ...    0.136066  0.767228
# 39889  Childish_Gambino  Pop Thieves (Make It Feel Good)  ...    0.136066  0.767228
# 46389       Talib_Kweli                       Soul Music  ...    0.102102  0.744195
# 47982              Guru                        Supa Love  ...   0.0371012  0.733678
# 61738         LL_Cool_J               You're in My Heart  ...  0.00480365   0.72033
# 55471             Nelly                 U Know U Want To  ...    0.186421  0.669552
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST HIP-HOP LIKE ROCK SONGS

# %%
data[data.ranker_genre=='alt rock'][columns_of_interest].sort_values(['Hip_Hop'], ascending=False).head(10)
# Out:
#                                 artist  ...          RnB
# 16140                 Hollywood Undead  ...  3.35924e-05
# 49324                          Sublime  ...   3.8444e-07
# 43810                 System of a Down  ...   4.6112e-07
# 28657         Blood on the Dance Floor  ...  9.66285e-05
# 49306                          Sublime  ...  2.15852e-06
# 34237         Blood on the Dance Floor  ...  3.23812e-05
# 55444  Fear Before the March of Flames  ...     0.001653
# 9794          I Set My Friends on Fire  ...   0.00318786
# 8071                  Hollywood Undead  ...  0.000120611
# 44331                           Emmure  ...  9.55004e-05
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST COUNTRY LIKE ROCK SONGS

# %%
data[data.ranker_genre=='alt rock'][columns_of_interest].sort_values(['Country'], ascending=False).head(10)
# Out:
#                   artist                        song  ...          Pop          RnB
# 60766            Misfits            You Belong To Me  ...  9.84196e-06   1.5277e-05
# 38266            Misfits           Only Make Believe  ...  1.48665e-06  3.68634e-05
# 37155       Bad Religion      O Come All Ye Faithful  ...  0.000576288  0.000202694
# 7779   Twenty One Pilots  Can't Help Falling in Love  ...  0.000244848  0.000778994
# 58968       Bad Religion             White Christmas  ...  4.48263e-06   0.00380672
# 54699         The Pogues               Train of Love  ...   0.00192768  0.000748007
# 56526         Frank Iero               Walk the Line  ...  0.000566966   0.00175477
# 27856               NOFX             Johnny B. Goode  ...   0.00029858   0.00195426
# 61521   Dropkick Murphys     You'll Never Walk Alone  ...  9.75256e-05  9.50439e-05
# 32774  Social Distortion              Making Believe  ...  0.000570128    0.0132796
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST POP LIKE ROCK SONGS

# %%
data[data.ranker_genre=='alt rock'][columns_of_interest].sort_values(['Pop'], ascending=False).head(10)
# Out:
#                               artist  ...          RnB
# 4658                      The Damned  ...  9.79262e-09
# 54648               A Static Lullaby  ...  7.22893e-07
# 54648               A Static Lullaby  ...  7.22893e-07
# 48862                          Heart  ...   0.00199268
# 18298  Joan Jett and the Blackhearts  ...   0.00177659
# 7867              The Bouncing Souls  ...   0.00239805
# 29029                 Blind Guardian  ...   0.00187247
# 33792                 Blind Guardian  ...   0.00133697
# 7592                         Blondie  ...    0.0056112
# 3201                    Bad Religion  ...    0.0382363
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST RnB LIKE ROCK SONGS

# %%
data[data.ranker_genre=='alt rock'][columns_of_interest].sort_values(['RnB'], ascending=False).head(10)
# Out:
#                               artist  ...       RnB
# 53415                        Misfits  ...  0.999735
# 1738                     Sonic Youth  ...  0.999642
# 38334                       Iggy Pop  ...  0.999027
# 14687                     The Cramps  ...  0.997709
# 28048                      Motörhead  ...  0.996904
# 29874  Joan Jett and the Blackhearts  ...  0.993224
# 22132                      The Slits  ...  0.986349
# 22132                      The Slits  ...  0.986349
# 4905                    Fall Out Boy  ...  0.986059
# 4904                 Pierce the Veil  ...  0.985724
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST HIP-HOP LIKE COUNTRY SONGS

# %%
data[data.ranker_genre=='Country'][columns_of_interest].sort_values(['Hip_Hop'], ascending=False).head(10)
# Out:
#                          artist  ...          RnB
# 53731              Taylor Swift  ...  0.000212714
# 49692        Hank Williams, Jr.  ...   0.00217393
# 19780              George Jones  ...   0.00103231
# 19779              George Jones  ...   0.00103231
# 8495                Johnny Cash  ...   0.00427101
# 1924              Willie Nelson  ...    0.0078147
# 38230              Brad Paisley  ...   0.00201119
# 27417                Buck Owens  ...    0.0260038
# 15502             Elvis Presley  ...    0.0260752
# 1984   The Charlie Daniels Band  ...   0.00101097
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST ROCK LIKE COUNTRY SONGS

# %%
data[data.ranker_genre=='Country'][columns_of_interest].sort_values(['Alt_Rock'], ascending=False).head(10)
# Out:
#                    artist  ...          RnB
# 31170  Olivia Newton-John  ...  0.000584441
# 18614       Willie Nelson  ...   0.00563176
# 18612         Johnny Cash  ...   0.00713294
# 30110       Elvis Presley  ...   0.00295297
# 13276       Elvis Presley  ...   0.00495669
# 34058         Eric Church  ...   0.00305675
# 8641            Hank Snow  ...   0.00341678
# 8640            Hank Snow  ...   0.00341678
# 53764          Tim McGraw  ...   0.00751579
# 15840     Martina McBride  ...   0.00331131
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST POP LIKE COUNTRY SONGS

# %%
data[data.ranker_genre=='Country'][columns_of_interest].sort_values(['Pop'], ascending=False).head(10)
# Out:
#                    artist  ...          RnB
# 30247  Olivia Newton-John  ...   3.3762e-05
# 24786    Barbara Mandrell  ...  1.63866e-05
# 13896  Olivia Newton-John  ...   8.3274e-05
# 13895  Olivia Newton-John  ...   8.3274e-05
# 42101          Toby Keith  ...  1.67697e-05
# 42480          Sara Evans  ...   0.00110023
# 42481       Dwight Yoakam  ...   0.00582449
# 33640       Elvis Presley  ...    0.0155601
# 19410       Willie Nelson  ...  0.000303285
# 19409         Kitty Wells  ...   0.00031632
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST RnB LIKE COUNTRY SONGS

# %%
data[data.ranker_genre=='Country'][columns_of_interest].sort_values(['RnB'], ascending=False).head(10)
# Out:
#                  artist  ...       RnB
# 35039     Glen Campbell  ...  0.999998
# 45390       Anne Murray  ...   0.99995
# 42384     Lee Greenwood  ...  0.999947
# 1606      Willie Nelson  ...   0.99994
# 52985     Ronnie Milsap  ...  0.999923
# 45383       Eddy Arnold  ...  0.999908
# 61541  Barbara Mandrell  ...  0.999845
# 61805       Anne Murray  ...   0.99984
# 38523      Ferlin Husky  ...  0.999799
# 43636     Willie Nelson  ...  0.999779
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST HIP-HOP LIKE POP SONGS

# %%
data[data.ranker_genre=='pop'][columns_of_interest].sort_values(['Hip_Hop'], ascending=False).head(10)
# Out:
#                    artist               song  ...         Pop         RnB
# 21860      Hannah Montana     I Forgive Yiew  ...   0.0364154   0.0171445
# 29453        Aaron Carter  Leave It Up To Me  ...  0.00856431     0.15569
# 48400          Katy Perry        Swish Swish  ...    0.296394  0.00100598
# 48400          Katy Perry        Swish Swish  ...    0.296394  0.00100598
# 53561          Katy Perry  This is How We Do  ...    0.316368  0.00116075
# 53561          Katy Perry  This is How We Do  ...    0.316368  0.00116075
# 42580             Giorgio          Rush Rush  ...   0.0574414   0.0228945
# 9184         Aaron Carter     Come Follow Me  ...    0.331551   0.0350854
# 33820      Hannah Montana   Milky Milky Milk  ...   0.0237215   0.0580617
# 5675   Christina Aguilera             Bionic  ...    0.378621   0.0102316
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST ROCK LIKE POP SONGS

# %%
data[data.ranker_genre=='pop'][columns_of_interest].sort_values(['Alt_Rock'], ascending=False).head(10)
# Out:
#                    artist                 song  ...          Pop         RnB
# 2722               Hanson         Already Home  ...    0.0115264    0.001983
# 26312      Hannah Montana             Inspired  ...     0.039462   0.0189454
# 7742        Debbie Gibson    Can't Do It Alone  ...     0.030831    0.054735
# 24675          Katy Perry  I'm Still Breathing  ...     0.127009  0.00305914
# 5611           Katy Perry       Bigger Than Me  ...     0.127206  0.00859582
# 31570  Christina Aguilera          Lotus Intro  ...    0.0477159   0.0238821
# 35604         Spice Girls                Naked  ...    0.0432071   0.0795172
# 42579     Backstreet Boys         Rush Over Me  ...    0.0471555   0.0709857
# 46660          Katy Perry                 Spit  ...  0.000357494   0.0198943
# 15664       Debbie Gibson              Free Me  ...    0.0263891    0.072329
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST COUNTRY LIKE POP SONGS

# %%
data[data.ranker_genre=='pop'][columns_of_interest].sort_values(['Country'], ascending=False).head(10)
# Out:
#                 artist  ...          RnB
# 60858      The Monkees  ...   0.00443921
# 23749  Jessica Simpson  ...   0.00137834
# 4385    Hannah Montana  ...   0.00718264
# 29682  Jessica Simpson  ...   0.00349132
# 44457   Jonas Brothers  ...  0.000606414
# 44457   Jonas Brothers  ...  0.000606414
# 25335      The Monkees  ...    0.0475536
# 20101      The Monkees  ...    0.0196793
# 6181     Bad Boys Blue  ...    0.0008291
# 6181     Bad Boys Blue  ...    0.0008291
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST RnB LIKE POP SONGS

# %%
data[data.ranker_genre=='pop'][columns_of_interest].sort_values(['Country'], ascending=False).head(10)
# Out:
#                 artist  ...          RnB
# 60858      The Monkees  ...   0.00443921
# 23749  Jessica Simpson  ...   0.00137834
# 4385    Hannah Montana  ...   0.00718264
# 29682  Jessica Simpson  ...   0.00349132
# 44457   Jonas Brothers  ...  0.000606414
# 44457   Jonas Brothers  ...  0.000606414
# 25335      The Monkees  ...    0.0475536
# 20101      The Monkees  ...    0.0196793
# 6181     Bad Boys Blue  ...    0.0008291
# 6181     Bad Boys Blue  ...    0.0008291
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST HIP-HOP LIKE RnB SONGS

# %%
data[data.ranker_genre=='rhythm and blues'][columns_of_interest].sort_values(['Hip_Hop'], ascending=False).head(10)
# Out:
#                 artist                     song  ...          Pop        RnB
# 9428             Usher  Confessions (Interlude)  ...    0.0071539  0.0173678
# 47664           Prince                    Style  ...   0.00238831  0.0620629
# 4389   Beyoncé Knowles                  Back Up  ...   0.00294022  0.0922259
# 43688  Beyoncé Knowles           Sexy Lil' Thug  ...  0.000299385  0.0991512
# 43688  Beyoncé Knowles           Sexy Lil' Thug  ...  0.000299385  0.0991512
# 41285           Prince               Release It  ...   0.00950548  0.0346091
# 62097           Prince                 Zannalee  ...    0.0195516  0.0479439
# 41814           Prince           Ripopgodazippa  ...   0.00091503  0.0563298
# 12190           Prince            Don't Play Me  ...   0.00971199  0.0402679
# 6348            Prince               Bob George  ...  0.000320543   0.151031
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST ROCK LIKE RnB SONGS

# %%
data[data.ranker_genre=='rhythm and blues'][columns_of_interest].sort_values(['Alt_Rock'], ascending=False).head(10)
# Out:
#               artist                  song  ...          Pop         RnB
# 13854   The Supremes       Everyday People  ...  7.87034e-05  0.00787299
# 9395     Tina Turner  Complicated Disaster  ...   0.00885123  0.00385407
# 13398         Prince                 Emale  ...   0.00496008   0.0187425
# 45585    Ray Charles        So Help Me God  ...   0.00701644   0.0251545
# 14366         Prince           Family Name  ...  0.000119268  0.00407865
# 19395         Prince                  Here  ...      0.00177   0.0592729
# 35949  Janet Jackson            New Agenda  ...   0.00201903   0.0241806
# 12777         Prince               Dreamer  ...   0.00103165   0.0754947
# 56593         Prince        Wall Of Berlin  ...   0.00667192   0.0206817
# 57408         Prince    Welcome 2 The Dawn  ...    0.0155649   0.0284808
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST COUNTRY LIKE RnB SONGS

# %%
data[data.ranker_genre=='rhythm and blues'][columns_of_interest].sort_values(['Country'], ascending=False).head(10)
# Out:
#                 artist  ...          RnB
# 24463      Tina Turner  ...  7.80012e-06
# 25976         Al Green  ...  4.46037e-06
# 40066         Al Green  ...   0.00015531
# 10521        Sam Cooke  ...  0.000508508
# 19684      Ray Charles  ...  0.000233316
# 19349      Tina Turner  ...  0.000705032
# 19349      Tina Turner  ...  0.000705032
# 13390  Aretha Franklin  ...  0.000705957
# 37199       Diana Ross  ...   0.00116471
# 37200       Diana Ross  ...   0.00116471
#
# [10 rows x 9 columns]

# %% [markdown]
# MOST POP LIKE RnB SONGS

# %%
data[data.ranker_genre=='rhythm and blues'][columns_of_interest].sort_values(['Pop'], ascending=False).head(10)
# Out:
#                    artist  ...         RnB
# 57599            Al Green  ...  0.00109337
# 35643        The Supremes  ...  0.00404273
# 18340          Diana Ross  ...  0.00311477
# 54220     Michael Jackson  ...  0.00513282
# 24705        The Supremes  ...  0.00550014
# 22793       The Jackson 5  ...   0.0068349
# 57598       Stevie Wonder  ...  0.00135041
# 23091  The Isley Brothers  ...   0.0106825
# 23091  The Isley Brothers  ...   0.0106825
# 14023     Whitney Houston  ...  0.00352766
#
# [10 rows x 9 columns]

# %% [markdown]
# WORD CLOUD

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt
comment_words = '' 
stopwords = set(STOPWORDS)

# %% [markdown]
# GENERAL WORD CLOUD

# %%
for val in lyrics_by_song.lyric:
  val = str(val) 
  tokens = val.split() 
  for i in range(len(tokens)): 
    tokens[i] = tokens[i].lower() 
  comment_words += " ".join(tokens)+" "
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', stopwords = stopwords, min_font_size = 10).generate(comment_words)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0)   
plt.show()

# %% [markdown]
# COUNTRY WORD CLOUD

# %%
if([lyrics_by_song.ranker_genre=='Country']):
  for val in lyrics_by_song.lyric: 
      val = str(val)  
      tokens = val.split() 
      for i in range(len(tokens)): 
          tokens[i] = tokens[i].lower() 
      comment_words += " ".join(tokens)+" "
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', stopwords = stopwords, min_font_size = 10).generate(comment_words) 
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# ROCK WORD CLOUD

# %%
if([lyrics_by_song.ranker_genre=='alt rock']):
  for val in lyrics_by_song.lyric: 
      val = str(val)  
      tokens = val.split() 
      for i in range(len(tokens)): 
          tokens[i] = tokens[i].lower() 
      comment_words += " ".join(tokens)+" "
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', stopwords = stopwords, min_font_size = 10).generate(comment_words) 
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# HIP HOP WORD CLOUD

# %%
if([lyrics_by_song.ranker_genre=='Hip Hop']):
  for val in lyrics_by_song.lyric: 
      val = str(val)  
      tokens = val.split() 
      for i in range(len(tokens)): 
          tokens[i] = tokens[i].lower() 
      comment_words += " ".join(tokens)+" "
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', stopwords = stopwords, min_font_size = 10).generate(comment_words) 
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# POP WORD CLOUD

# %%
if([lyrics_by_song.ranker_genre=='pop']):
  for val in lyrics_by_song.lyric: 
      val = str(val)  
      tokens = val.split() 
      for i in range(len(tokens)): 
          tokens[i] = tokens[i].lower() 
      comment_words += " ".join(tokens)+" "
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', stopwords = stopwords, min_font_size = 10).generate(comment_words) 
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# RnB WORD CLOUD

# %%
if([lyrics_by_song.ranker_genre=='rhythm and blues']):
  for val in lyrics_by_song.lyric: 
      val = str(val)  
      tokens = val.split() 
      for i in range(len(tokens)): 
          tokens[i] = tokens[i].lower() 
      comment_words += " ".join(tokens)+" "
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', stopwords = stopwords, min_font_size = 10).generate(comment_words) 
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
