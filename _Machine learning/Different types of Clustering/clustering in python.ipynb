# %%
#importing main library
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/My/Desktop/data science/clustering/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#convert species into numerical from by label encoder
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['Species']=label_encoder.fit_transform(df['Species'])
df
df.isnull().sum()# missing values sort out
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
x = df.drop(['Species','Id'],axis = 1)
y = df['Species']

# %%
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int32

# %%
x.shape
# Out:
# (150, 4)

# %%
x.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
for i in x.columns:
    for j in x.columns:
        if i!=j:
            sb.scatterplot(i,j,data=x)
            plt.show()
# Out:
# C:\Users\My\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\My\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\My\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df_2 = x.copy()
df_3 = x.copy()
df_4 = x.copy()
df_5 = x.copy()
df_6 = x.copy()

# %% [markdown]
# **DBSCAN (Density-Based Spatial Clustering of Applications with Noise)**

# %%
from sklearn.cluster import DBSCAN
import sklearn.utils
db = DBSCAN().fit(df_2)

# %%
labels = db.labels_

# %%
df_2['clus'] = labels

# %%
df_2.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'clus'],
#       dtype='object')

# %%
sb.scatterplot(df_2['PetalLengthCm'],df_2['PetalWidthCm'],hue = df_2['clus'])
plt.show()
# Out:
# C:\Users\My\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **OPTICS (Ordering Points to Identify Clustering Structure)**

# %%
from sklearn.cluster import OPTICS
op = OPTICS().fit(df_3)

# %%
labels1 = op.labels_

# %%
df_3['clus'] = labels1

# %%
sb.scatterplot(df_3['PetalLengthCm'],df_3['PetalWidthCm'],hue = df_3['clus'])
plt.show()
# Out:
# C:\Users\My\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Hierarchical Clustering**

# %%
from sklearn.cluster import AgglomerativeClustering
agg_clustering = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')
labels2 = agg_clustering.fit_predict(df_4)

# %%
df_4['clus'] = labels2

# %%
sb.scatterplot(df_4['PetalLengthCm'],df_4['PetalWidthCm'],hue = df_4['clus'])
plt.show()
# Out:
# C:\Users\My\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import scipy.cluster.hierarchy as sc

# %%
plt.figure(figsize=(20, 7))  
plt.title("Dendrograms")  
sc.dendrogram(sc.linkage(df_4, method='ward'))
plt.title('Dendrogram')
plt.xlabel('Sample index')
plt.ylabel('Euclidean distance')
# Out:
# Text(0, 0.5, 'Euclidean distance')

# %% [markdown]
# **Partitioning Clustering**
#
# **K-means clustering**

# %%
cluster_range = range(2,10)
cluster_wss = []
from sklearn.cluster import KMeans
for num_cluster in cluster_range:
    cluster = KMeans(num_cluster,random_state=25)
    cluster.fit(x)
    cluster_wss.append(cluster.inertia_)

# %%
cluster_df = pd.DataFrame({'num_cluster':cluster_range,'cluster_wss':cluster_wss})
cluster_df
# Out:
#    num_cluster  cluster_wss
# 0            2   152.368706
# 1            3    78.940841
# 2            4    57.317873
# 3            5    46.561630
# 4            6    38.930963
# 5            7    34.636328
# 6            8    30.009659
# 7            9    28.170474

# %%
plt.xlabel('no. of cluster')
plt.ylabel('WSS')
plt.plot(cluster_df['num_cluster'],cluster_df['cluster_wss'],marker = '*')

# %%
Kclusters = KMeans (n_clusters = 3,random_state = 25)
Kclusters.fit(df_5)
df_5['clus'] = Kclusters.predict(df_5)

# %%
sb.scatterplot(df_5['PetalLengthCm'],df_5['PetalWidthCm'],hue = df_5['clus'])
plt.show()
# Out:
# C:\Users\My\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **PAM (Partitioning Around Medoids)**

# %%
#conda install -c conda-forge scikit-learn-extra
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
from sklearn_extra.cluster import KMedoids
kmedoids = KMedoids(n_clusters=3, random_state=0).fit(df_6)

# %%
df_6['clus'] = kmedoids.predict(df_6)

# %%
sb.scatterplot(df_6['PetalLengthCm'],df_6['PetalWidthCm'],hue = df_6['clus'])
plt.show()
# Out:
# C:\Users\My\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
