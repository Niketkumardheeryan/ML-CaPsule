# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.0/755.0 kB 5.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Qm5ZOoE8El12JR1k5ifR")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 2372.60it/s]

# %%
dataset.location
# Out:
# '/content/football-players-detection-1'

# %%
'''import shutil

shutil.move('/content/football-players-detection-1/train',
            '/content/drive/MyDrive/Datasets/football-players-detection-1/football-players-detection-1/train'
            )

shutil.move('/content/football-players-detection-1/test',
            '/content/drive/MyDrive/Datasets/football-players-detection-1/football-players-detection-1/test'
            )

shutil.move('/content/football-players-detection-1/valid',
            '/content/drive/MyDrive/Datasets/football-players-detection-1/football-players-detection-1/valid')'''
# Out:
# "import shutil\n\nshutil.move('/content/football-players-detection-1/train',\n            '/content/drive/MyDrive/Datasets/football-players-detection-1/football-players-detection-1/train'\n            )\n\nshutil.move('/content/football-players-detection-1/test',\n            '/content/drive/MyDrive/Datasets/football-players-detection-1/football-players-detection-1/test'\n            )\n\nshutil.move('/content/football-players-detection-1/valid',\n            '/content/drive/MyDrive/Datasets/football-players-detection-1/football-players-detection-1/valid')"

# %%
import shutil
shutil.move('/content/runs/detect/train2/weights/best.pt',
            '/content/drive/MyDrive/Datasets/football-players-detection-1/newBest100.pt')
# Out:
# '/content/drive/MyDrive/Datasets/football-players-detection-1/newBest100.pt'

# %%
shutil.move('/content/runs/detect/train2/weights/last.pt',
            '/content/drive/MyDrive/Datasets/football-players-detection-1/newLast100.pt')
# Out:
# '/content/drive/MyDrive/Datasets/football-players-detection-1/newLast100.pt'

# %%
# !yolo task=detect mode=train model=yolov5x.pt data="/content/drive/MyDrive/Datasets/football-players-detection-1/data.yaml" epochs=100 imgsz=600
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics YOLOv8.2.5 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
